# %%
#%pip install yfinance

# %%
import yfinance as yfin
import os


start = '1950-01-01'

# %%
def download_price_data(ticker_list_file, start_date, end_date, dest_dir):
    # create dest_dir if not exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    with open(ticker_list_file, 'r') as f:
        tickers = f.readlines()
        # replace space to dash '-'
        tickers = [ticker.replace(' ', '-').strip() for ticker in tickers]
    for ticker in tickers:
        try:
            data = yfin.Ticker(ticker).history(start=start_date, end=end_date, auto_adjust=False, timeout=40)
            data.index = data.index.date.astype(str)
            data.to_csv(f'{dest_dir}/{ticker}.csv')
            print(f'Downloaded data for {ticker}')
        except Exception as e:
            print(f'Failed to download data for {ticker}: {e}')
            continue

# %%
download_price_data('./data/sp_500.txt', start, None, './data/prices')
# Out:
# Exception ignored from cffi callback <function buffer_callback at 0x7378f4edf420>:
# Traceback (most recent call last):
#   File "/home/ken/.pyenv/versions/myenv/lib/python3.11/site-packages/curl_cffi/curl.py", line 100, in buffer_callback
#     @ffi.def_extern()
#
# KeyboardInterrupt:
# Failed to get ticker 'MMM' reason: Failed to perform, curl: (23) Failure writing output to destination, passed 13 returned 0. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# $ANSS: possibly delisted; no timezone found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 download_price_data('./data/sp_500.txt', start, None, './data/prices')
#
# Cell In[6], line 12, in download_price_data(ticker_list_file, start_date, end_date, dest_dir)
#      10 for ticker in tickers:
#      11     data = yfin.Ticker(ticker).history(start=start_date, end=end_date, auto_adjust=False, timeout=40)
# ---> 12     data.index = data.index.date.astype(str)
#      13     data.to_csv(f'{dest_dir}/{ticker}.csv')
#
# AttributeError: 'Index' object has no attribute 'date'
