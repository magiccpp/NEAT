# %%
from pathlib import Path
import pandas as pd
import numpy as np

def count_csv_rows(file_path, has_header=True):
    """
    Counts the number of rows in a CSV file.
    
    Parameters:
    - file_path (Path): The path to the CSV file.
    - has_header (bool): Whether the CSV file has a header row.
    
    Returns:
    - int: The number of data rows in the CSV file.
    """
    with file_path.open('r', encoding='utf-8') as file:
        row_count = sum(1 for _ in file)
    return row_count - 1 if has_header else row_count

def enumerate_and_sort_csv(datadir, has_header=True):
    """
    Enumerates CSV files in the given directory, counts their rows, and sorts them.
    
    Parameters:
    - datadir (str or Path): The directory containing CSV files.
    - has_header (bool): Whether the CSV files have header rows.
    
    Returns:
    - List of tuples: Each tuple contains (file_name, row_count), sorted by row_count ascending.
    """
    datadir = Path(datadir)
    if not datadir.is_dir():
        raise ValueError(f"The path {datadir} is not a valid directory.")
    
    # Find all CSV files in the directory
    csv_files = list(datadir.glob('*.csv'))
    
    if not csv_files:
        print("No CSV files found in the specified directory.")
        return []
    
    file_row_counts = []
    
    for file in csv_files:
        try:
            rows = count_csv_rows(file, has_header=has_header)
            file_row_counts.append((file.name, rows))
        except Exception as e:
            print(f"Error processing {file.name}: {e}")
    
    # Sort the list of tuples based on row_count (ascending order)
    sorted_files = sorted(file_row_counts, key=lambda x: x[1])
    
    return sorted_files

# %%
# Specify the directory containing CSV files
data_directory = 'data/prices'  # Replace with your directory path

# Enumerate and sort CSV files
sorted_csv_files = enumerate_and_sort_csv(data_directory, has_header=True)

if sorted_csv_files:
    print("\nCSV files sorted by number of rows (ascending):")
    for filename, count in sorted_csv_files:
        print(f"{filename}: {count} rows")
# Out:
# CSV files sorted by number of rows (ascending):
# GEV.csv: 448 rows
# SOLV.csv: 449 rows
# VLTO.csv: 568 rows
# KVUE.csv: 673 rows
# GEHC.csv: 768 rows
# CEG.csv: 997 rows
# ABNB.csv: 1275 rows
# CARR.csv: 1460 rows
# OTIS.csv: 1460 rows
# CTVA.csv: 1666 rows
# UBER.csv: 1676 rows
# DOW.csv: 1712 rows
# FOX.csv: 1717 rows
# FOXA.csv: 1718 rows
# MRNA.csv: 1781 rows
# DAY.csv: 1937 rows
# VICI.csv: 2016 rows
# IR.csv: 2177 rows
# INVH.csv: 2247 rows
# LW.csv: 2302 rows
# HWM.csv: 2309 rows
# FTV.csv: 2393 rows
# HPE.csv: 2571 rows
# KHC.csv: 2645 rows
# PYPL.csv: 2645 rows
# ETSY.csv: 2700 rows
# QRVO.csv: 2771 rows
# KEYS.csv: 2822 rows
# CFG.csv: 2840 rows
# CZR.csv: 2842 rows
# SYF.csv: 2878 rows
# ANET.csv: 2916 rows
# PAYC.csv: 2952 rows
# HLT.csv: 3036 rows
# ALLE.csv: 3053 rows
# CDW.csv: 3153 rows
# NWS.csv: 3159 rows
# NWSA.csv: 3159 rows
# IQV.csv: 3187 rows
# ZTS.csv: 3254 rows
# NCLH.csv: 3263 rows
# ABBV.csv: 3275 rows
# FANG.csv: 3328 rows
# PANW.csv: 3387 rows
# NOW.csv: 3401 rows
# META.csv: 3430 rows
# AMCR.csv: 3433 rows
# PSX.csv: 3456 rows
# ENPH.csv: 3464 rows
# EPAM.csv: 3500 rows
# APTV.csv: 3555 rows
# XYL.csv: 3580 rows
# MPC.csv: 3657 rows
# HII.csv: 3723 rows
# HCA.csv: 3731 rows
# KMI.csv: 3749 rows
# CPAY.csv: 3789 rows
# TRGP.csv: 3795 rows
# GM.csv: 3807 rows
# NXPI.csv: 3880 rows
# TSLA.csv: 3907 rows
# CBOE.csv: 3917 rows
# LYB.csv: 3950 rows
# GNRC.csv: 4002 rows
# CHTR.csv: 4028 rows
# FTNT.csv: 4059 rows
# DG.csv: 4062 rows
# VRSK.csv: 4089 rows
# AVGO.csv: 4132 rows
# KDP.csv: 4447 rows
# AWK.csv: 4457 rows
# V.csv: 4481 rows
# PM.csv: 4483 rows
# MSCI.csv: 4565 rows
# ULTA.csv: 4580 rows
# LULU.csv: 4643 rows
# BX.csv: 4667 rows
# TEL.csv: 4673 rows
# PODD.csv: 4694 rows
# DAL.csv: 4702 rows
# TMUS.csv: 4712 rows
# SMCI.csv: 4726 rows
# BR.csv: 4731 rows
# FSLR.csv: 4814 rows
# LDOS.csv: 4837 rows
# MA.csv: 4937 rows
# TDG.csv: 4987 rows
# UAL.csv: 5013 rows
# CMG.csv: 5020 rows
# LYV.csv: 5043 rows
# ICE.csv: 5067 rows
# AAL.csv: 5103 rows
# AMP.csv: 5111 rows
# CF.csv: 5135 rows
# EXPE.csv: 5150 rows
# WBD.csv: 5159 rows
# BLDR.csv: 5166 rows
# DXCM.csv: 5218 rows
# CE.csv: 5275 rows
# LVS.csv: 5300 rows
# MPWR.csv: 5317 rows
# MKTX.csv: 5327 rows
# DLR.csv: 5332 rows
# GOOG.csv: 5382 rows
# GOOGL.csv: 5382 rows
# EXR.csv: 5385 rows
# DPZ.csv: 5409 rows
# CRM.csv: 5422 rows
# CBRE.csv: 5430 rows
# AIZ.csv: 5517 rows
# NRG.csv: 5561 rows
# LKQ.csv: 5601 rows
# MOH.csv: 5667 rows
# STX.csv: 5806 rows
# CME.csv: 5809 rows
# WYNN.csv: 5838 rows
# NDAQ.csv: 5920 rows
# NFLX.csv: 5946 rows
# CNC.csv: 6056 rows
# PRU.csv: 6056 rows
# ELV.csv: 6087 rows
# PFG.csv: 6092 rows
# BG.csv: 6145 rows
# ZBH.csv: 6151 rows
# ACN.csv: 6155 rows
# FIS.csv: 6175 rows
# AXON.csv: 6176 rows
# MDLZ.csv: 6180 rows
# WTW.csv: 6181 rows
# ALGN.csv: 6273 rows
# GPN.csv: 6283 rows
# GRMN.csv: 6307 rows
# TPR.csv: 6351 rows
# EQIX.csv: 6390 rows
# ILMN.csv: 6400 rows
# CRL.csv: 6424 rows
# ISRG.csv: 6429 rows
# ON.csv: 6461 rows
# MET.csv: 6479 rows
# EW.csv: 6486 rows
# PKG.csv: 6526 rows
# TDY.csv: 6571 rows
# A.csv: 6574 rows
# UPS.csv: 6580 rows
# AKAM.csv: 6588 rows
# BLK.csv: 6608 rows
# SBAC.csv: 6683 rows
# FFIV.csv: 6691 rows
# GS.csv: 6713 rows
# BKNG.csv: 6736 rows
# NVDA.csv: 6783 rows
# EBAY.csv: 6865 rows
# CCI.csv: 6891 rows
# CSGP.csv: 6924 rows
# RSG.csv: 6924 rows
# SRE.csv: 6926 rows
# CTSH.csv: 6932 rows
# MAR.csv: 6994 rows
# AMT.csv: 7010 rows
# PWR.csv: 7020 rows
# VRSN.csv: 7029 rows
# AEE.csv: 7048 rows
# URI.csv: 7057 rows
# PLD.csv: 7075 rows
# MTD.csv: 7080 rows
# FE.csv: 7084 rows
# CHRW.csv: 7101 rows
# YUM.csv: 7122 rows
# BXP.csv: 7185 rows
# RL.csv: 7189 rows
# ARE.csv: 7200 rows
# AMZN.csv: 7208 rows
# VTR.csv: 7216 rows
# TTWO.csv: 7230 rows
# KMX.csv: 7278 rows
# DGX.csv: 7311 rows
# STLD.csv: 7327 rows
# FDS.csv: 7430 rows
# IRM.csv: 7533 rows
# HIG.csv: 7565 rows
# NTAP.csv: 7582 rows
# EL.csv: 7584 rows
# WAT.csv: 7584 rows
# HSIC.csv: 7594 rows
# DVA.csv: 7597 rows
# POOL.csv: 7609 rows
# EG.csv: 7617 rows
# ACGL.csv: 7630 rows
# IVZ.csv: 7643 rows
# FCX.csv: 7677 rows
# WAB.csv: 7692 rows
# RMD.csv: 7702 rows
# DRI.csv: 7719 rows
# COR.csv: 7743 rows
# DLTR.csv: 7763 rows
# COF.csv: 7838 rows
# MCK.csv: 7842 rows
# MCO.csv: 7850 rows
# SJM.csv: 7850 rows
# O.csv: 7859 rows
# ESS.csv: 7952 rows
# CPRT.csv: 8007 rows
# AVB.csv: 8011 rows
# ALB.csv: 8024 rows
# MLM.csv: 8026 rows
# TSCO.csv: 8026 rows
# MAA.csv: 8040 rows
# EMN.csv: 8072 rows
# SPG.csv: 8072 rows
# INCY.csv: 8099 rows
# REG.csv: 8103 rows
# DECK.csv: 8113 rows
# IT.csv: 8121 rows
# BWA.csv: 8157 rows
# EQR.csv: 8158 rows
# CPT.csv: 8173 rows
# ALL.csv: 8207 rows
# JBL.csv: 8229 rows
# RCL.csv: 8232 rows
# ORLY.csv: 8235 rows
# CB.csv: 8255 rows
# MCHP.csv: 8259 rows
# INTU.csv: 8264 rows
# MS.csv: 8277 rows
# MTCH.csv: 8301 rows
# SBUX.csv: 8443 rows
# LIN.csv: 8450 rows
# DHI.csv: 8458 rows
# STE.csv: 8462 rows
# BSX.csv: 8470 rows
# MHK.csv: 8503 rows
# STZ.csv: 8514 rows
# SNPS.csv: 8528 rows
# ROP.csv: 8536 rows
# GILD.csv: 8552 rows
# QCOM.csv: 8578 rows
# KIM.csv: 8592 rows
# APH.csv: 8602 rows
# ODFL.csv: 8613 rows
# BIIB.csv: 8640 rows
# ZBRA.csv: 8662 rows
# VRTX.csv: 8678 rows
# AES.csv: 8697 rows
# IDXX.csv: 8700 rows
# AZO.csv: 8757 rows
# REGN.csv: 8757 rows
# TRMB.csv: 8933 rows
# LH.csv: 9011 rows
# HOLX.csv: 9031 rows
# CSCO.csv: 9039 rows
# CTRA.csv: 9045 rows
# PTC.csv: 9087 rows
# EOG.csv: 9133 rows
# EA.csv: 9143 rows
# GEN.csv: 9204 rows
# IEX.csv: 9219 rows
# TECH.csv: 9297 rows
# WM.csv: 9458 rows
# MGM.csv: 9494 rows
# MOS.csv: 9561 rows
# KEY.csv: 9616 rows
# JCI.csv: 9644 rows
# SCHW.csv: 9648 rows
# FAST.csv: 9670 rows
# CCL.csv: 9689 rows
# FICO.csv: 9691 rows
# TJX.csv: 9708 rows
# CDNS.csv: 9720 rows
# BKR.csv: 9765 rows
# FI.csv: 9898 rows
# ADBE.csv: 9928 rows
# COST.csv: 9953 rows
# TROW.csv: 10021 rows
# MSFT.csv: 10034 rows
# ORCL.csv: 10035 rows
# MNST.csv: 10099 rows
# JKHY.csv: 10111 rows
# ROST.csv: 10183 rows
# DVN.csv: 10196 rows
# NVR.csv: 10196 rows
# ADSK.csv: 10211 rows
# DOC.csv: 10236 rows
# BBY.csv: 10261 rows
# UNH.csv: 10387 rows
# EXPD.csv: 10402 rows
# SWKS.csv: 10415 rows
# AME.csv: 10450 rows
# AJG.csv: 10470 rows
# MU.csv: 10483 rows
# LRCX.csv: 10502 rows
# ATO.csv: 10591 rows
# JBHT.csv: 10615 rows
# T.csv: 10616 rows
# VZ.csv: 10616 rows
# AOS.csv: 10652 rows
# BEN.csv: 10657 rows
# PAYX.csv: 10676 rows
# CTAS.csv: 10681 rows
# CAH.csv: 10692 rows
# RJF.csv: 10715 rows
# AMGN.csv: 10725 rows
# COO.csv: 10827 rows
# NSC.csv: 10990 rows
# BBWI.csv: 11032 rows
# CI.csv: 11033 rows
# VLO.csv: 11094 rows
# COP.csv: 11095 rows
# GLW.csv: 11095 rows
# HUM.csv: 11095 rows
# LHX.csv: 11095 rows
# NOC.csv: 11095 rows
# OXY.csv: 11095 rows
# ROK.csv: 11095 rows
# SLB.csv: 11095 rows
# SO.csv: 11095 rows
# WMB.csv: 11095 rows
# BAX.csv: 11140 rows
# HD.csv: 11165 rows
# UHS.csv: 11217 rows
# BRO.csv: 11319 rows
# AAPL.csv: 11360 rows
# NKE.csv: 11368 rows
# PSA.csv: 11377 rows
# CSX.csv: 11387 rows
# KLAC.csv: 11405 rows
# GL.csv: 11410 rows
# OKE.csv: 11410 rows
# AON.csv: 11495 rows
# WELL.csv: 11546 rows
# NDSN.csv: 11547 rows
# TFC.csv: 11547 rows
# ABT.csv: 11548 rows
# ADI.csv: 11548 rows
# ADM.csv: 11548 rows
# ADP.csv: 11548 rows
# AFL.csv: 11548 rows
# AMAT.csv: 11548 rows
# AMD.csv: 11548 rows
# APD.csv: 11548 rows
# CAG.csv: 11548 rows
# CHD.csv: 11548 rows
# CINF.csv: 11548 rows
# CMA.csv: 11548 rows
# CMCSA.csv: 11548 rows
# D.csv: 11548 rows
# DOV.csv: 11548 rows
# DUK.csv: 11548 rows
# EFX.csv: 11548 rows
# EQT.csv: 11548 rows
# FITB.csv: 11548 rows
# FMC.csv: 11548 rows
# GIS.csv: 11548 rows
# GPC.csv: 11548 rows
# HAS.csv: 11548 rows
# HBAN.csv: 11548 rows
# HRL.csv: 11548 rows
# HST.csv: 11548 rows
# HSY.csv: 11548 rows
# INTC.csv: 11548 rows
# J.csv: 11548 rows
# JPM.csv: 11548 rows
# KMB.csv: 11548 rows
# L.csv: 11548 rows
# LEN.csv: 11548 rows
# LOW.csv: 11548 rows
# MAS.csv: 11548 rows
# MTB.csv: 11548 rows
# NEM.csv: 11548 rows
# NTRS.csv: 11548 rows
# NUE.csv: 11548 rows
# OMC.csv: 11548 rows
# PCAR.csv: 11548 rows
# PGR.csv: 11548 rows
# PH.csv: 11548 rows
# PHM.csv: 11548 rows
# PPG.csv: 11548 rows
# PPL.csv: 11548 rows
# RF.csv: 11548 rows
# RHI.csv: 11548 rows
# ROL.csv: 11548 rows
# SHW.csv: 11548 rows
# STT.csv: 11548 rows
# SWK.csv: 11548 rows
# SYK.csv: 11548 rows
# TFX.csv: 11548 rows
# TMO.csv: 11548 rows
# TSN.csv: 11548 rows
# TT.csv: 11548 rows
# TYL.csv: 11548 rows
# UDR.csv: 11548 rows
# VTRS.csv: 11548 rows
# WEC.csv: 11548 rows
# WST.csv: 11548 rows
# BIO.csv: 11561 rows
# LUV.csv: 11600 rows
# PEG.csv: 11600 rows
# UNP.csv: 11600 rows
# APA.csv: 11760 rows
# DHR.csv: 11854 rows
# WDC.csv: 11895 rows
# FDX.csv: 12036 rows
# C.csv: 12357 rows
# PNC.csv: 12641 rows
# TRV.csv: 12641 rows
# TAP.csv: 12751 rows
# IFF.csv: 12873 rows
# WRB.csv: 13164 rows
# SYY.csv: 13281 rows
# BK.csv: 13284 rows
# EIX.csv: 13284 rows
# FRT.csv: 13284 rows
# PNR.csv: 13284 rows
# USB.csv: 13284 rows
# WY.csv: 13284 rows
# CL.csv: 13285 rows
# EXC.csv: 13285 rows
# MDT.csv: 13285 rows
# ITW.csv: 13320 rows
# AVY.csv: 13334 rows
# BAC.csv: 13334 rows
# BALL.csv: 13334 rows
# BDX.csv: 13334 rows
# CLX.csv: 13334 rows
# CMI.csv: 13334 rows
# CMS.csv: 13334 rows
# CPB.csv: 13334 rows
# CVS.csv: 13334 rows
# ECL.csv: 13334 rows
# ES.csv: 13334 rows
# EVRG.csv: 13334 rows
# GWW.csv: 13334 rows
# LNT.csv: 13334 rows
# MKC.csv: 13334 rows
# MMC.csv: 13334 rows
# NEE.csv: 13334 rows
# NI.csv: 13334 rows
# PNW.csv: 13334 rows
# RVTY.csv: 13334 rows
# SNA.csv: 13334 rows
# SPGI.csv: 13334 rows
# TER.csv: 13334 rows
# TGT.csv: 13334 rows
# TXT.csv: 13334 rows
# VMC.csv: 13334 rows
# XEL.csv: 13334 rows
# K.csv: 13336 rows
# IPG.csv: 13358 rows
# AIG.csv: 13368 rows
# HUBB.csv: 13392 rows
# WMT.csv: 13454 rows
# AXP.csv: 13514 rows
# BMY.csv: 13514 rows
# DD.csv: 13514 rows
# DE.csv: 13514 rows
# EMR.csv: 13514 rows
# ETN.csv: 13514 rows
# ETR.csv: 13514 rows
# F.csv: 13514 rows
# HAL.csv: 13514 rows
# LLY.csv: 13514 rows
# PCG.csv: 13514 rows
# PEP.csv: 13514 rows
# PFE.csv: 13514 rows
# TXN.csv: 13514 rows
# WFC.csv: 13514 rows
# MCD.csv: 14978 rows
# RTX.csv: 16050 rows
# LMT.csv: 16112 rows
# AEP.csv: 16113 rows
# BA.csv: 16113 rows
# CAT.csv: 16113 rows
# CNP.csv: 16113 rows
# CVX.csv: 16113 rows
# DIS.csv: 16113 rows
# DTE.csv: 16113 rows
# ED.csv: 16113 rows
# GD.csv: 16113 rows
# GE.csv: 16113 rows
# HON.csv: 16113 rows
# HPQ.csv: 16113 rows
# IBM.csv: 16113 rows
# IP.csv: 16113 rows
# JNJ.csv: 16113 rows
# KO.csv: 16113 rows
# KR.csv: 16113 rows
# MMM.csv: 16113 rows
# MO.csv: 16113 rows
# MRK.csv: 16113 rows
# MSI.csv: 16113 rows
# PG.csv: 16113 rows
# XOM.csv: 16113 rows

# %%
from collections import defaultdict
import numpy as np

def cluster_csv_pairs_hdbscan_sorted(sorted_csv_files,
                                     min_cluster_size=5,
                                     min_samples=None,
                                     alpha=1.0):
    """
    HDBSCAN clustering with cluster IDs reordered by descending row counts.
    Cluster 0 has the largest rows.
    """

    import hdbscan
    from sklearn.preprocessing import RobustScaler

    if not sorted_csv_files:
        return {}

    # Feature: row count only
    row_counts = np.array([rc for _, rc in sorted_csv_files], dtype=np.float64).reshape(-1, 1)

    # Robust scaling
    X = RobustScaler().fit_transform(row_counts)

    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=min_samples,
        alpha=alpha,
        metric="euclidean"
    )

    raw_labels = clusterer.fit_predict(X)

    # Collect raw clusters
    raw_clusters = defaultdict(list)
    for pair, lab in zip(sorted_csv_files, raw_labels):
        raw_clusters[int(lab)].append(pair)

    # Separate noise
    noise = raw_clusters.pop(-1, [])

    # Sort clusters by mean row count (descending)
    sorted_clusters = sorted(
        raw_clusters.values(),
        key=lambda items: np.mean([rc for _, rc in items]),
        reverse=True
    )

    # Reassign cluster IDs: 0 = largest rows
    final_clusters = {}
    for new_id, items in enumerate(sorted_clusters):
        final_clusters[new_id] = sorted(items, key=lambda x: x[1], reverse=True)

    if noise:
        final_clusters[-1] = sorted(noise, key=lambda x: x[1], reverse=True)

    # Pretty print
    print(f"Clusters found (excluding noise): {len(sorted_clusters)}")
    print(f"Noise points (-1): {len(noise)}\n")

    for cid in sorted(final_clusters.keys(), key=lambda x: (x == -1, x)):
        title = "Noise (-1)" if cid == -1 else f"Cluster {cid}"
        print(f"{title} | size={len(final_clusters[cid])}")
        for fname, rc in final_clusters[cid]:
            print(f"  ({fname!r}, {rc})")
        print()

    return final_clusters


# ---- Example usage ----
# clusters = cluster_csv_pairs_hdbscan_sorted(
#     sorted_csv_files,
#     min_cluster_size=5
# )

# %%
from collections import defaultdict
import numpy as np

def cluster_csv_pairs_k_mean_sorted(sorted_csv_files,
                                    n_clusters,
                                    random_state=None):
    """
    K-Means clustering with cluster IDs reordered by descending row counts.
    Cluster 0 has the largest rows, then 1, etc.

    Parameters
    ----------
    sorted_csv_files : List[Tuple[str, int]]
        A list of (filename, row_count) pairs.
    n_clusters : int
        The number of clusters to form.
    random_state : int or None
        Random seed for KMeans initialization.

    Returns
    -------
    dict[int, List[Tuple[str, int]]]
        A dict mapping new_cluster_id -> list of (filename, row_count),
        with filenames sorted by row count descending.
    """
    from sklearn.cluster import KMeans
    from sklearn.preprocessing import RobustScaler

    if not sorted_csv_files:
        return {}

    # Extract row counts and reshape for sklearn
    row_counts = np.array([rc for _, rc in sorted_csv_files], dtype=np.float64).reshape(-1, 1)

    # Robust scaling to reduce influence of outliers
    X = RobustScaler().fit_transform(row_counts)

    # Run KMeans
    kmeans = KMeans(
        n_clusters=n_clusters,
        random_state=random_state
    )
    labels = kmeans.fit_predict(X)

    # Collect raw clusters
    raw_clusters = defaultdict(list)
    for (fname, rc), lab in zip(sorted_csv_files, labels):
        raw_clusters[int(lab)].append((fname, rc))

    # Re‐order clusters by descending mean row count
    sorted_cluster_items = sorted(
        raw_clusters.values(),
        key=lambda items: np.mean([rc for _, rc in items]),
        reverse=True
    )

    # Assign new IDs: 0 = largest mean row count, 1 = next largest, ...
    final_clusters = {}
    for new_id, items in enumerate(sorted_cluster_items):
        # Within each cluster sort by row count descending
        final_clusters[new_id] = sorted(items, key=lambda x: x[1], reverse=True)

    # Pretty print
    print(f"KMeans Clusters found: {len(final_clusters)}\n")
    for cid in sorted(final_clusters.keys()):
        print(f"Cluster {cid} | size={len(final_clusters[cid])}")
        for fname, rc in final_clusters[cid]:
            print(f"  ({fname!r}, {rc})")
        print()

    return final_clusters


# ---- Example usage ----
# Suppose you have:
# sorted_csv_files = [
#     ("a.csv", 150),
#     ("b.csv", 2000),
#     ("c.csv", 75),
#     # ...
# ]
# clusters = cluster_csv_pairs_k_mean_sorted(
#     sorted_csv_files,
#     n_clusters=4,
#     random_state=42
# )

# %%
clusters = cluster_csv_pairs_k_mean_sorted(sorted_csv_files,
                                              n_clusters=10,
                                              random_state=42)
# Out:
# KMeans Clusters found: 10
#
# Cluster 0 | size=26
#   ('AEP.csv', 16113)
#   ('BA.csv', 16113)
#   ('CAT.csv', 16113)
#   ('CNP.csv', 16113)
#   ('CVX.csv', 16113)
#   ('DIS.csv', 16113)
#   ('DTE.csv', 16113)
#   ('ED.csv', 16113)
#   ('GD.csv', 16113)
#   ('GE.csv', 16113)
#   ('HON.csv', 16113)
#   ('HPQ.csv', 16113)
#   ('IBM.csv', 16113)
#   ('IP.csv', 16113)
#   ('JNJ.csv', 16113)
#   ('KO.csv', 16113)
#   ('KR.csv', 16113)
#   ('MMM.csv', 16113)
#   ('MO.csv', 16113)
#   ('MRK.csv', 16113)
#   ('MSI.csv', 16113)
#   ('PG.csv', 16113)
#   ('XOM.csv', 16113)
#   ('LMT.csv', 16112)
#   ('RTX.csv', 16050)
#   ('MCD.csv', 14978)
#
# Cluster 1 | size=63
#   ('AXP.csv', 13514)
#   ('BMY.csv', 13514)
#   ('DD.csv', 13514)
#   ('DE.csv', 13514)
#   ('EMR.csv', 13514)
#   ('ETN.csv', 13514)
#   ('ETR.csv', 13514)
#   ('F.csv', 13514)
#   ('HAL.csv', 13514)
#   ('LLY.csv', 13514)
#   ('PCG.csv', 13514)
#   ('PEP.csv', 13514)
#   ('PFE.csv', 13514)
#   ('TXN.csv', 13514)
#   ('WFC.csv', 13514)
#   ('WMT.csv', 13454)
#   ('HUBB.csv', 13392)
#   ('AIG.csv', 13368)
#   ('IPG.csv', 13358)
#   ('K.csv', 13336)
#   ('AVY.csv', 13334)
#   ('BAC.csv', 13334)
#   ('BALL.csv', 13334)
#   ('BDX.csv', 13334)
#   ('CLX.csv', 13334)
#   ('CMI.csv', 13334)
#   ('CMS.csv', 13334)
#   ('CPB.csv', 13334)
#   ('CVS.csv', 13334)
#   ('ECL.csv', 13334)
#   ('ES.csv', 13334)
#   ('EVRG.csv', 13334)
#   ('GWW.csv', 13334)
#   ('LNT.csv', 13334)
#   ('MKC.csv', 13334)
#   ('MMC.csv', 13334)
#   ('NEE.csv', 13334)
#   ('NI.csv', 13334)
#   ('PNW.csv', 13334)
#   ('RVTY.csv', 13334)
#   ('SNA.csv', 13334)
#   ('SPGI.csv', 13334)
#   ('TER.csv', 13334)
#   ('TGT.csv', 13334)
#   ('TXT.csv', 13334)
#   ('VMC.csv', 13334)
#   ('XEL.csv', 13334)
#   ('ITW.csv', 13320)
#   ('CL.csv', 13285)
#   ('EXC.csv', 13285)
#   ('MDT.csv', 13285)
#   ('BK.csv', 13284)
#   ('EIX.csv', 13284)
#   ('FRT.csv', 13284)
#   ('PNR.csv', 13284)
#   ('USB.csv', 13284)
#   ('WY.csv', 13284)
#   ('SYY.csv', 13281)
#   ('WRB.csv', 13164)
#   ('IFF.csv', 12873)
#   ('TAP.csv', 12751)
#   ('PNC.csv', 12641)
#   ('TRV.csv', 12641)
#
# Cluster 2 | size=101
#   ('C.csv', 12357)
#   ('FDX.csv', 12036)
#   ('WDC.csv', 11895)
#   ('DHR.csv', 11854)
#   ('APA.csv', 11760)
#   ('LUV.csv', 11600)
#   ('PEG.csv', 11600)
#   ('UNP.csv', 11600)
#   ('BIO.csv', 11561)
#   ('ABT.csv', 11548)
#   ('ADI.csv', 11548)
#   ('ADM.csv', 11548)
#   ('ADP.csv', 11548)
#   ('AFL.csv', 11548)
#   ('AMAT.csv', 11548)
#   ('AMD.csv', 11548)
#   ('APD.csv', 11548)
#   ('CAG.csv', 11548)
#   ('CHD.csv', 11548)
#   ('CINF.csv', 11548)
#   ('CMA.csv', 11548)
#   ('CMCSA.csv', 11548)
#   ('D.csv', 11548)
#   ('DOV.csv', 11548)
#   ('DUK.csv', 11548)
#   ('EFX.csv', 11548)
#   ('EQT.csv', 11548)
#   ('FITB.csv', 11548)
#   ('FMC.csv', 11548)
#   ('GIS.csv', 11548)
#   ('GPC.csv', 11548)
#   ('HAS.csv', 11548)
#   ('HBAN.csv', 11548)
#   ('HRL.csv', 11548)
#   ('HST.csv', 11548)
#   ('HSY.csv', 11548)
#   ('INTC.csv', 11548)
#   ('J.csv', 11548)
#   ('JPM.csv', 11548)
#   ('KMB.csv', 11548)
#   ('L.csv', 11548)
#   ('LEN.csv', 11548)
#   ('LOW.csv', 11548)
#   ('MAS.csv', 11548)
#   ('MTB.csv', 11548)
#   ('NEM.csv', 11548)
#   ('NTRS.csv', 11548)
#   ('NUE.csv', 11548)
#   ('OMC.csv', 11548)
#   ('PCAR.csv', 11548)
#   ('PGR.csv', 11548)
#   ('PH.csv', 11548)
#   ('PHM.csv', 11548)
#   ('PPG.csv', 11548)
#   ('PPL.csv', 11548)
#   ('RF.csv', 11548)
#   ('RHI.csv', 11548)
#   ('ROL.csv', 11548)
#   ('SHW.csv', 11548)
#   ('STT.csv', 11548)
#   ('SWK.csv', 11548)
#   ('SYK.csv', 11548)
#   ('TFX.csv', 11548)
#   ('TMO.csv', 11548)
#   ('TSN.csv', 11548)
#   ('TT.csv', 11548)
#   ('TYL.csv', 11548)
#   ('UDR.csv', 11548)
#   ('VTRS.csv', 11548)
#   ('WEC.csv', 11548)
#   ('WST.csv', 11548)
#   ('NDSN.csv', 11547)
#   ('TFC.csv', 11547)
#   ('WELL.csv', 11546)
#   ('AON.csv', 11495)
#   ('GL.csv', 11410)
#   ('OKE.csv', 11410)
#   ('KLAC.csv', 11405)
#   ('CSX.csv', 11387)
#   ('PSA.csv', 11377)
#   ('NKE.csv', 11368)
#   ('AAPL.csv', 11360)
#   ('BRO.csv', 11319)
#   ('UHS.csv', 11217)
#   ('HD.csv', 11165)
#   ('BAX.csv', 11140)
#   ('COP.csv', 11095)
#   ('GLW.csv', 11095)
#   ('HUM.csv', 11095)
#   ('LHX.csv', 11095)
#   ('NOC.csv', 11095)
#   ('OXY.csv', 11095)
#   ('ROK.csv', 11095)
#   ('SLB.csv', 11095)
#   ('SO.csv', 11095)
#   ('WMB.csv', 11095)
#   ('VLO.csv', 11094)
#   ('CI.csv', 11033)
#   ('BBWI.csv', 11032)
#   ('NSC.csv', 10990)
#   ('COO.csv', 10827)
#
# Cluster 3 | size=44
#   ('AMGN.csv', 10725)
#   ('RJF.csv', 10715)
#   ('CAH.csv', 10692)
#   ('CTAS.csv', 10681)
#   ('PAYX.csv', 10676)
#   ('BEN.csv', 10657)
#   ('AOS.csv', 10652)
#   ('T.csv', 10616)
#   ('VZ.csv', 10616)
#   ('JBHT.csv', 10615)
#   ('ATO.csv', 10591)
#   ('LRCX.csv', 10502)
#   ('MU.csv', 10483)
#   ('AJG.csv', 10470)
#   ('AME.csv', 10450)
#   ('SWKS.csv', 10415)
#   ('EXPD.csv', 10402)
#   ('UNH.csv', 10387)
#   ('BBY.csv', 10261)
#   ('DOC.csv', 10236)
#   ('ADSK.csv', 10211)
#   ('DVN.csv', 10196)
#   ('NVR.csv', 10196)
#   ('ROST.csv', 10183)
#   ('JKHY.csv', 10111)
#   ('MNST.csv', 10099)
#   ('ORCL.csv', 10035)
#   ('MSFT.csv', 10034)
#   ('TROW.csv', 10021)
#   ('COST.csv', 9953)
#   ('ADBE.csv', 9928)
#   ('FI.csv', 9898)
#   ('BKR.csv', 9765)
#   ('CDNS.csv', 9720)
#   ('TJX.csv', 9708)
#   ('FICO.csv', 9691)
#   ('CCL.csv', 9689)
#   ('FAST.csv', 9670)
#   ('SCHW.csv', 9648)
#   ('JCI.csv', 9644)
#   ('KEY.csv', 9616)
#   ('MOS.csv', 9561)
#   ('MGM.csv', 9494)
#   ('WM.csv', 9458)
#
# Cluster 4 | size=57
#   ('TECH.csv', 9297)
#   ('IEX.csv', 9219)
#   ('GEN.csv', 9204)
#   ('EA.csv', 9143)
#   ('EOG.csv', 9133)
#   ('PTC.csv', 9087)
#   ('CTRA.csv', 9045)
#   ('CSCO.csv', 9039)
#   ('HOLX.csv', 9031)
#   ('LH.csv', 9011)
#   ('TRMB.csv', 8933)
#   ('AZO.csv', 8757)
#   ('REGN.csv', 8757)
#   ('IDXX.csv', 8700)
#   ('AES.csv', 8697)
#   ('VRTX.csv', 8678)
#   ('ZBRA.csv', 8662)
#   ('BIIB.csv', 8640)
#   ('ODFL.csv', 8613)
#   ('APH.csv', 8602)
#   ('KIM.csv', 8592)
#   ('QCOM.csv', 8578)
#   ('GILD.csv', 8552)
#   ('ROP.csv', 8536)
#   ('SNPS.csv', 8528)
#   ('STZ.csv', 8514)
#   ('MHK.csv', 8503)
#   ('BSX.csv', 8470)
#   ('STE.csv', 8462)
#   ('DHI.csv', 8458)
#   ('LIN.csv', 8450)
#   ('SBUX.csv', 8443)
#   ('MTCH.csv', 8301)
#   ('MS.csv', 8277)
#   ('INTU.csv', 8264)
#   ('MCHP.csv', 8259)
#   ('CB.csv', 8255)
#   ('ORLY.csv', 8235)
#   ('RCL.csv', 8232)
#   ('JBL.csv', 8229)
#   ('ALL.csv', 8207)
#   ('CPT.csv', 8173)
#   ('EQR.csv', 8158)
#   ('BWA.csv', 8157)
#   ('IT.csv', 8121)
#   ('DECK.csv', 8113)
#   ('REG.csv', 8103)
#   ('INCY.csv', 8099)
#   ('EMN.csv', 8072)
#   ('SPG.csv', 8072)
#   ('MAA.csv', 8040)
#   ('MLM.csv', 8026)
#   ('TSCO.csv', 8026)
#   ('ALB.csv', 8024)
#   ('AVB.csv', 8011)
#   ('CPRT.csv', 8007)
#   ('ESS.csv', 7952)
#
# Cluster 5 | size=49
#   ('O.csv', 7859)
#   ('MCO.csv', 7850)
#   ('SJM.csv', 7850)
#   ('MCK.csv', 7842)
#   ('COF.csv', 7838)
#   ('DLTR.csv', 7763)
#   ('COR.csv', 7743)
#   ('DRI.csv', 7719)
#   ('RMD.csv', 7702)
#   ('WAB.csv', 7692)
#   ('FCX.csv', 7677)
#   ('IVZ.csv', 7643)
#   ('ACGL.csv', 7630)
#   ('EG.csv', 7617)
#   ('POOL.csv', 7609)
#   ('DVA.csv', 7597)
#   ('HSIC.csv', 7594)
#   ('EL.csv', 7584)
#   ('WAT.csv', 7584)
#   ('NTAP.csv', 7582)
#   ('HIG.csv', 7565)
#   ('IRM.csv', 7533)
#   ('FDS.csv', 7430)
#   ('STLD.csv', 7327)
#   ('DGX.csv', 7311)
#   ('KMX.csv', 7278)
#   ('TTWO.csv', 7230)
#   ('VTR.csv', 7216)
#   ('AMZN.csv', 7208)
#   ('ARE.csv', 7200)
#   ('RL.csv', 7189)
#   ('BXP.csv', 7185)
#   ('YUM.csv', 7122)
#   ('CHRW.csv', 7101)
#   ('FE.csv', 7084)
#   ('MTD.csv', 7080)
#   ('PLD.csv', 7075)
#   ('URI.csv', 7057)
#   ('AEE.csv', 7048)
#   ('VRSN.csv', 7029)
#   ('PWR.csv', 7020)
#   ('AMT.csv', 7010)
#   ('MAR.csv', 6994)
#   ('CTSH.csv', 6932)
#   ('SRE.csv', 6926)
#   ('CSGP.csv', 6924)
#   ('RSG.csv', 6924)
#   ('CCI.csv', 6891)
#   ('EBAY.csv', 6865)
#
# Cluster 6 | size=38
#   ('NVDA.csv', 6783)
#   ('BKNG.csv', 6736)
#   ('GS.csv', 6713)
#   ('FFIV.csv', 6691)
#   ('SBAC.csv', 6683)
#   ('BLK.csv', 6608)
#   ('AKAM.csv', 6588)
#   ('UPS.csv', 6580)
#   ('A.csv', 6574)
#   ('TDY.csv', 6571)
#   ('PKG.csv', 6526)
#   ('EW.csv', 6486)
#   ('MET.csv', 6479)
#   ('ON.csv', 6461)
#   ('ISRG.csv', 6429)
#   ('CRL.csv', 6424)
#   ('ILMN.csv', 6400)
#   ('EQIX.csv', 6390)
#   ('TPR.csv', 6351)
#   ('GRMN.csv', 6307)
#   ('GPN.csv', 6283)
#   ('ALGN.csv', 6273)
#   ('WTW.csv', 6181)
#   ('MDLZ.csv', 6180)
#   ('AXON.csv', 6176)
#   ('FIS.csv', 6175)
#   ('ACN.csv', 6155)
#   ('ZBH.csv', 6151)
#   ('BG.csv', 6145)
#   ('PFG.csv', 6092)
#   ('ELV.csv', 6087)
#   ('CNC.csv', 6056)
#   ('PRU.csv', 6056)
#   ('NFLX.csv', 5946)
#   ('NDAQ.csv', 5920)
#   ('WYNN.csv', 5838)
#   ('CME.csv', 5809)
#   ('STX.csv', 5806)
#
# Cluster 7 | size=44
#   ('MOH.csv', 5667)
#   ('LKQ.csv', 5601)
#   ('NRG.csv', 5561)
#   ('AIZ.csv', 5517)
#   ('CBRE.csv', 5430)
#   ('CRM.csv', 5422)
#   ('DPZ.csv', 5409)
#   ('EXR.csv', 5385)
#   ('GOOG.csv', 5382)
#   ('GOOGL.csv', 5382)
#   ('DLR.csv', 5332)
#   ('MKTX.csv', 5327)
#   ('MPWR.csv', 5317)
#   ('LVS.csv', 5300)
#   ('CE.csv', 5275)
#   ('DXCM.csv', 5218)
#   ('BLDR.csv', 5166)
#   ('WBD.csv', 5159)
#   ('EXPE.csv', 5150)
#   ('CF.csv', 5135)
#   ('AMP.csv', 5111)
#   ('AAL.csv', 5103)
#   ('ICE.csv', 5067)
#   ('LYV.csv', 5043)
#   ('CMG.csv', 5020)
#   ('UAL.csv', 5013)
#   ('TDG.csv', 4987)
#   ('MA.csv', 4937)
#   ('LDOS.csv', 4837)
#   ('FSLR.csv', 4814)
#   ('BR.csv', 4731)
#   ('SMCI.csv', 4726)
#   ('TMUS.csv', 4712)
#   ('DAL.csv', 4702)
#   ('PODD.csv', 4694)
#   ('TEL.csv', 4673)
#   ('BX.csv', 4667)
#   ('LULU.csv', 4643)
#   ('ULTA.csv', 4580)
#   ('MSCI.csv', 4565)
#   ('PM.csv', 4483)
#   ('V.csv', 4481)
#   ('AWK.csv', 4457)
#   ('KDP.csv', 4447)
#
# Cluster 8 | size=47
#   ('AVGO.csv', 4132)
#   ('VRSK.csv', 4089)
#   ('DG.csv', 4062)
#   ('FTNT.csv', 4059)
#   ('CHTR.csv', 4028)
#   ('GNRC.csv', 4002)
#   ('LYB.csv', 3950)
#   ('CBOE.csv', 3917)
#   ('TSLA.csv', 3907)
#   ('NXPI.csv', 3880)
#   ('GM.csv', 3807)
#   ('TRGP.csv', 3795)
#   ('CPAY.csv', 3789)
#   ('KMI.csv', 3749)
#   ('HCA.csv', 3731)
#   ('HII.csv', 3723)
#   ('MPC.csv', 3657)
#   ('XYL.csv', 3580)
#   ('APTV.csv', 3555)
#   ('EPAM.csv', 3500)
#   ('ENPH.csv', 3464)
#   ('PSX.csv', 3456)
#   ('AMCR.csv', 3433)
#   ('META.csv', 3430)
#   ('NOW.csv', 3401)
#   ('PANW.csv', 3387)
#   ('FANG.csv', 3328)
#   ('ABBV.csv', 3275)
#   ('NCLH.csv', 3263)
#   ('ZTS.csv', 3254)
#   ('IQV.csv', 3187)
#   ('NWS.csv', 3159)
#   ('NWSA.csv', 3159)
#   ('CDW.csv', 3153)
#   ('ALLE.csv', 3053)
#   ('HLT.csv', 3036)
#   ('PAYC.csv', 2952)
#   ('ANET.csv', 2916)
#   ('SYF.csv', 2878)
#   ('CZR.csv', 2842)
#   ('CFG.csv', 2840)
#   ('KEYS.csv', 2822)
#   ('QRVO.csv', 2771)
#   ('ETSY.csv', 2700)
#   ('KHC.csv', 2645)
#   ('PYPL.csv', 2645)
#   ('HPE.csv', 2571)
#
# Cluster 9 | size=22
#   ('FTV.csv', 2393)
#   ('HWM.csv', 2309)
#   ('LW.csv', 2302)
#   ('INVH.csv', 2247)
#   ('IR.csv', 2177)
#   ('VICI.csv', 2016)
#   ('DAY.csv', 1937)
#   ('MRNA.csv', 1781)
#   ('FOXA.csv', 1718)
#   ('FOX.csv', 1717)
#   ('DOW.csv', 1712)
#   ('UBER.csv', 1676)
#   ('CTVA.csv', 1666)
#   ('CARR.csv', 1460)
#   ('OTIS.csv', 1460)
#   ('ABNB.csv', 1275)
#   ('CEG.csv', 997)
#   ('GEHC.csv', 768)
#   ('KVUE.csv', 673)
#   ('VLTO.csv', 568)
#   ('SOLV.csv', 449)
#   ('GEV.csv', 448)

# %%
output_dir = "input_files"
# create if it does not exist
Path(output_dir).mkdir(parents=True, exist_ok=True)

for cluster_id in range(len(clusters)-1):
    print(f"Processing cluster {cluster_id}")
    dataframes_vol = []
    for filename, rows in clusters[cluster_id]:
        print(f"File: {filename}, Rows: {rows}")
        # make one single pandas dataframe contains the data from above stock IDs, the index is the data, the columns are the stock IDs
        stock_id = filename[:-4]  

        file_path = Path(data_directory) / filename
        df_vol = pd.read_csv(file_path, usecols=['Date', 'Adj Close', 'Volume'], parse_dates=['Date'])
        df_vol.set_index('Date', inplace=True)
        df_vol.rename(columns={'Adj Close': f"{stock_id}_price", 'Volume': f"{stock_id}_vol"}, inplace=True)
        dataframes_vol.append(df_vol)

    combined_df_vol = pd.concat(dataframes_vol, axis=1)
    combined_df_vol.fillna(method='ffill', inplace=True)
    combined_df_vol.fillna(method='bfill', inplace=True)
    log_returns_df_vol = np.log(combined_df_vol / (combined_df_vol.shift(1) + 1e-9 ) + 1e-9)
    # drop the first row
    #log_returns_df_vol = log_returns_df_vol.iloc[1:]
    log_returns_df_vol = log_returns_df_vol.dropna()  # Drop the first row with

    price_columns = [col for col in log_returns_df_vol.columns if col.endswith('_price')]
    volume_columns = [col for col in log_returns_df_vol.columns if col.endswith('_vol')]
    log_returns_df_vol = log_returns_df_vol[price_columns + volume_columns]
    # find out the earliest date in the dataframe
    start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
    log_returns_df_vol.to_csv(f"{output_dir}/stock_data_vol-cluster-{cluster_id}-startdate-{start_date}.csv")
# Out:
# Processing cluster 0
# File: AEP.csv, Rows: 16113
# File: BA.csv, Rows: 16113
# File: CAT.csv, Rows: 16113
# File: CNP.csv, Rows: 16113
# File: CVX.csv, Rows: 16113
# File: DIS.csv, Rows: 16113
# File: DTE.csv, Rows: 16113
# File: ED.csv, Rows: 16113
# File: GD.csv, Rows: 16113
# File: GE.csv, Rows: 16113
# File: HON.csv, Rows: 16113
# File: HPQ.csv, Rows: 16113
# File: IBM.csv, Rows: 16113
# File: IP.csv, Rows: 16113
# File: JNJ.csv, Rows: 16113
# File: KO.csv, Rows: 16113
# File: KR.csv, Rows: 16113
# File: MMM.csv, Rows: 16113
# File: MO.csv, Rows: 16113
# File: MRK.csv, Rows: 16113
# File: MSI.csv, Rows: 16113
# File: PG.csv, Rows: 16113
# File: XOM.csv, Rows: 16113
# File: LMT.csv, Rows: 16112
# File: RTX.csv, Rows: 16050
# File: MCD.csv, Rows: 14978
# /tmp/ipykernel_6643/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_6643/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 1
# File: AXP.csv, Rows: 13514
# File: BMY.csv, Rows: 13514
# File: DD.csv, Rows: 13514
# File: DE.csv, Rows: 13514
# File: EMR.csv, Rows: 13514
# File: ETN.csv, Rows: 13514
# File: ETR.csv, Rows: 13514
# File: F.csv, Rows: 13514
# File: HAL.csv, Rows: 13514
# File: LLY.csv, Rows: 13514
# File: PCG.csv, Rows: 13514
# File: PEP.csv, Rows: 13514
# File: PFE.csv, Rows: 13514
# File: UNH.csv, Rows: 10387
# File: BBY.csv, Rows: 10261
# File: DOC.csv, Rows: 10236
# File: ADSK.csv, Rows: 10211
# File: DVN.csv, Rows: 10196
# File: NVR.csv, Rows: 10196
# File: ROST.csv, Rows: 10183
# File: JKHY.csv, Rows: 10111
# File: MNST.csv, Rows: 10099
# File: ORCL.csv, Rows: 10035
# File: MSFT.csv, Rows: 10034
# File: TROW.csv, Rows: 10021
# File: COST.csv, Rows: 9953
# File: ADBE.csv, Rows: 9928
# File: FI.csv, Rows: 9898
# File: BKR.csv, Rows: 9765
# File: CDNS.csv, Rows: 9720
# File: TJX.csv, Rows: 9708
# File: FICO.csv, Rows: 9691
# File: CCL.csv, Rows: 9689
# File: FAST.csv, Rows: 9670
# File: SCHW.csv, Rows: 9648
# File: JCI.csv, Rows: 9644
# File: KEY.csv, Rows: 9616
# File: MOS.csv, Rows: 9561
# File: MGM.csv, Rows: 9494
# File: WM.csv, Rows: 9458
# /tmp/ipykernel_6643/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_6643/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 4
# File: TECH.csv, Rows: 9297
# File: IEX.csv, Rows: 9219
# File: GEN.csv, Rows: 9204
# File: EA.csv, Rows: 9143
# File: EOG.csv, Rows: 9133
# File: PTC.csv, Rows: 9087
# File: CTRA.csv, Rows: 9045
# File: CSCO.csv, Rows: 9039
# File: HOLX.csv, Rows: 9031
# File: LH.csv, Rows: 9011
# File: TRMB.csv, Rows: 8933
# File: AZO.csv, Rows: 8757
# File: REGN.csv, Rows: 8757
# File: IDXX.csv, Rows: 8700
# File: AES.csv, Rows: 8697
# File: VRTX.csv, Rows: 8678
# File: ZBRA.csv, Rows: 8662
# File: BIIB.csv, Rows: 8640
# File: ODFL.csv, Rows: 8613
# File: APH.csv, Rows: 8602
# File: KIM.csv, Rows: 8592
# File: QCOM.csv, Rows: 8578
# File: GILD.csv, Rows: 8552
# File: ROP.csv, Rows: 8536
# File: SNPS.csv, Rows: 8528
# File: STZ.csv, Rows: 8514
# File: MHK.csv, Rows: 8503
# File: BSX.csv, Rows: 8470
# File: STE.csv, Rows: 8462
# File: DHI.csv, Rows: 8458
# File: LIN.csv, Rows: 8450
# File: SBUX.csv, Rows: 8443
# File: MTCH.csv, Rows: 8301
# File: MS.csv, Rows: 8277
# File: INTU.csv, Rows: 8264
# File: MCHP.csv, Rows: 8259
# File: CB.csv, Rows: 8255
# File: ORLY.csv, Rows: 8235
# File: RCL.csv, Rows: 8232
# File: JBL.csv, Rows: 8229
# File: ALL.csv, Rows: 8207
# File: CPT.csv, Rows: 8173
# File: EQR.csv, Rows: 8158
# File: BWA.csv, Rows: 8157
# File: IT.csv, Rows: 8121
# File: DECK.csv, Rows: 8113
# File: REG.csv, Rows: 8103
# File: INCY.csv, Rows: 8099
# File: EMN.csv, Rows: 8072
# File: SPG.csv, Rows: 8072
# File: MAA.csv, Rows: 8040
# File: MLM.csv, Rows: 8026
# File: TSCO.csv, Rows: 8026
# File: ALB.csv, Rows: 8024
# File: AVB.csv, Rows: 8011
# File: CPRT.csv, Rows: 8007
# File: ESS.csv, Rows: 7952
# /tmp/ipykernel_6643/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel
# File: IQV.csv, Rows: 3187
# File: NWS.csv, Rows: 3159
# File: NWSA.csv, Rows: 3159
# File: CDW.csv, Rows: 3153
# File: ALLE.csv, Rows: 3053
# File: HLT.csv, Rows: 3036
# File: PAYC.csv, Rows: 2952
# File: ANET.csv, Rows: 2916
# File: SYF.csv, Rows: 2878
# File: CZR.csv, Rows: 2842
# File: CFG.csv, Rows: 2840
# File: KEYS.csv, Rows: 2822
# File: QRVO.csv, Rows: 2771
# File: ETSY.csv, Rows: 2700
# File: KHC.csv, Rows: 2645
# File: PYPL.csv, Rows: 2645
# File: HPE.csv, Rows: 2571
# /tmp/ipykernel_6643/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_6643/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)

# %%
from pathlib import Path
import pandas as pd

# to get a big table for all stocks
dataframes_vol = []

for cluster_id in range(len(clusters) - 1):

    # sort files in THIS cluster by row count (descending) BEFORE reading/appending
    for filename, rows in sorted(clusters[cluster_id], key=lambda x: x[1], reverse=True):
        print(f"File: {filename}, Rows: {rows}")

        stock_id = filename[:-4]
        file_path = Path(data_directory) / filename

        df_vol = pd.read_csv(
            file_path,
            usecols=["Date", "Adj Close", "Volume"],
            parse_dates=["Date"]
        )
        df_vol.set_index("Date", inplace=True)
        df_vol.rename(
            columns={"Adj Close": f"{stock_id}_price", "Volume": f"{stock_id}_vol"},
            inplace=True
        )
        dataframes_vol.append(df_vol)

    combined_df_vol = pd.concat(dataframes_vol, axis=1)

    price_columns = [col for col in combined_df_vol.columns if col.endswith('_price')]
    volume_columns = [col for col in combined_df_vol.columns if col.endswith('_vol')]

    combined_df_vol[price_columns] = (
        combined_df_vol[price_columns]
            .ffill()
    )

    combined_df_vol[volume_columns] = (
        combined_df_vol[volume_columns].fillna(0)
    )

    # add a column: how many source tables (stocks) have data on each row
    # (counts a stock as "present" if either its _price or _vol is non-NaN)
    price_vol = combined_df_vol.filter(like='_price')
    present_by_stock = (
        price_vol.notna()
        .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
        .any()
    )


    stocks_in_row = present_by_stock.sum(axis=1).astype("int32")
    combined_df_vol[price_columns] = (
        combined_df_vol[price_columns]
            .bfill()
    )

    log_returns_df_vol = np.log(combined_df_vol / (combined_df_vol.shift(1) + 1e-9 ) + 1e-9)
    # drop the first row
    #log_returns_df_vol = log_returns_df_vol.iloc[1:]
    log_returns_df_vol = log_returns_df_vol.dropna()  # Drop the first row with
    log_returns_df_vol = log_returns_df_vol[price_columns + volume_columns]
    # find out the earliest date in the dataframe
    start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
    log_returns_df_vol['stocks_in_row'] = stocks_in_row
    log_returns_df_vol.to_csv(f"stock_data_vol-all-in-one-startdate-{start_date}-stock-nbr.csv")
# Out:
# File: AEP.csv, Rows: 16113
# File: BA.csv, Rows: 16113
# File: CAT.csv, Rows: 16113
# File: CNP.csv, Rows: 16113
# File: CVX.csv, Rows: 16113
# File: DIS.csv, Rows: 16113
# File: DTE.csv, Rows: 16113
# File: ED.csv, Rows: 16113
# File: GD.csv, Rows: 16113
# File: AAPL.csv, Rows: 11360
# File: BRO.csv, Rows: 11319
# File: UHS.csv, Rows: 11217
# File: HD.csv, Rows: 11165
# File: BAX.csv, Rows: 11140
# File: COP.csv, Rows: 11095
# File: GLW.csv, Rows: 11095
# File: HUM.csv, Rows: 11095
# File: LHX.csv, Rows: 11095
# File: NOC.csv, Rows: 11095
# File: OXY.csv, Rows: 11095
# File: ROK.csv, Rows: 11095
# File: SLB.csv, Rows: 11095
# File: SO.csv, Rows: 11095
# File: WMB.csv, Rows: 11095
# File: VLO.csv, Rows: 11094
# File: CI.csv, Rows: 11033
# File: BBWI.csv, Rows: 11032
# File: NSC.csv, Rows: 10990
# File: COO.csv, Rows: 10827
# /tmp/ipykernel_6643/4019959411.py:47: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
# /tmp/ipykernel_6643/4019959411.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   log_returns_df_vol['stocks_in_row'] = stocks_in_row
# File: AMGN.csv, Rows: 10725
# File: RJF.csv, Rows: 10715
# File: CAH.csv, Rows: 10692
# File: CTAS.csv, Rows: 10681
# File: PAYX.csv, Rows: 10676
# File: BEN.csv, Rows: 10657
# File: AOS.csv, Rows: 10652
# File: T.csv, Rows: 10616
# File: VZ.csv, Rows: 10616
# File: JBHT.csv, Rows: 10615
# File: ATO.csv, Rows: 10591
# File: LRCX.csv, Rows: 10502
# File: MU.csv, Rows: 10483
# File: AJG.csv, Rows: 10470
# File: AME.csv, Rows: 10450
# File: SWKS.csv, Rows: 10415
# File: EXPD.csv, Rows: 10402
# File: UNH.csv, Rows: 10387
# File: BBY.csv, Rows: 10261
# File: DOC.csv, Rows: 10236
# File: ADSK.csv, Rows: 10211
# File: DVN.csv, Rows: 10196
# File: NVR.csv, Rows: 10196
# File: ROST.csv, Rows: 10183
# File: JKHY.csv, Rows: 10111
# File: MNST.csv, Rows: 10099
# File: ORCL.csv, Rows: 10035
# File: MSFT.csv, Rows: 10034
# File: TROW.csv, Rows: 10021
# File: COST.csv, Rows: 9953
# File: ADBE.csv, Rows: 9928
# File: FI.csv, Rows: 9898
# File: BKR.csv, Rows: 9765
# File: CDNS.csv, Rows: 9720
# File: TJX.csv, Rows: 9708
# File: FICO.csv, Rows: 9691
# File: CCL.csv, Rows: 9689
# File: FAST.csv, Rows: 9670
# File: SCHW.csv, Rows: 9648
# File: JCI.csv, Rows: 9644
# File: KEY.csv, Rows: 9616
# File: MOS.csv, Rows: 9561
# File: MGM.csv, Rows: 9494
# File: WM.csv, Rows: 9458
# /tmp/ipykernel_6643/4019959411.py:47: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
# /tmp/ipykernel_6643/4019959411.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   log_returns_df_vol['stocks_in_row'] = stocks_in_row
# File: TECH.csv, Rows: 9297
# File: IEX.csv, Rows: 9219
# File: GEN.csv, Rows: 9204
# File: EA.csv, Rows: 9143
# File: EOG.csv, Rows: 9133
# File: PTC.csv, Rows: 9087
# File: CTRA.csv, Rows: 9045
# File: CSCO.csv, Rows: 9039
# File: HOLX.csv, Rows: 9031
# File: LH.csv, Rows: 9011
# File: TRMB.csv, Rows: 8933
# File: AZO.csv, Rows: 8757
# File: REGN.csv, Rows: 8757
# File: IDXX.csv, Rows: 8700
# File: AES.csv, Rows: 8697
# File: VRTX.csv, Rows: 8678
# File: ZBRA.csv, Rows: 8662
# File: BIIB.csv, Rows: 8640
# File: ODFL.csv, Rows: 8613
# File: APH.csv, Rows: 8602
# File: KIM.csv, Rows: 8592
# File: QCOM.csv, Rows: 8578
# File: GILD.csv, Rows: 8552
# File: ROP.csv, Rows: 8536
# File: SNPS.csv, Rows: 8528
# File: STZ.csv, Rows: 8514
# File: MHK.csv, Rows: 8503
# File: BSX.csv, Rows: 8470
# File: STE.csv, Rows: 8462
# File: DHI.csv, Rows: 8458
# File: LIN.csv, Rows: 8450
# File: SBUX.csv, Rows: 8443
# File: MTCH.csv, Rows: 8301
# File: MS.csv, Rows: 8277
# File: INTU.csv, Rows: 8264
# File: MCHP.csv, Rows: 8259
# File: CB.csv, Rows: 8255
# File: ORLY.csv, Rows: 8235
# File: RCL.csv, Rows: 8232
# File: JBL.csv, Rows: 8229
# File: ALL.csv, Rows: 8207
# File: CPT.csv, Rows: 8173
# File: EQR.csv, Rows: 8158
# File: BWA.csv, Rows: 8157
# File: IT.csv, Rows: 8121
# File: DECK.csv, Rows: 8113
# File: REG.csv, Rows: 8103
# File: INCY.csv, Rows: 8099
# File: EMN.csv, Rows: 8072
# File: SPG.csv, Rows: 8072
# File: MAA.csv, Rows: 8040
# File: MLM.csv, Rows: 8026
# File: TSCO.csv, Rows: 8026
# File: ALB.csv, Rows: 8024
# File: AVB.csv, Rows: 8011
# File: CPRT.csv, Rows: 8007
# File: ESS.csv, Rows: 7952
# /tmp/ipykernel_6643/4019959411.py:47: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
# /tmp/ipykernel_6643/4019959411.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   log_returns_df_vol['stocks_in_row'] = stocks_in_row
# File: O.csv, Rows: 7859
# File: MCO.csv, Rows: 7850
# File: SJM.csv, Rows: 7850
# File: MCK.csv, Rows: 7842
# File: COF.csv, Rows: 7838
# File: DLTR.csv, Rows: 7763
# File: COR.csv, Rows: 7743
# File: DRI.csv, Rows: 7719
# File: RMD.csv, Rows: 7702
# File: WAB.csv, Rows: 7692
# File: FCX.csv, Rows: 7677
# File: IVZ.csv, Rows: 7643
# File: ACGL.csv, Rows: 7630
# File: EG.csv, Rows: 7617
# File: POOL.csv, Rows: 7609
# File: DVA.csv, Rows: 7597
# File: HSIC.csv, Rows: 7594
# File: EL.csv, Rows: 7584
# File: WAT.csv, Rows: 7584
# File: NTAP.csv, Rows: 7582
# File: HIG.csv, Rows: 7565
# File: IRM.csv, Rows: 7533
# File: FDS.csv, Rows: 7430
# File: STLD.csv, Rows: 7327
# File: DGX.csv, Rows: 7311
# File: KMX.csv, Rows: 7278
# File: TTWO.csv, Rows: 7230
# File: VTR.csv, Rows: 7216
# File: AMZN.csv, Rows: 7208
# File: ARE.csv, Rows: 7200
# File: RL.csv, Rows: 7189
# File: BXP.csv, Rows: 7185
# File: YUM.csv, Rows: 7122
# File: CHRW.csv, Rows: 7101
# File: FE.csv, Rows: 7084
# File: MTD.csv, Rows: 7080
# File: PLD.csv, Rows: 7075
# File: URI.csv, Rows: 7057
# File: AEE.csv, Rows: 7048
# File: VRSN.csv, Rows: 7029
# File: PWR.csv, Rows: 7020
# File: AMT.csv, Rows: 7010
# File: MAR.csv, Rows: 6994
# File: CTSH.csv, Rows: 6932
# File: SRE.csv, Rows: 6926
# File: CSGP.csv, Rows: 6924
# File: RSG.csv, Rows: 6924
# File: CCI.csv, Rows: 6891
# File: EBAY.csv, Rows: 6865
# /tmp/ipykernel_6643/4019959411.py:47: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
# /tmp/ipykernel_6643/4019959411.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   log_returns_df_vol['stocks_in_row'] = stocks_in_row
# File: NVDA.csv, Rows: 6783
# File: BKNG.csv, Rows: 6736
# File: GS.csv, Rows: 6713
# File: FFIV.csv, Rows: 6691
# File: SBAC.csv, Rows: 6683
# File: BLK.csv, Rows: 6608
# File: AKAM.csv, Rows: 6588
# File: UPS.csv, Rows: 6580
# File: A.csv, Rows: 6574
# File: TDY.csv, Rows: 6571
# File: PKG.csv, Rows: 6526
# File: EW.csv, Rows: 6486
# File: MET.csv, Rows: 6479
# File: ON.csv, Rows: 6461
# File: ISRG.csv, Rows: 6429
# File: CRL.csv, Rows: 6424
# File: ILMN.csv, Rows: 6400
# File: EQIX.csv, Rows: 6390
# File: TPR.csv, Rows: 6351
# File: GRMN.csv, Rows: 6307
# File: GPN.csv, Rows: 6283
# File: ALGN.csv, Rows: 6273
# File: WTW.csv, Rows: 6181
# File: MDLZ.csv, Rows: 6180
# File: AXON.csv, Rows: 6176
# File: FIS.csv, Rows: 6175
# File: ACN.csv, Rows: 6155
# File: ZBH.csv, Rows: 6151
# File: BG.csv, Rows: 6145
# File: PFG.csv, Rows: 6092
# File: ELV.csv, Rows: 6087
# File: CNC.csv, Rows: 6056
# File: PRU.csv, Rows: 6056
# File: NFLX.csv, Rows: 5946
# File: NDAQ.csv, Rows: 5920
# File: WYNN.csv, Rows: 5838
# File: CME.csv, Rows: 5809
# File: STX.csv, Rows: 5806
# /tmp/ipykernel_6643/4019959411.py:47: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   .groupby(lambda c: c.rsplit("_", 1)[0], axis=1)  # group columns by stock_id
# /tmp/ipykernel_6643/4019959411.py:65: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   log_returns_df_vol['stocks_in_row'] = stocks_in_row
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 66
#      64 start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
#      65 log_returns_df_vol['stocks_in_row'] = stocks_in_row
# ---> 66 log_returns_df_vol.to_csv(f"stock_data_vol-all-in-one-startdate-{start_date}-stock-nbr.csv")
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/io/formats/csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)    258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/io/formats/csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/io/formats/csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 slicer = slice(start_i, end_i)
#     318 df = self.obj.iloc[slicer]
# --> 320 res = df._get_values_for_csv(**self._number_format)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/frame.py:1414, in DataFrame._get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#    1404 def _get_values_for_csv(
#    1405     self,
#    1406     *,
#    (...)   1412 ) -> Self:
#    1413     # helper used by to_csv
# -> 1414     mgr = self._mgr.get_values_for_csv(
#    1415         float_format=float_format,
#    1416         date_format=date_format,
#    1417         decimal=decimal,
#    1418         na_rep=na_rep,
#    1419         quoting=quoting,
#    1420     )
#    1421     # error: Incompatible return value type (got "DataFrame", expected "Self")
#    1422     return self._constructor_from_mgr(mgr, axes=mgr.axes)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/internals/managers.py:485, in BaseBlockManager.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     478 def get_values_for_csv(
#     479     self, *, float_format, date_format, decimal, na_rep: str = "nan", quoting=None
#     480 ) -> Self:
#     481     """
#     482     Convert values to native types (strings / python objects) that are used
#     483     in formatting (repr / csv).
#     484     """
# --> 485     return self.apply(
#     486         "get_values_for_csv",
#     487         na_rep=na_rep,
#     488         quoting=quoting,
#     489         float_format=float_format,
#     490         date_format=date_format,
#     491         decimal=decimal,
#     492     )
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/internals/blocks.py:814, in Block.get_values_for_csv(self, float_format, date_format, decimal, na_rep, quoting)
#     805 """convert to our native types format"""
#     806 result = get_values_for_csv(
#     807     self.values,
#     808     na_rep=na_rep,
#    (...)    812     decimal=decimal,
#     813 )
# --> 814 return self.make_block(result)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/internals/blocks.py:292, in Block.make_block(self, values, placement, refs)
#     289 if self.is_extension:
#     290     values = ensure_block_shape(values, ndim=self.ndim)
# --> 292 return new_block(values, placement=placement, ndim=self.ndim, refs=refs)
#
# File /anaconda/envs/finance/lib/python3.11/site-packages/pandas/core/internals/blocks.py:2801, in new_block(values, placement, ndim, refs)
#    2789 def new_block(
#    2790     values,
#    2791     placement: BlockPlacement,
#    (...)   2798     # - check_ndim/ensure_block_shape already checked
#    2799     # - maybe_coerce_values already called/unnecessary
#    2800     klass = get_block_type(values.dtype)
# -> 2801     return klass(values, ndim=ndim, placement=placement, refs=refs)
#
# KeyboardInterrupt:

# %%
combined_df_vol.tail()
# Out:
#             HPQ_price     HPQ_vol    PG_price     PG_vol   IP_price  \
# Date
# 2025-10-20      27.66   7049700.0  151.960007  5601300.0  47.889999
# 2025-10-21      28.16   8330400.0  151.619995  6013400.0  47.680000
# 2025-10-22      27.66   8976800.0  152.199997  6394400.0  47.950001
# 2025-10-23      27.83  11798700.0  152.210007  8205400.0  49.099998
# 2025-10-24      27.66   8626235.0  152.490005  9647790.0  48.869999
#
#                IP_vol   DIS_price    DIS_vol  MRK_price     MRK_vol  ...  \
# Date                                                                 ...
# 2025-10-20  3292900.0  111.959999  8047500.0  86.320000   8611800.0  ...
# 2025-10-21  3301100.0  114.300003  8163200.0  87.620003   9852400.0  ...
# 2025-10-22  2716900.0  113.080002  7569200.0  87.610001  10926300.0  ...
# 2025-10-23  4571500.0  113.029999  6945400.0  87.180000   7687500.0  ...
# 2025-10-24  3862174.0  111.680000  6225963.0  87.489998   5503322.0  ...
#
#             CTEC.L_vol   HWM_price    HWM_vol   LW_price     LW_vol  \
# Date
# 2025-10-20   5181799.0  192.520004  1044900.0  65.669998  2489300.0
# 2025-10-21   8403771.0  197.179993  2022600.0  64.650002  2410800.0
# 2025-10-22  11076252.0  191.229996  2251000.0  64.750000  1441400.0
# 2025-10-23   4036832.0  200.100006  2300800.0  65.160004  1448200.0
# 2025-10-24   6243046.0  198.509995  2142300.0  66.379997  1528198.0
#
#             COWZ_price   COWZ_vol  INVH_price   INVH_vol  tables_in_row
# Date
# 2025-10-20   57.380001  2153200.0   28.600000  4073700.0            696
# 2025-10-21   57.880001  1698600.0   28.690001  4045700.0            696
# 2025-10-22   57.660000  1657100.0   28.889999  3504500.0            696
# 2025-10-23   57.939999  1833500.0   28.910000  2626300.0            696
# 2025-10-24   57.980000  1874400.0   28.870001  4100900.0            696
#
# [5 rows x 1393 columns]

# %%
len(combined_df_vol.columns)
# Out:
# 1393

# %%
# to get a big table for all stocks
dataframes_vol = []
for cluster_id in range(len(clusters)-1):
   
    for filename, rows in clusters[cluster_id]:
        print(f"File: {filename}, Rows: {rows}")
        # make one single pandas dataframe contains the data from above stock IDs, the index is the data, the columns are the stock IDs
        stock_id = filename[:-4]  

        file_path = Path(data_directory) / filename
        df_vol = pd.read_csv(file_path, usecols=['Date', 'Adj Close', 'Volume'], parse_dates=['Date'])
        df_vol.set_index('Date', inplace=True)
        df_vol.rename(columns={'Adj Close': f"{stock_id}_price", 'Volume': f"{stock_id}_vol"}, inplace=True)
        dataframes_vol.append(df_vol)

combined_df_vol = pd.concat(dataframes_vol, axis=1)

price_columns = [col for col in combined_df_vol.columns if col.endswith('_price')]
volume_columns = [col for col in combined_df_vol.columns if col.endswith('_vol')]

combined_df_vol[price_columns] = (
    combined_df_vol[price_columns]
        .ffill()
        .bfill()
)

combined_df_vol[volume_columns] = (
    combined_df_vol[volume_columns].fillna(0)
)

log_returns_df_vol = np.log(combined_df_vol / (combined_df_vol.shift(1) + 1e-9 ) + 1e-9)
# drop the first row
#log_returns_df_vol = log_returns_df_vol.iloc[1:]
log_returns_df_vol = log_returns_df_vol.dropna()  # Drop the first row with

price_columns = [col for col in log_returns_df_vol.columns if col.endswith('_price')]
volume_columns = [col for col in log_returns_df_vol.columns if col.endswith('_vol')]
log_returns_df_vol = log_returns_df_vol[price_columns + volume_columns]
# find out the earliest date in the dataframe
start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
log_returns_df_vol.to_csv(f"stock_data_vol-all-in-one-startdate-{start_date}.csv")
# Out:
# File: HPQ.csv, Rows: 16062
# File: PG.csv, Rows: 16062
# File: IP.csv, Rows: 16062
# File: DIS.csv, Rows: 16062
# File: MRK.csv, Rows: 16062
# File: HON.csv, Rows: 16062
# File: CAT.csv, Rows: 16062
# File: GE.csv, Rows: 16062
# File: IBM.csv, Rows: 16062
# File: GD.csv, Rows: 16062
# File: JNJ.csv, Rows: 16062
# File: ED.csv, Rows: 16062
# File: DTE.csv, Rows: 16062
# File: XOM.csv, Rows: 16062
# File: MMM.csv, Rows: 16062
# File: CVX.csv, Rows: 16062
# File: BA.csv, Rows: 16062
# File: KO.csv, Rows: 16062
# File: MSI.csv, Rows: 16062
# File: CNP.csv, Rows: 16062
# File: MO.csv, Rows: 16062
# File: KR.csv, Rows: 16062
# File: AEP.csv, Rows: 16062
# File: LMT.csv, Rows: 16061
# File: RTX.csv, Rows: 15999
# File: MCD.csv, Rows: 14927
# File: FCIT.L.csv, Rows: 14660
# File: SMT.L.csv, Rows: 14660
# File: F.csv, Rows: 13463
# File: LLY.csv, Rows: 13463
# File: HAL.csv, Rows: 13463
# File: PCG.csv, Rows: 13463
# File: AXP.csv, Rows: 13463
# File: EMR.csv, Rows: 13463
# File: PFE.csv, Rows: 13463
# File: ML.PA.csv, Rows: 6635
# File: CA.PA.csv, Rows: 6635
# File: SBAC.csv, Rows: 6632
# File: EOAN.DE.csv, Rows: 6600
# File: ATCO-B.ST.csv, Rows: 6577
# File: CPG.L.csv, Rows: 6571
# File: DCC.L.csv, Rows: 6571
# File: BLK.csv, Rows: 6557
# File: ERIC-B.ST.csv, Rows: 6554
# File: AZN.ST.csv, Rows: 6554
# File: SKA-B.ST.csv, Rows: 6554
# File: ASSA-B.ST.csv, Rows: 6554
# File: SHB-A.ST.csv, Rows: 6554
# File: HEXA-B.ST.csv, Rows: 6554
# File: SWED-A.ST.csv, Rows: 6554
# File: GETI-B.ST.csv, Rows: 6554
# File: ELUX-B.ST.csv, Rows: 6554
# File: NDA-SE.ST.csv, Rows: 6554
# File: SKF-B.ST.csv, Rows: 6554
# File: ALIV-SDB.ST.csv, Rows: 6554
# File: TEL2-B.ST.csv, Rows: 6554
# File: ATCO-A.ST.csv, Rows: 6554
# File: SAND.ST.csv, Rows: 6554
# File: INVE-B.ST.csv, Rows: 6554
# File: VOLV-B.ST.csv, Rows: 6554
# File: HM-B.ST.csv, Rows: 6554
# File: SEB-A.ST.csv, Rows: 6554
# File: SCA-B.ST.csv, Rows: 6554
# File: KINV-B.ST.csv, Rows: 6554
# File: IFX.DE.csv, Rows: 6550
# File: AKAM.csv, Rows: 6537
# File: UPS.csv, Rows: 6529
# File: A.csv, Rows: 6523
# File: TDY.csv, Rows: 6520
# File: PUB.PA.csv, Rows: 6449
# File: TELIA.ST.csv, Rows: 6438
# File: EW.csv, Rows: 6435
# File: MET.csv, Rows: 6428
# File: ON.csv, Rows: 6410
# File: IWB.csv, Rows: 6397
# File: IYW.csv, Rows: 6397
# File: IVV.csv, Rows: 6397
# File: IVW.csv, Rows: 6392
# File: IVE.csv, Rows: 6392
# File: IJH.csv, Rows: 6392
# File: IJR.csv, Rows: 6392
# File: IWM.csv, Rows: 6392
# File: IWF.csv, Rows: 6392
# File: IWD.csv, Rows: 6392
# File: HNR1.DE.csv, Rows: 6390
# File: SMH.csv, Rows: 6387
# File: ISRG.csv, Rows: 6378
# File: CRL.csv, Rows: 6373
# File: MRVL.csv, Rows: 6368
# File: IUSG.csv, Rows: 6349
# File: ILMN.csv, Rows: 6349
# File: EZJ.L.csv, Rows: 6345
# File: IUSV.csv, Rows: 6344
# File: EQIX.csv, Rows: 6339
# File: DHL.DE.csv, Rows: 6320
# File: DB1.DE.csv, Rows: 6315
# File: SPYG.csv, Rows: 6304
# File: SPYV.csv, Rows: 6304
# File: TPR.csv, Rows: 6300
# File: GPN.csv, Rows: 6232
# File: ALGN.csv, Rows: 6222
# File: ABB.ST.csv, Rows: 6203
# File: STLAP.PA.csv, Rows: 6200
# File: STMPA.PA.csv, Rows: 6200
# File: AIR.PA.csv, Rows: 6200
# File: LSEG.L.csv, Rows: 6168
# File: WTW.csv, Rows: 6130
# File: MDLZ.csv, Rows: 6129
# File: VTI.csv, Rows: 6127
# File: ACA.PA.csv, Rows: 6126
# File: AXON.csv, Rows: 6125
# File: FIS.csv, Rows: 6124
# File: ACN.csv, Rows: 6104
# File: ZBH.csv, Rows: 6100
# File: BG.csv, Rows: 6094
# File: IWR.csv, Rows: 6077
# File: EFA.csv, Rows: 6077
# File: PFG.csv, Rows: 6041
# File: ITRK.L.csv, Rows: 5948
# File: BRBY.L.csv, Rows: 5913
# File: FRAS.L.csv, Rows: 5900
# File: NFLX.csv, Rows: 5895
# File: NDAQ.csv, Rows: 5869
# File: TLT.csv, Rows: 5849
# File: SHY.csv, Rows: 5849
# File: IEF.csv, Rows: 5849
# File: LQD.csv, Rows: 5849
# File: BEZ.L.csv, Rows: 5826
# File: MRO.L.csv, Rows: 5576
# File: AGG.csv, Rows: 5555
# File: LKQ.csv, Rows: 5550
# File: DVY.csv, Rows: 5526
# File: NRG.csv, Rows: 5510
# File: ITOT.csv, Rows: 5475
# File: VUG.csv, Rows: 5470
# File: VTV.csv, Rows: 5470
# File: VO.csv, Rows: 5470
# File: VHT.csv, Rows: 5470
# File: VGT.csv, Rows: 5470
# File: VV.csv, Rows: 5470
# File: VB.csv, Rows: 5470
# File: VBR.csv, Rows: 5470
# File: AIZ.csv, Rows: 5466
# File: CBRE.csv, Rows: 5379
# File: CRM.csv, Rows: 5371
# File: DPZ.csv, Rows: 5358
# File: ADM.L.csv, Rows: 5339
# File: EXR.csv, Rows: 5334
# File: GOOGL.csv, Rows: 5331
# File: GOOG.csv, Rows: 5331
# File: VNQ.csv, Rows: 5303
# File: DLR.csv, Rows: 5281
# File: MKTX.csv, Rows: 5276
# File: ENT.L.csv, Rows: 5276
# File: GLD.csv, Rows: 5267
# File: MPWR.csv, Rows: 5266
# File: LVS.csv, Rows: 5249
# File: CE.csv, Rows: 5224
# File: IAU.csv, Rows: 5219
# File: VWO.csv, Rows: 5191
# File: VGK.csv, Rows: 5191
# File: MT.AS.csv, Rows: 5190
# File: MTX.DE.csv, Rows: 5185
# File: ALO.PA.csv, Rows: 5178
# File: DXCM.csv, Rows: 5167
# File: BLDR.csv, Rows: 5115
# File: WBD.csv, Rows: 5108
# File: EXPE.csv, Rows: 5099
# File: EFV.csv, Rows: 5088
# File: CF.csv, Rows: 5084
# File: AMP.csv, Rows: 5060
# File: AAL.csv, Rows: 5052
# File: HIK.L.csv, Rows: 5051
# File: SDY.csv, Rows: 5017
# File: SPLG.csv, Rows: 5017
# File: ICE.csv, Rows: 5016
# File: LR.PA.csv, Rows: 5001
# File: LYV.csv, Rows: 4992
# File: CMG.csv, Rows: 4969
# File: UAL.csv, Rows: 4962
# File: RMV.L.csv, Rows: 4959
# File: TDG.csv, Rows: 4936
# File: LDOS.csv, Rows: 4786
# File: VYM.csv, Rows: 4764
# File: FSLR.csv, Rows: 4763
# File: IGSB.csv, Rows: 4728
# File: SHV.csv, Rows: 4728
# File: SKG.L.csv, Rows: 4703
# File: VEU.csv, Rows: 4690
# File: MBB.csv, Rows: 4684
# File: BR.csv, Rows: 4680
# File: SMCI.csv, Rows: 4675
# File: MRK.DE.csv, Rows: 6996
# File: DIA.csv, Rows: 6986
# File: BEI.DE.csv, Rows: 6978
# File: QIA.DE.csv, Rows: 6978
# File: VRSN.csv, Rows: 6978
# File: VOW3.DE.csv, Rows: 6978
# File: HEI.DE.csv, Rows: 6975
# File: PWR.csv, Rows: 6969
# File: RHM.DE.csv, Rows: 6968
# File: AMT.csv, Rows: 6959
# File: FLTR.L.csv, Rows: 6945
# File: MAR.csv, Rows: 6943
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 21
# File: FRE.DE.csv, Rows: 6900
# File: AIR.DE.csv, Rows: 6899
# File: MSTR.csv, Rows: 6887
# File: CTSH.csv, Rows: 6881
# File: SRE.csv, Rows: 6875
# File: CSGP.csv, Rows: 6873
# File: RSG.csv, Rows: 6873
# File: INF.L.csv, Rows: 6841
# File: CCI.csv, Rows: 6840
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 22
# File: SRT3.DE.csv, Rows: 6778
# File: XLV.csv, Rows: 6752
# File: XLY.csv, Rows: 6752
# File: XLE.csv, Rows: 6752
# File: XLI.csv, Rows: 6752
# File: XLF.csv, Rows: 6752
# File: XLK.csv, Rows: 6752
# File: NVDA.csv, Rows: 6732
# File: AAL.L.csv, Rows: 6732
# File: UTG.L.csv, Rows: 6726
# File: QQQ.csv, Rows: 6700
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 23
# File: GS.csv, Rows: 6662
# File: FFIV.csv, Rows: 6640
# File: RMS.PA.csv, Rows: 6635
# File: RI.PA.csv, Rows: 6635
# File: SGO.PA.csv, Rows: 6635
# File: SU.PA.csv, Rows: 6635
# File: SAN.PA.csv, Rows: 6635
# File: DG.PA.csv, Rows: 6635
# File: DSY.PA.csv, Rows: 6635
# File: CAP.PA.csv, Rows: 6635
# File: KER.PA.csv, Rows: 6635
# File: RNO.PA.csv, Rows: 6635
# File: GLE.PA.csv, Rows: 6635
# File: MC.PA.csv, Rows: 6635
# File: ENGI.PA.csv, Rows: 6635
# File: ORA.PA.csv, Rows: 6635
# File: EL.PA.csv, Rows: 6635
# File: SAF.PA.csv, Rows: 6635
# File: OR.PA.csv, Rows: 6635
# File: HO.PA.csv, Rows: 6635
# File: TTE.PA.csv, Rows: 6635
# File: AI.PA.csv, Rows: 6635
# File: ML.PA.csv, Rows: 6635
# File: CA.PA.csv, Rows: 6635
# File: SBAC.csv, Rows: 6632
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 24
# File: EOAN.DE.csv, Rows: 6600
# File: ATCO-B.ST.csv, Rows: 6577
# File: CPG.L.csv, Rows: 6571
# File: DCC.L.csv, Rows: 6571
# File: BLK.csv, Rows: 6557
# File: ERIC-B.ST.csv, Rows: 6554
# File: AZN.ST.csv, Rows: 6554
# File: SKA-B.ST.csv, Rows: 6554
# File: ASSA-B.ST.csv, Rows: 6554
# File: SHB-A.ST.csv, Rows: 6554
# File: HEXA-B.ST.csv, Rows: 6554
# File: SWED-A.ST.csv, Rows: 6554
# File: GETI-B.ST.csv, Rows: 6554
# File: ELUX-B.ST.csv, Rows: 6554
# File: NDA-SE.ST.csv, Rows: 6554
# File: SKF-B.ST.csv, Rows: 6554
# File: ALIV-SDB.ST.csv, Rows: 6554
# File: TEL2-B.ST.csv, Rows: 6554
# File: ATCO-A.ST.csv, Rows: 6554
# File: SAND.ST.csv, Rows: 6554
# File: INVE-B.ST.csv, Rows: 6554
# File: VOLV-B.ST.csv, Rows: 6554
# File: HM-B.ST.csv, Rows: 6554
# File: SEB-A.ST.csv, Rows: 6554
# File: SCA-B.ST.csv, Rows: 6554
# File: KINV-B.ST.csv, Rows: 6554
# File: IFX.DE.csv, Rows: 6550
# File: AKAM.csv, Rows: 6537
# File: UPS.csv, Rows: 6529
# File: A.csv, Rows: 6523
# File: TDY.csv, Rows: 6520
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 25
# File: PUB.PA.csv, Rows: 6449
# File: TELIA.ST.csv, Rows: 6438
# File: EW.csv, Rows: 6435
# File: MET.csv, Rows: 6428
# File: ON.csv, Rows: 6410
# File: IWB.csv, Rows: 6397
# File: IYW.csv, Rows: 6397
# File: IVV.csv, Rows: 6397
# File: IVW.csv, Rows: 6392
# File: IVE.csv, Rows: 6392
# File: IJH.csv, Rows: 6392
# File: IJR.csv, Rows: 6392
# File: IWM.csv, Rows: 6392
# File: IWF.csv, Rows: 6392
# File: IWD.csv, Rows: 6392
# File: HNR1.DE.csv, Rows: 6390
# File: SMH.csv, Rows: 6387
# File: ISRG.csv, Rows: 6378
# File: CRL.csv, Rows: 6373
# File: MRVL.csv, Rows: 6368
# File: IUSG.csv, Rows: 6349
# File: ILMN.csv, Rows: 6349
# File: EZJ.L.csv, Rows: 6345
# File: IUSV.csv, Rows: 6344
# File: EQIX.csv, Rows: 6339
# File: DHL.DE.csv, Rows: 6320
# File: DB1.DE.csv, Rows: 6315
# File: SPYG.csv, Rows: 6304
# File: SPYV.csv, Rows: 6304
# File: TPR.csv, Rows: 6300
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 26
# File: GPN.csv, Rows: 6232
# File: ALGN.csv, Rows: 6222
# File: ABB.ST.csv, Rows: 6203
# File: STLAP.PA.csv, Rows: 6200
# File: STMPA.PA.csv, Rows: 6200
# File: AIR.PA.csv, Rows: 6200
# Processing cluster 27
# File: LSEG.L.csv, Rows: 6168
# File: WTW.csv, Rows: 6130
# File: MDLZ.csv, Rows: 6129
# File: VTI.csv, Rows: 6127
# File: ACA.PA.csv, Rows: 6126
# File: AXON.csv, Rows: 6125
# File: FIS.csv, Rows: 6124
# File: ACN.csv, Rows: 6104
# File: ZBH.csv, Rows: 6100
# File: BG.csv, Rows: 6094
# File: IWR.csv, Rows: 6077
# File: EFA.csv, Rows: 6077
# File: PFG.csv, Rows: 6041
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /home/ken/.pyenv/versions/myenv/lib/python3.11/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Processing cluster 28
# File: ITRK.L.csv, Rows: 5948
# File: BRBY.L.csv, Rows: 5913
# File: FRAS.L.csv, Rows: 5900
# File: NFLX.csv, Rows: 5895
# File: NDAQ.csv, Rows: 5869
# File: TLT.csv, Rows: 5849
# File: SHY.csv, Rows: 5849
# File: IEF.csv, Rows: 5849
# File: LQD.csv, Rows: 5849
# File: BEZ.L.csv, Rows: 5826
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 29
# File: MRO.L.csv, Rows: 5576
# File: AGG.csv, Rows: 5555
# File: LKQ.csv, Rows: 5550
# File: DVY.csv, Rows: 5526
# File: NRG.csv, Rows: 5510
# File: ITOT.csv, Rows: 5475
# File: VUG.csv, Rows: 5470
# File: VTV.csv, Rows: 5470
# File: VO.csv, Rows: 5470
# File: VHT.csv, Rows: 5470
# File: VGT.csv, Rows: 5470
# File: VV.csv, Rows: 5470
# File: VB.csv, Rows: 5470
# File: VBR.csv, Rows: 5470
# File: AIZ.csv, Rows: 5466
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 30
# File: CBRE.csv, Rows: 5379
# File: CRM.csv, Rows: 5371
# File: DPZ.csv, Rows: 5358
# File: ADM.L.csv, Rows: 5339
# File: EXR.csv, Rows: 5334
# File: GOOGL.csv, Rows: 5331
# File: GOOG.csv, Rows: 5331
# File: VNQ.csv, Rows: 5303
# File: DLR.csv, Rows: 5281
# File: MKTX.csv, Rows: 5276
# File: ENT.L.csv, Rows: 5276
# File: GLD.csv, Rows: 5267
# File: MPWR.csv, Rows: 5266
# File: LVS.csv, Rows: 5249
# File: CE.csv, Rows: 5224
# File: IAU.csv, Rows: 5219
# File: VWO.csv, Rows: 5191
# File: VGK.csv, Rows: 5191
# File: MT.AS.csv, Rows: 5190
# File: MTX.DE.csv, Rows: 5185
# File: ALO.PA.csv, Rows: 5178
# File: DXCM.csv, Rows: 5167
# File: BLDR.csv, Rows: 5115
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 31
# File: WBD.csv, Rows: 5108
# File: EXPE.csv, Rows: 5099
# File: EFV.csv, Rows: 5088
# File: CF.csv, Rows: 5084
# File: AMP.csv, Rows: 5060
# File: AAL.csv, Rows: 5052
# File: HIK.L.csv, Rows: 5051
# File: SDY.csv, Rows: 5017
# File: SPLG.csv, Rows: 5017
# File: ICE.csv, Rows: 5016
# File: LR.PA.csv, Rows: 5001
# File: LYV.csv, Rows: 4992
# File: CMG.csv, Rows: 4969
# File: UAL.csv, Rows: 4962
# File: RMV.L.csv, Rows: 4959
# File: TDG.csv, Rows: 4936
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 32
# File: LDOS.csv, Rows: 4786
# File: VYM.csv, Rows: 4764
# File: FSLR.csv, Rows: 4763
# File: IGSB.csv, Rows: 4728
# File: SHV.csv, Rows: 4728
# File: SKG.L.csv, Rows: 4703
# File: VEU.csv, Rows: 4690
# File: MBB.csv, Rows: 4684
# File: BR.csv, Rows: 4680
# File: SMCI.csv, Rows: 4675
# File: BND.csv, Rows: 4668
# File: BIV.csv, Rows: 4668
# File: BSV.csv, Rows: 4668
# File: TMUS.csv, Rows: 4661
# File: SPDW.csv, Rows: 4656
# File: DAL.csv, Rows: 4651
# File: PODD.csv, Rows: 4643
# File: BIL.csv, Rows: 4633
# File: MNDI.L.csv, Rows: 4631
# File: TEL.csv, Rows: 4622
# File: BX.csv, Rows: 4616
# File: VEA.csv, Rows: 4593
# File: LULU.csv, Rows: 4592
# File: MELI.csv, Rows: 4582
# File: MUB.csv, Rows: 4562
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 33
# File: ULTA.csv, Rows: 4529
# File: MGK.csv, Rows: 4486
# File: PM.csv, Rows: 4432
# File: V.csv, Rows: 4430
# File: ACWI.csv, Rows: 4424
# File: FRES.L.csv, Rows: 4413
# File: AWK.csv, Rows: 4406
# File: KDP.csv, Rows: 4396
# Processing cluster 34
# File: VRSK.csv, Rows: 4038
# File: PHNX.L.csv, Rows: 4026
# File: SCHX.csv, Rows: 4019
# File: SCHF.csv, Rows: 4019
# File: SCHB.csv, Rows: 4019
# File: DG.csv, Rows: 4011
# File: FTNT.csv, Rows: 4008
# File: VCIT.csv, Rows: 4005
# File: VGSH.csv, Rows: 4005
# File: VCSH.csv, Rows: 4005
# File: VGIT.csv, Rows: 4005
# File: SCHG.csv, Rows: 3978
# File: CHTR.csv, Rows: 3977
# File: BNR.DE.csv, Rows: 3960
# File: TQQQ.csv, Rows: 3951
# File: GNRC.csv, Rows: 3951
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 35
# File: LYB.csv, Rows: 3899
# File: OCDO.L.csv, Rows: 3857
# File: TSLA.csv, Rows: 3856
# File: NXPI.csv, Rows: 3829
# File: VOO.csv, Rows: 3806
# File: GM.csv, Rows: 3756
# File: VXUS.csv, Rows: 3708
# File: KMI.csv, Rows: 3698
# Processing cluster 36
# File: GOVT.csv, Rows: 3438
# File: ENPH.csv, Rows: 3413
# File: PSX.csv, Rows: 3405
# File: AMCR.csv, Rows: 3382
# File: META.csv, Rows: 3379
# File: PANW.csv, Rows: 3336
# Processing cluster 37
# File: FANG.csv, Rows: 3277
# File: WDAY.csv, Rows: 3277
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: IEFA.csv, Rows: 3269
# File: IXUS.csv, Rows: 3269
# File: IEMG.csv, Rows: 3269
# File: ABBV.csv, Rows: 3224
# Processing cluster 38
# File: NCLH.csv, Rows: 3212
# File: CCH.L.csv, Rows: 3158
# File: IQV.csv, Rows: 3136
# File: VNA.DE.csv, Rows: 3122
# File: BNDX.csv, Rows: 3119
# File: NWS.csv, Rows: 3108
# File: NWSA.csv, Rows: 3108
# File: CDW.csv, Rows: 3102
# File: QUAL.csv, Rows: 3088
# Processing cluster 39
# File: WLN.PA.csv, Rows: 2902
# File: PAYC.csv, Rows: 2901
# File: BME.L.csv, Rows: 2874
# File: ANET.csv, Rows: 2865
# File: DGRO.csv, Rows: 2861
# File: IUSB.csv, Rows: 2861
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: SYF.csv, Rows: 2827
# File: ZAL.DE.csv, Rows: 2812
# File: CZR.csv, Rows: 2791
# File: CFG.csv, Rows: 2789
# File: KEYS.csv, Rows: 2771
# File: QRVO.csv, Rows: 2720
# Processing cluster 40
# File: ETSY.csv, Rows: 2649
# File: SHOP.csv, Rows: 2625
# File: PYPL.csv, Rows: 2594
# File: KHC.csv, Rows: 2594
# File: 1COV.DE.csv, Rows: 2558
# File: VTEB.csv, Rows: 2558
# File: SINCH.ST.csv, Rows: 2528
# Processing cluster 41
# File: FTV.csv, Rows: 2342
# File: TTD.csv, Rows: 2287
# File: CTEC.L.csv, Rows: 2272
# File: HWM.csv, Rows: 2258
# File: LW.csv, Rows: 2251
# File: COWZ.csv, Rows: 2222
# File: INVH.csv, Rows: 2196
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
