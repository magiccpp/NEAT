# %%
from pathlib import Path
import pandas as pd
import numpy as np

def count_csv_rows(file_path, has_header=True):
    """
    Counts the number of rows in a CSV file.
    
    Parameters:
    - file_path (Path): The path to the CSV file.
    - has_header (bool): Whether the CSV file has a header row.
    
    Returns:
    - int: The number of data rows in the CSV file.
    """
    with file_path.open('r', encoding='utf-8') as file:
        row_count = sum(1 for _ in file)
    return row_count - 1 if has_header else row_count

def enumerate_and_sort_csv(datadir, has_header=True):
    """
    Enumerates CSV files in the given directory, counts their rows, and sorts them.
    
    Parameters:
    - datadir (str or Path): The directory containing CSV files.
    - has_header (bool): Whether the CSV files have header rows.
    
    Returns:
    - List of tuples: Each tuple contains (file_name, row_count), sorted by row_count ascending.
    """
    datadir = Path(datadir)
    if not datadir.is_dir():
        raise ValueError(f"The path {datadir} is not a valid directory.")
    
    # Find all CSV files in the directory
    csv_files = list(datadir.glob('*.csv'))
    
    if not csv_files:
        print("No CSV files found in the specified directory.")
        return []
    
    file_row_counts = []
    
    for file in csv_files:
        try:
            rows = count_csv_rows(file, has_header=has_header)
            file_row_counts.append((file.name, rows))
        except Exception as e:
            print(f"Error processing {file.name}: {e}")
    
    # Sort the list of tuples based on row_count (ascending order)
    sorted_files = sorted(file_row_counts, key=lambda x: x[1])
    
    return sorted_files

# %%
# Specify the directory containing CSV files
data_directory = 'data/prices'  # Replace with your directory path

# Enumerate and sort CSV files
sorted_csv_files = enumerate_and_sort_csv(data_directory, has_header=True)

if sorted_csv_files:
    print("\nCSV files sorted by number of rows (ascending):")
    for filename, count in sorted_csv_files:
        print(f"{filename}: {count} rows")
# Out:
# CSV files sorted by number of rows (ascending):
# INVH.csv: 2196 rows
# COWZ.csv: 2222 rows
# LW.csv: 2251 rows
# HWM.csv: 2258 rows
# CTEC.L.csv: 2272 rows
# TTD.csv: 2287 rows
# FTV.csv: 2342 rows
# TEAM.csv: 2484 rows
# HPE.csv: 2520 rows
# SINCH.ST.csv: 2528 rows
# 1COV.DE.csv: 2558 rows
# VTEB.csv: 2558 rows
# PYPL.csv: 2594 rows
# KHC.csv: 2594 rows
# SHOP.csv: 2625 rows
# ETSY.csv: 2649 rows
# EVO.ST.csv: 2667 rows
# AUTO.L.csv: 2679 rows
# QRVO.csv: 2720 rows
# KEYS.csv: 2771 rows
# CFG.csv: 2789 rows
# CZR.csv: 2791 rows
# ZAL.DE.csv: 2812 rows
# SYF.csv: 2827 rows
# DGRO.csv: 2861 rows
# IUSB.csv: 2861 rows
# ANET.csv: 2865 rows
# BME.L.csv: 2874 rows
# PAYC.csv: 2901 rows
# WLN.PA.csv: 2902 rows
# HLT.csv: 2985 rows
# ALLE.csv: 3002 rows
# QUAL.csv: 3088 rows
# CDW.csv: 3102 rows
# NWS.csv: 3108 rows
# NWSA.csv: 3108 rows
# BNDX.csv: 3119 rows
# VNA.DE.csv: 3122 rows
# IQV.csv: 3136 rows
# CCH.L.csv: 3158 rows
# ZTS.csv: 3203 rows
# NCLH.csv: 3212 rows
# ABBV.csv: 3224 rows
# IEFA.csv: 3269 rows
# IXUS.csv: 3269 rows
# IEMG.csv: 3269 rows
# FANG.csv: 3277 rows
# WDAY.csv: 3277 rows
# PANW.csv: 3336 rows
# NOW.csv: 3350 rows
# META.csv: 3379 rows
# AMCR.csv: 3382 rows
# PSX.csv: 3405 rows
# ENPH.csv: 3413 rows
# GOVT.csv: 3438 rows
# EPAM.csv: 3449 rows
# APTV.csv: 3504 rows
# SCHD.csv: 3524 rows
# USMV.csv: 3524 rows
# XYL.csv: 3529 rows
# MPC.csv: 3606 rows
# GLEN.L.csv: 3646 rows
# HII.csv: 3672 rows
# HCA.csv: 3680 rows
# KMI.csv: 3698 rows
# VXUS.csv: 3708 rows
# CPAY.csv: 3738 rows
# TRGP.csv: 3744 rows
# GM.csv: 3756 rows
# VONG.csv: 3797 rows
# VOO.csv: 3806 rows
# NXPI.csv: 3829 rows
# TSLA.csv: 3856 rows
# OCDO.L.csv: 3857 rows
# CBOE.csv: 3866 rows
# LYB.csv: 3899 rows
# EDEN.PA.csv: 3922 rows
# TQQQ.csv: 3951 rows
# GNRC.csv: 3951 rows
# BNR.DE.csv: 3960 rows
# CHTR.csv: 3977 rows
# SCHG.csv: 3978 rows
# VCIT.csv: 4005 rows
# VGSH.csv: 4005 rows
# VCSH.csv: 4005 rows
# VGIT.csv: 4005 rows
# FTNT.csv: 4008 rows
# DG.csv: 4011 rows
# SCHX.csv: 4019 rows
# SCHF.csv: 4019 rows
# SCHB.csv: 4019 rows
# PHNX.L.csv: 4026 rows
# VRSK.csv: 4038 rows
# AVGO.csv: 4081 rows
# PAH3.DE.csv: 4256 rows
# VT.csv: 4361 rows
# KDP.csv: 4396 rows
# AWK.csv: 4406 rows
# FRES.L.csv: 4413 rows
# ACWI.csv: 4424 rows
# V.csv: 4430 rows
# PM.csv: 4432 rows
# MGK.csv: 4486 rows
# MSCI.csv: 4514 rows
# ULTA.csv: 4529 rows
# MUB.csv: 4562 rows
# MELI.csv: 4582 rows
# LULU.csv: 4592 rows
# VEA.csv: 4593 rows
# BX.csv: 4616 rows
# TEL.csv: 4622 rows
# MNDI.L.csv: 4631 rows
# BIL.csv: 4633 rows
# PODD.csv: 4643 rows
# DAL.csv: 4651 rows
# SPDW.csv: 4656 rows
# TMUS.csv: 4661 rows
# BND.csv: 4668 rows
# BIV.csv: 4668 rows
# BSV.csv: 4668 rows
# SMCI.csv: 4675 rows
# BR.csv: 4680 rows
# MBB.csv: 4684 rows
# VEU.csv: 4690 rows
# SKG.L.csv: 4703 rows
# IGSB.csv: 4728 rows
# SHV.csv: 4728 rows
# FSLR.csv: 4763 rows
# VYM.csv: 4764 rows
# LDOS.csv: 4786 rows
# SY1.DE.csv: 4793 rows
# EXPN.L.csv: 4813 rows
# MA.csv: 4886 rows
# VIG.csv: 4903 rows
# TDG.csv: 4936 rows
# RMV.L.csv: 4959 rows
# UAL.csv: 4962 rows
# CMG.csv: 4969 rows
# LYV.csv: 4992 rows
# LR.PA.csv: 5001 rows
# ICE.csv: 5016 rows
# SDY.csv: 5017 rows
# SPLG.csv: 5017 rows
# HIK.L.csv: 5051 rows
# AAL.csv: 5052 rows
# AMP.csv: 5060 rows
# CF.csv: 5084 rows
# EFV.csv: 5088 rows
# EXPE.csv: 5099 rows
# WBD.csv: 5108 rows
# BLDR.csv: 5115 rows
# DXCM.csv: 5167 rows
# ALO.PA.csv: 5178 rows
# MTX.DE.csv: 5185 rows
# MT.AS.csv: 5190 rows
# VWO.csv: 5191 rows
# VGK.csv: 5191 rows
# IAU.csv: 5219 rows
# CE.csv: 5224 rows
# LVS.csv: 5249 rows
# MPWR.csv: 5266 rows
# GLD.csv: 5267 rows
# MKTX.csv: 5276 rows
# ENT.L.csv: 5276 rows
# DLR.csv: 5281 rows
# VNQ.csv: 5303 rows
# GOOGL.csv: 5331 rows
# GOOG.csv: 5331 rows
# EXR.csv: 5334 rows
# ADM.L.csv: 5339 rows
# DPZ.csv: 5358 rows
# CRM.csv: 5371 rows
# CBRE.csv: 5379 rows
# AIZ.csv: 5466 rows
# VUG.csv: 5470 rows
# VTV.csv: 5470 rows
# VO.csv: 5470 rows
# VHT.csv: 5470 rows
# VGT.csv: 5470 rows
# VV.csv: 5470 rows
# VB.csv: 5470 rows
# VBR.csv: 5470 rows
# ITOT.csv: 5475 rows
# NRG.csv: 5510 rows
# DVY.csv: 5526 rows
# LKQ.csv: 5550 rows
# AGG.csv: 5555 rows
# MRO.L.csv: 5576 rows
# MOH.csv: 5616 rows
# RSP.csv: 5659 rows
# IHG.L.csv: 5727 rows
# STX.csv: 5755 rows
# CME.csv: 5758 rows
# IAG.L.csv: 5784 rows
# WYNN.csv: 5787 rows
# BEZ.L.csv: 5826 rows
# TLT.csv: 5849 rows
# SHY.csv: 5849 rows
# IEF.csv: 5849 rows
# LQD.csv: 5849 rows
# NDAQ.csv: 5869 rows
# NFLX.csv: 5895 rows
# FRAS.L.csv: 5900 rows
# BRBY.L.csv: 5913 rows
# ALFA.ST.csv: 5935 rows
# ITRK.L.csv: 5948 rows
# VXF.csv: 5991 rows
# CNC.csv: 6005 rows
# PRU.csv: 6005 rows
# ELV.csv: 6036 rows
# PFG.csv: 6041 rows
# BOL.ST.csv: 6052 rows
# IWR.csv: 6077 rows
# EFA.csv: 6077 rows
# BG.csv: 6094 rows
# ZBH.csv: 6100 rows
# ACN.csv: 6104 rows
# FIS.csv: 6124 rows
# AXON.csv: 6125 rows
# ACA.PA.csv: 6126 rows
# VTI.csv: 6127 rows
# MDLZ.csv: 6129 rows
# WTW.csv: 6130 rows
# LSEG.L.csv: 6168 rows
# STLAP.PA.csv: 6200 rows
# STMPA.PA.csv: 6200 rows
# AIR.PA.csv: 6200 rows
# ABB.ST.csv: 6203 rows
# ALGN.csv: 6222 rows
# GPN.csv: 6232 rows
# GRMN.csv: 6256 rows
# TPR.csv: 6300 rows
# SPYG.csv: 6304 rows
# SPYV.csv: 6304 rows
# DB1.DE.csv: 6315 rows
# DHL.DE.csv: 6320 rows
# EQIX.csv: 6339 rows
# IUSV.csv: 6344 rows
# EZJ.L.csv: 6345 rows
# IUSG.csv: 6349 rows
# ILMN.csv: 6349 rows
# MRVL.csv: 6368 rows
# CRL.csv: 6373 rows
# ISRG.csv: 6378 rows
# SMH.csv: 6387 rows
# HNR1.DE.csv: 6390 rows
# IVW.csv: 6392 rows
# IVE.csv: 6392 rows
# IJH.csv: 6392 rows
# IJR.csv: 6392 rows
# IWM.csv: 6392 rows
# IWF.csv: 6392 rows
# IWD.csv: 6392 rows
# IWB.csv: 6397 rows
# IYW.csv: 6397 rows
# IVV.csv: 6397 rows
# ON.csv: 6410 rows
# MET.csv: 6428 rows
# EW.csv: 6435 rows
# TELIA.ST.csv: 6438 rows
# PUB.PA.csv: 6449 rows
# PKG.csv: 6475 rows
# VIE.PA.csv: 6492 rows
# TDY.csv: 6520 rows
# A.csv: 6523 rows
# UPS.csv: 6529 rows
# AKAM.csv: 6537 rows
# IFX.DE.csv: 6550 rows
# ERIC-B.ST.csv: 6554 rows
# AZN.ST.csv: 6554 rows
# SKA-B.ST.csv: 6554 rows
# ASSA-B.ST.csv: 6554 rows
# SHB-A.ST.csv: 6554 rows
# HEXA-B.ST.csv: 6554 rows
# SWED-A.ST.csv: 6554 rows
# GETI-B.ST.csv: 6554 rows
# ELUX-B.ST.csv: 6554 rows
# NDA-SE.ST.csv: 6554 rows
# SKF-B.ST.csv: 6554 rows
# ALIV-SDB.ST.csv: 6554 rows
# TEL2-B.ST.csv: 6554 rows
# ATCO-A.ST.csv: 6554 rows
# SAND.ST.csv: 6554 rows
# INVE-B.ST.csv: 6554 rows
# VOLV-B.ST.csv: 6554 rows
# HM-B.ST.csv: 6554 rows
# SEB-A.ST.csv: 6554 rows
# SCA-B.ST.csv: 6554 rows
# KINV-B.ST.csv: 6554 rows
# BLK.csv: 6557 rows
# CPG.L.csv: 6571 rows
# DCC.L.csv: 6571 rows
# ATCO-B.ST.csv: 6577 rows
# EOAN.DE.csv: 6600 rows
# SBAC.csv: 6632 rows
# RMS.PA.csv: 6635 rows
# RI.PA.csv: 6635 rows
# SGO.PA.csv: 6635 rows
# SU.PA.csv: 6635 rows
# SAN.PA.csv: 6635 rows
# DG.PA.csv: 6635 rows
# DSY.PA.csv: 6635 rows
# CAP.PA.csv: 6635 rows
# KER.PA.csv: 6635 rows
# RNO.PA.csv: 6635 rows
# GLE.PA.csv: 6635 rows
# MC.PA.csv: 6635 rows
# ENGI.PA.csv: 6635 rows
# ORA.PA.csv: 6635 rows
# EL.PA.csv: 6635 rows
# SAF.PA.csv: 6635 rows
# OR.PA.csv: 6635 rows
# HO.PA.csv: 6635 rows
# TTE.PA.csv: 6635 rows
# AI.PA.csv: 6635 rows
# ML.PA.csv: 6635 rows
# CA.PA.csv: 6635 rows
# FFIV.csv: 6640 rows
# GS.csv: 6662 rows
# BKNG.csv: 6685 rows
# QQQ.csv: 6700 rows
# UTG.L.csv: 6726 rows
# NVDA.csv: 6732 rows
# AAL.L.csv: 6732 rows
# XLV.csv: 6752 rows
# XLY.csv: 6752 rows
# XLE.csv: 6752 rows
# XLI.csv: 6752 rows
# XLF.csv: 6752 rows
# XLK.csv: 6752 rows
# SRT3.DE.csv: 6778 rows
# EBAY.csv: 6814 rows
# CCI.csv: 6840 rows
# INF.L.csv: 6841 rows
# CSGP.csv: 6873 rows
# RSG.csv: 6873 rows
# SRE.csv: 6875 rows
# CTSH.csv: 6881 rows
# MSTR.csv: 6887 rows
# AIR.DE.csv: 6899 rows
# FRE.DE.csv: 6900 rows
# MAR.csv: 6943 rows
# FLTR.L.csv: 6945 rows
# AMT.csv: 6959 rows
# RHM.DE.csv: 6968 rows
# PWR.csv: 6969 rows
# HEI.DE.csv: 6975 rows
# BEI.DE.csv: 6978 rows
# QIA.DE.csv: 6978 rows
# VRSN.csv: 6978 rows
# VOW3.DE.csv: 6978 rows
# DIA.csv: 6986 rows
# MRK.DE.csv: 6996 rows
# HEN3.DE.csv: 6997 rows
# AEE.csv: 6997 rows
# MUV2.DE.csv: 6998 rows
# ADS.DE.csv: 6998 rows
# URI.csv: 7006 rows
# PLD.csv: 7024 rows
# MTD.csv: 7029 rows
# FE.csv: 7033 rows
# CHRW.csv: 7050 rows
# SAP.DE.csv: 7052 rows
# TSM.csv: 7055 rows
# YUM.csv: 7071 rows
# BXP.csv: 7134 rows
# RL.csv: 7138 rows
# ARE.csv: 7149 rows
# AMZN.csv: 7157 rows
# VTR.csv: 7165 rows
# TTWO.csv: 7179 rows
# ERF.PA.csv: 7205 rows
# KMX.csv: 7227 rows
# DGX.csv: 7260 rows
# STLD.csv: 7276 rows
# CNA.L.csv: 7322 rows
# FDS.csv: 7379 rows
# CBK.DE.csv: 7395 rows
# ALV.DE.csv: 7395 rows
# BAYN.DE.csv: 7395 rows
# RWE.DE.csv: 7395 rows
# BAS.DE.csv: 7395 rows
# CON.DE.csv: 7395 rows
# JD.L.csv: 7406 rows
# DBK.DE.csv: 7415 rows
# DTE.DE.csv: 7415 rows
# IMB.L.csv: 7420 rows
# BMW.DE.csv: 7421 rows
# SIE.DE.csv: 7421 rows
# MBG.DE.csv: 7428 rows
# SHEL.L.csv: 7444 rows
# IRM.csv: 7482 rows
# HIG.csv: 7514 rows
# NTAP.csv: 7531 rows
# EL.csv: 7533 rows
# WAT.csv: 7533 rows
# HSIC.csv: 7543 rows
# DVA.csv: 7546 rows
# POOL.csv: 7558 rows
# EG.csv: 7566 rows
# ACGL.csv: 7579 rows
# IVZ.csv: 7592 rows
# LLOY.L.csv: 7619 rows
# FCX.csv: 7626 rows
# NG.L.csv: 7632 rows
# WAB.csv: 7641 rows
# RMD.csv: 7651 rows
# DRI.csv: 7668 rows
# MDY.csv: 7671 rows
# COR.csv: 7692 rows
# ASML.csv: 7706 rows
# DLTR.csv: 7712 rows
# PARA.csv: 7787 rows
# COF.csv: 7787 rows
# MCK.csv: 7791 rows
# SJM.csv: 7799 rows
# MCO.csv: 7799 rows
# O.csv: 7808 rows
# WPP.L.csv: 7816 rows
# BATS.L.csv: 7876 rows
# ESS.csv: 7901 rows
# CPRT.csv: 7956 rows
# AVB.csv: 7960 rows
# ALB.csv: 7973 rows
# TSCO.csv: 7975 rows
# MLM.csv: 7975 rows
# MAA.csv: 7989 rows
# III.L.csv: 7996 rows
# EMN.csv: 8021 rows
# SPG.csv: 8021 rows
# INCY.csv: 8048 rows
# REG.csv: 8052 rows
# DECK.csv: 8062 rows
# IT.csv: 8070 rows
# BWA.csv: 8106 rows
# EQR.csv: 8107 rows
# CPT.csv: 8122 rows
# ALL.csv: 8156 rows
# AZN.csv: 8171 rows
# JBL.csv: 8178 rows
# RCL.csv: 8181 rows
# ORLY.csv: 8184 rows
# CB.csv: 8204 rows
# MCHP.csv: 8208 rows
# INTU.csv: 8213 rows
# MS.csv: 8226 rows
# SPY.csv: 8242 rows
# MTCH.csv: 8250 rows
# BNP.PA.csv: 8255 rows
# AZN.L.csv: 8298 rows
# SBUX.csv: 8392 rows
# LIN.csv: 8399 rows
# DHI.csv: 8407 rows
# STE.csv: 8411 rows
# BSX.csv: 8419 rows
# MHK.csv: 8452 rows
# STZ.csv: 8463 rows
# SNPS.csv: 8477 rows
# ROP.csv: 8485 rows
# GILD.csv: 8501 rows
# HWDN.L.csv: 8519 rows
# QCOM.csv: 8527 rows
# KIM.csv: 8541 rows
# APH.csv: 8551 rows
# ODFL.csv: 8562 rows
# BIIB.csv: 8589 rows
# ZBRA.csv: 8611 rows
# TEP.PA.csv: 8615 rows
# VRTX.csv: 8627 rows
# AES.csv: 8646 rows
# IDXX.csv: 8649 rows
# AZO.csv: 8706 rows
# REGN.csv: 8706 rows
# SSE.L.csv: 8802 rows
# TRMB.csv: 8882 rows
# LH.csv: 8960 rows
# EN.PA.csv: 8980 rows
# HOLX.csv: 8980 rows
# CSCO.csv: 8988 rows
# CTRA.csv: 8994 rows
# STJ.L.csv: 9011 rows
# PTC.csv: 9036 rows
# CS.PA.csv: 9076 rows
# EOG.csv: 9082 rows
# EA.csv: 9092 rows
# GEN.csv: 9153 rows
# IEX.csv: 9168 rows
# SGE.L.csv: 9195 rows
# SVT.L.csv: 9197 rows
# UU.L.csv: 9197 rows
# TECH.csv: 9246 rows
# WM.csv: 9407 rows
# MGM.csv: 9443 rows
# VOD.L.csv: 9491 rows
# BN.PA.csv: 9495 rows
# MOS.csv: 9510 rows
# KEY.csv: 9565 rows
# HSBA.L.csv: 9571 rows
# CRDA.L.csv: 9572 rows
# BP.L.csv: 9572 rows
# SN.L.csv: 9572 rows
# RS1.L.csv: 9573 rows
# ABF.L.csv: 9573 rows
# TSCO.L.csv: 9573 rows
# TW.L.csv: 9573 rows
# RR.L.csv: 9573 rows
# DPLM.L.csv: 9573 rows
# SMIN.L.csv: 9573 rows
# RKT.L.csv: 9573 rows
# AHT.L.csv: 9573 rows
# MKS.L.csv: 9573 rows
# BA.L.csv: 9573 rows
# WTB.L.csv: 9573 rows
# RIO.L.csv: 9573 rows
# BT-A.L.csv: 9573 rows
# ANTO.L.csv: 9573 rows
# PSON.L.csv: 9573 rows
# LAND.L.csv: 9573 rows
# STAN.L.csv: 9573 rows
# KGF.L.csv: 9573 rows
# REL.L.csv: 9573 rows
# LGEN.L.csv: 9573 rows
# BNZL.L.csv: 9573 rows
# IMI.L.csv: 9573 rows
# SDR.L.csv: 9573 rows
# AV.L.csv: 9573 rows
# WEIR.L.csv: 9573 rows
# BARC.L.csv: 9573 rows
# RTO.L.csv: 9573 rows
# HLMA.L.csv: 9573 rows
# ULVR.L.csv: 9573 rows
# SBRY.L.csv: 9573 rows
# GSK.L.csv: 9573 rows
# PRU.L.csv: 9573 rows
# PSN.L.csv: 9573 rows
# BKG.L.csv: 9573 rows
# SPX.L.csv: 9573 rows
# NXT.L.csv: 9573 rows
# SGRO.L.csv: 9573 rows
# NWG.L.csv: 9573 rows
# JCI.csv: 9593 rows
# SCHW.csv: 9597 rows
# DGE.L.csv: 9615 rows
# FAST.csv: 9619 rows
# CCL.csv: 9638 rows
# FICO.csv: 9640 rows
# TJX.csv: 9657 rows
# CDNS.csv: 9669 rows
# BKR.csv: 9714 rows
# CCEP.csv: 9805 rows
# FI.csv: 9847 rows
# ADBE.csv: 9877 rows
# COST.csv: 9902 rows
# TROW.csv: 9970 rows
# MSFT.csv: 9983 rows
# ORCL.csv: 9984 rows
# MNST.csv: 10048 rows
# JKHY.csv: 10060 rows
# ROST.csv: 10132 rows
# NVR.csv: 10145 rows
# DVN.csv: 10145 rows
# ADSK.csv: 10160 rows
# DOC.csv: 10185 rows
# BBY.csv: 10210 rows
# UNH.csv: 10336 rows
# EXPD.csv: 10351 rows
# SWKS.csv: 10364 rows
# AME.csv: 10399 rows
# AJG.csv: 10419 rows
# MU.csv: 10432 rows
# LRCX.csv: 10451 rows
# ATO.csv: 10540 rows
# JBHT.csv: 10564 rows
# VZ.csv: 10565 rows
# T.csv: 10565 rows
# AOS.csv: 10601 rows
# BEN.csv: 10606 rows
# PAYX.csv: 10625 rows
# CTAS.csv: 10630 rows
# CAH.csv: 10641 rows
# RJF.csv: 10664 rows
# AMGN.csv: 10674 rows
# COO.csv: 10776 rows
# NSC.csv: 10939 rows
# BBWI.csv: 10981 rows
# CI.csv: 10982 rows
# VLO.csv: 11043 rows
# GLW.csv: 11044 rows
# OXY.csv: 11044 rows
# SO.csv: 11044 rows
# SLB.csv: 11044 rows
# LHX.csv: 11044 rows
# COP.csv: 11044 rows
# HUM.csv: 11044 rows
# NOC.csv: 11044 rows
# ROK.csv: 11044 rows
# WMB.csv: 11044 rows
# BAX.csv: 11089 rows
# HD.csv: 11114 rows
# UHS.csv: 11166 rows
# BRO.csv: 11268 rows
# AAPL.csv: 11309 rows
# NKE.csv: 11317 rows
# PSA.csv: 11326 rows
# CSX.csv: 11336 rows
# KLAC.csv: 11354 rows
# GL.csv: 11359 rows
# OKE.csv: 11359 rows
# AON.csv: 11444 rows
# WELL.csv: 11495 rows
# NDSN.csv: 11496 rows
# TFC.csv: 11496 rows
# TYL.csv: 11497 rows
# CAG.csv: 11497 rows
# HAS.csv: 11497 rows
# RHI.csv: 11497 rows
# MAS.csv: 11497 rows
# TT.csv: 11497 rows
# NUE.csv: 11497 rows
# ABT.csv: 11497 rows
# IPG.csv: 11497 rows
# VTRS.csv: 11497 rows
# J.csv: 11497 rows
# JPM.csv: 11497 rows
# NTRS.csv: 11497 rows
# PCAR.csv: 11497 rows
# WST.csv: 11497 rows
# WEC.csv: 11497 rows
# PH.csv: 11497 rows
# ADM.csv: 11497 rows
# OMC.csv: 11497 rows
# CINF.csv: 11497 rows
# AMD.csv: 11497 rows
# GIS.csv: 11497 rows
# FITB.csv: 11497 rows
# PPL.csv: 11497 rows
# EQT.csv: 11497 rows
# DOV.csv: 11497 rows
# SWK.csv: 11497 rows
# TFX.csv: 11497 rows
# INTC.csv: 11497 rows
# ADI.csv: 11497 rows
# AFL.csv: 11497 rows
# STT.csv: 11497 rows
# PGR.csv: 11497 rows
# CMA.csv: 11497 rows
# SHW.csv: 11497 rows
# UDR.csv: 11497 rows
# D.csv: 11497 rows
# SYK.csv: 11497 rows
# ROL.csv: 11497 rows
# CHD.csv: 11497 rows
# HSY.csv: 11497 rows
# CMCSA.csv: 11497 rows
# HRL.csv: 11497 rows
# LEN.csv: 11497 rows
# TMO.csv: 11497 rows
# TSN.csv: 11497 rows
# AMAT.csv: 11497 rows
# RF.csv: 11497 rows
# LOW.csv: 11497 rows
# HBAN.csv: 11497 rows
# EFX.csv: 11497 rows
# MTB.csv: 11497 rows
# FMC.csv: 11497 rows
# L.csv: 11497 rows
# GPC.csv: 11497 rows
# PHM.csv: 11497 rows
# PPG.csv: 11497 rows
# APD.csv: 11497 rows
# NEM.csv: 11497 rows
# DUK.csv: 11497 rows
# KMB.csv: 11497 rows
# ADP.csv: 11497 rows
# HST.csv: 11497 rows
# BIO.csv: 11510 rows
# PEG.csv: 11549 rows
# UNP.csv: 11549 rows
# LUV.csv: 11549 rows
# APA.csv: 11709 rows
# DHR.csv: 11803 rows
# WDC.csv: 11844 rows
# FDX.csv: 11985 rows
# C.csv: 12306 rows
# TRV.csv: 12590 rows
# PNC.csv: 12590 rows
# TAP.csv: 12700 rows
# IFF.csv: 12822 rows
# WRB.csv: 13113 rows
# SYY.csv: 13230 rows
# BK.csv: 13233 rows
# USB.csv: 13233 rows
# FRT.csv: 13233 rows
# EIX.csv: 13233 rows
# PNR.csv: 13233 rows
# WY.csv: 13233 rows
# CL.csv: 13234 rows
# MDT.csv: 13234 rows
# EXC.csv: 13234 rows
# ITW.csv: 13269 rows
# ES.csv: 13283 rows
# CLX.csv: 13283 rows
# CVS.csv: 13283 rows
# VMC.csv: 13283 rows
# BDX.csv: 13283 rows
# EVRG.csv: 13283 rows
# MKC.csv: 13283 rows
# BAC.csv: 13283 rows
# TGT.csv: 13283 rows
# K.csv: 13283 rows
# RVTY.csv: 13283 rows
# CMS.csv: 13283 rows
# BALL.csv: 13283 rows
# TER.csv: 13283 rows
# MMC.csv: 13283 rows
# XEL.csv: 13283 rows
# NEE.csv: 13283 rows
# NI.csv: 13283 rows
# ECL.csv: 13283 rows
# CMI.csv: 13283 rows
# PNW.csv: 13283 rows
# CPB.csv: 13283 rows
# AVY.csv: 13283 rows
# SPGI.csv: 13283 rows
# TXT.csv: 13283 rows
# LNT.csv: 13283 rows
# SNA.csv: 13283 rows
# GWW.csv: 13283 rows
# AIG.csv: 13317 rows
# HUBB.csv: 13341 rows
# WBA.csv: 13345 rows
# WMT.csv: 13403 rows
# F.csv: 13463 rows
# LLY.csv: 13463 rows
# HAL.csv: 13463 rows
# PCG.csv: 13463 rows
# AXP.csv: 13463 rows
# EMR.csv: 13463 rows
# PFE.csv: 13463 rows
# DE.csv: 13463 rows
# TXN.csv: 13463 rows
# BMY.csv: 13463 rows
# ETN.csv: 13463 rows
# DD.csv: 13463 rows
# ETR.csv: 13463 rows
# WFC.csv: 13463 rows
# PEP.csv: 13463 rows
# FCIT.L.csv: 14660 rows
# SMT.L.csv: 14660 rows
# MCD.csv: 14927 rows
# RTX.csv: 15999 rows
# LMT.csv: 16061 rows
# HPQ.csv: 16062 rows
# PG.csv: 16062 rows
# IP.csv: 16062 rows
# DIS.csv: 16062 rows
# MRK.csv: 16062 rows
# HON.csv: 16062 rows
# CAT.csv: 16062 rows
# GE.csv: 16062 rows
# IBM.csv: 16062 rows
# GD.csv: 16062 rows
# JNJ.csv: 16062 rows
# ED.csv: 16062 rows
# DTE.csv: 16062 rows
# XOM.csv: 16062 rows
# MMM.csv: 16062 rows
# CVX.csv: 16062 rows
# BA.csv: 16062 rows
# KO.csv: 16062 rows
# MSI.csv: 16062 rows
# CNP.csv: 16062 rows
# MO.csv: 16062 rows
# KR.csv: 16062 rows
# AEP.csv: 16062 rows

# %%
from collections import defaultdict
import numpy as np

def cluster_csv_pairs_hdbscan_sorted(sorted_csv_files,
                                     min_cluster_size=5,
                                     min_samples=None,
                                     alpha=1.0):
    """
    HDBSCAN clustering with cluster IDs reordered by descending row counts.
    Cluster 0 has the largest rows.
    """

    import hdbscan
    from sklearn.preprocessing import RobustScaler

    if not sorted_csv_files:
        return {}

    # Feature: row count only
    row_counts = np.array([rc for _, rc in sorted_csv_files], dtype=np.float64).reshape(-1, 1)

    # Robust scaling
    X = RobustScaler().fit_transform(row_counts)

    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=min_cluster_size,
        min_samples=min_samples,
        alpha=alpha,
        metric="euclidean"
    )

    raw_labels = clusterer.fit_predict(X)

    # Collect raw clusters
    raw_clusters = defaultdict(list)
    for pair, lab in zip(sorted_csv_files, raw_labels):
        raw_clusters[int(lab)].append(pair)

    # Separate noise
    noise = raw_clusters.pop(-1, [])

    # Sort clusters by mean row count (descending)
    sorted_clusters = sorted(
        raw_clusters.values(),
        key=lambda items: np.mean([rc for _, rc in items]),
        reverse=True
    )

    # Reassign cluster IDs: 0 = largest rows
    final_clusters = {}
    for new_id, items in enumerate(sorted_clusters):
        final_clusters[new_id] = sorted(items, key=lambda x: x[1], reverse=True)

    if noise:
        final_clusters[-1] = sorted(noise, key=lambda x: x[1], reverse=True)

    # Pretty print
    print(f"Clusters found (excluding noise): {len(sorted_clusters)}")
    print(f"Noise points (-1): {len(noise)}\n")

    for cid in sorted(final_clusters.keys(), key=lambda x: (x == -1, x)):
        title = "Noise (-1)" if cid == -1 else f"Cluster {cid}"
        print(f"{title} | size={len(final_clusters[cid])}")
        for fname, rc in final_clusters[cid]:
            print(f"  ({fname!r}, {rc})")
        print()

    return final_clusters


# ---- Example usage ----
# clusters = cluster_csv_pairs_hdbscan_sorted(
#     sorted_csv_files,
#     min_cluster_size=5
# )

# %%
clusters = cluster_csv_pairs_hdbscan_sorted(sorted_csv_files,
                                              min_cluster_size=5,
                                              min_samples=5)
# Out:
# Clusters found (excluding noise): 42
# Noise points (-1): 79
#
# Cluster 0 | size=28
#   ('HPQ.csv', 16062)
#   ('PG.csv', 16062)
#   ('IP.csv', 16062)
#   ('DIS.csv', 16062)
#   ('MRK.csv', 16062)
#   ('HON.csv', 16062)
#   ('CAT.csv', 16062)
#   ('GE.csv', 16062)
#   ('IBM.csv', 16062)
#   ('GD.csv', 16062)
#   ('JNJ.csv', 16062)
#   ('ED.csv', 16062)
#   ('DTE.csv', 16062)
#   ('XOM.csv', 16062)
#   ('MMM.csv', 16062)
#   ('CVX.csv', 16062)
#   ('BA.csv', 16062)
#   ('KO.csv', 16062)
#   ('MSI.csv', 16062)
#   ('CNP.csv', 16062)
#   ('MO.csv', 16062)
#   ('KR.csv', 16062)
#   ('AEP.csv', 16062)
#   ('LMT.csv', 16061)
#   ('RTX.csv', 15999)
#   ('MCD.csv', 14927)
#   ('FCIT.L.csv', 14660)
#   ('SMT.L.csv', 14660)
#
# Cluster 1 | size=17
#   ('F.csv', 13463)
#   ('LLY.csv', 13463)
#   ('HAL.csv', 13463)
#   ('PCG.csv', 13463)
#   ('AXP.csv', 13463)
#   ('EMR.csv', 13463)
#   ('PFE.csv', 13463)
#   ('DE.csv', 13463)
#   ('TXN.csv', 13463)
#   ('BMY.csv', 13463)
#   ('ETN.csv', 13463)
#   ('DD.csv', 13463)
#   ('ETR.csv', 13463)
#   ('WFC.csv', 13463)
#   ('PEP.csv', 13463)
#   ('WMT.csv', 13403)
#   ('WBA.csv', 13345)
#
# Cluster 2 | size=30
#   ('AIG.csv', 13317)
#   ('ES.csv', 13283)
#   ('CLX.csv', 13283)
#   ('CVS.csv', 13283)
#   ('VMC.csv', 13283)
#   ('BDX.csv', 13283)
#   ('EVRG.csv', 13283)
#   ('MKC.csv', 13283)
#   ('BAC.csv', 13283)
#   ('TGT.csv', 13283)
#   ('K.csv', 13283)
#   ('RVTY.csv', 13283)
#   ('CMS.csv', 13283)
#   ('BALL.csv', 13283)
#   ('TER.csv', 13283)
#   ('MMC.csv', 13283)
#   ('XEL.csv', 13283)
#   ('NEE.csv', 13283)
#   ('NI.csv', 13283)
#   ('ECL.csv', 13283)
#   ('CMI.csv', 13283)
#   ('PNW.csv', 13283)
#   ('CPB.csv', 13283)
#   ('AVY.csv', 13283)
#   ('SPGI.csv', 13283)
#   ('TXT.csv', 13283)
#   ('LNT.csv', 13283)
#   ('SNA.csv', 13283)
#   ('GWW.csv', 13283)
#   ('ITW.csv', 13269)
#
# Cluster 3 | size=10
#   ('CL.csv', 13234)
#   ('MDT.csv', 13234)
#   ('EXC.csv', 13234)
#   ('BK.csv', 13233)
#   ('USB.csv', 13233)
#   ('FRT.csv', 13233)
#   ('EIX.csv', 13233)
#   ('PNR.csv', 13233)
#   ('WY.csv', 13233)
#   ('SYY.csv', 13230)
#
# Cluster 4 | size=71
#   ('PEG.csv', 11549)
#   ('UNP.csv', 11549)
#   ('LUV.csv', 11549)
#   ('BIO.csv', 11510)
#   ('TYL.csv', 11497)
#   ('CAG.csv', 11497)
#   ('HAS.csv', 11497)
#   ('RHI.csv', 11497)
#   ('MAS.csv', 11497)
#   ('TT.csv', 11497)
#   ('NUE.csv', 11497)
#   ('ABT.csv', 11497)
#   ('IPG.csv', 11497)
#   ('VTRS.csv', 11497)
#   ('J.csv', 11497)
#   ('JPM.csv', 11497)
#   ('NTRS.csv', 11497)
#   ('PCAR.csv', 11497)
#   ('WST.csv', 11497)
#   ('WEC.csv', 11497)
#   ('PH.csv', 11497)
#   ('ADM.csv', 11497)
#   ('OMC.csv', 11497)
#   ('CINF.csv', 11497)
#   ('AMD.csv', 11497)
#   ('GIS.csv', 11497)
#   ('FITB.csv', 11497)
#   ('PPL.csv', 11497)
#   ('EQT.csv', 11497)
#   ('DOV.csv', 11497)
#   ('SWK.csv', 11497)
#   ('TFX.csv', 11497)
#   ('INTC.csv', 11497)
#   ('ADI.csv', 11497)
#   ('AFL.csv', 11497)
#   ('STT.csv', 11497)
#   ('PGR.csv', 11497)
#   ('CMA.csv', 11497)
#   ('SHW.csv', 11497)
#   ('UDR.csv', 11497)
#   ('D.csv', 11497)
#   ('SYK.csv', 11497)
#   ('ROL.csv', 11497)
#   ('CHD.csv', 11497)
#   ('HSY.csv', 11497)
#   ('CMCSA.csv', 11497)
#   ('HRL.csv', 11497)
#   ('LEN.csv', 11497)
#   ('TMO.csv', 11497)
#   ('TSN.csv', 11497)
#   ('AMAT.csv', 11497)
#   ('RF.csv', 11497)
#   ('LOW.csv', 11497)
#   ('HBAN.csv', 11497)
#   ('EFX.csv', 11497)
#   ('MTB.csv', 11497)
#   ('FMC.csv', 11497)
#   ('L.csv', 11497)
#   ('GPC.csv', 11497)
#   ('PHM.csv', 11497)
#   ('PPG.csv', 11497)
#   ('APD.csv', 11497)
#   ('NEM.csv', 11497)
#   ('DUK.csv', 11497)
#   ('KMB.csv', 11497)
#   ('ADP.csv', 11497)
#   ('HST.csv', 11497)
#   ('NDSN.csv', 11496)
#   ('TFC.csv', 11496)
#   ('WELL.csv', 11495)
#   ('AON.csv', 11444)
#
# Cluster 5 | size=7
#   ('GL.csv', 11359)
#   ('OKE.csv', 11359)
#   ('KLAC.csv', 11354)
#   ('CSX.csv', 11336)
#   ('PSA.csv', 11326)
#   ('NKE.csv', 11317)
#   ('AAPL.csv', 11309)
#
# Cluster 6 | size=17
#   ('UHS.csv', 11166)
#   ('HD.csv', 11114)
#   ('BAX.csv', 11089)
#   ('GLW.csv', 11044)
#   ('OXY.csv', 11044)
#   ('SO.csv', 11044)
#   ('SLB.csv', 11044)
#   ('LHX.csv', 11044)
#   ('COP.csv', 11044)
#   ('HUM.csv', 11044)
#   ('NOC.csv', 11044)
#   ('ROK.csv', 11044)
#   ('WMB.csv', 11044)
#   ('VLO.csv', 11043)
#   ('CI.csv', 10982)
#   ('BBWI.csv', 10981)
#   ('NSC.csv', 10939)
#
# Cluster 7 | size=12
#   ('AMGN.csv', 10674)
#   ('RJF.csv', 10664)
#   ('CAH.csv', 10641)
#   ('CTAS.csv', 10630)
#   ('PAYX.csv', 10625)
#   ('BEN.csv', 10606)
#   ('AOS.csv', 10601)
#   ('VZ.csv', 10565)
#   ('T.csv', 10565)
#   ('JBHT.csv', 10564)
#   ('ATO.csv', 10540)
#   ('LRCX.csv', 10451)
#
# Cluster 8 | size=5
#   ('MU.csv', 10432)
#   ('AJG.csv', 10419)
#   ('AME.csv', 10399)
#   ('SWKS.csv', 10364)
#   ('EXPD.csv', 10351)
#
# Cluster 9 | size=13
#   ('BBY.csv', 10210)
#   ('DOC.csv', 10185)
#   ('ADSK.csv', 10160)
#   ('NVR.csv', 10145)
#   ('DVN.csv', 10145)
#   ('ROST.csv', 10132)
#   ('JKHY.csv', 10060)
#   ('MNST.csv', 10048)
#   ('ORCL.csv', 9984)
#   ('MSFT.csv', 9983)
#   ('TROW.csv', 9970)
#   ('COST.csv', 9902)
#   ('ADBE.csv', 9877)
#
# Cluster 10 | size=58
#   ('FI.csv', 9847)
#   ('BKR.csv', 9714)
#   ('CDNS.csv', 9669)
#   ('TJX.csv', 9657)
#   ('FICO.csv', 9640)
#   ('CCL.csv', 9638)
#   ('FAST.csv', 9619)
#   ('DGE.L.csv', 9615)
#   ('SCHW.csv', 9597)
#   ('JCI.csv', 9593)
#   ('RS1.L.csv', 9573)
#   ('ABF.L.csv', 9573)
#   ('TSCO.L.csv', 9573)
#   ('TW.L.csv', 9573)
#   ('RR.L.csv', 9573)
#   ('DPLM.L.csv', 9573)
#   ('SMIN.L.csv', 9573)
#   ('RKT.L.csv', 9573)
#   ('AHT.L.csv', 9573)
#   ('MKS.L.csv', 9573)
#   ('BA.L.csv', 9573)
#   ('WTB.L.csv', 9573)
#   ('RIO.L.csv', 9573)
#   ('BT-A.L.csv', 9573)
#   ('ANTO.L.csv', 9573)
#   ('PSON.L.csv', 9573)
#   ('LAND.L.csv', 9573)
#   ('STAN.L.csv', 9573)
#   ('KGF.L.csv', 9573)
#   ('REL.L.csv', 9573)
#   ('LGEN.L.csv', 9573)
#   ('BNZL.L.csv', 9573)
#   ('IMI.L.csv', 9573)
#   ('SDR.L.csv', 9573)
#   ('AV.L.csv', 9573)
#   ('WEIR.L.csv', 9573)
#   ('BARC.L.csv', 9573)
#   ('RTO.L.csv', 9573)
#   ('HLMA.L.csv', 9573)
#   ('ULVR.L.csv', 9573)
#   ('SBRY.L.csv', 9573)
#   ('GSK.L.csv', 9573)
#   ('PRU.L.csv', 9573)
#   ('PSN.L.csv', 9573)
#   ('BKG.L.csv', 9573)
#   ('SPX.L.csv', 9573)
#   ('NXT.L.csv', 9573)
#   ('SGRO.L.csv', 9573)
#   ('NWG.L.csv', 9573)
#   ('CRDA.L.csv', 9572)
#   ('BP.L.csv', 9572)
#   ('SN.L.csv', 9572)
#   ('HSBA.L.csv', 9571)
#   ('KEY.csv', 9565)
#   ('MOS.csv', 9510)
#   ('BN.PA.csv', 9495)
#   ('VOD.L.csv', 9491)
#   ('MGM.csv', 9443)
#
# Cluster 11 | size=17
#   ('TECH.csv', 9246)
#   ('SVT.L.csv', 9197)
#   ('UU.L.csv', 9197)
#   ('SGE.L.csv', 9195)
#   ('IEX.csv', 9168)
#   ('GEN.csv', 9153)
#   ('EA.csv', 9092)
#   ('EOG.csv', 9082)
#   ('CS.PA.csv', 9076)
#   ('PTC.csv', 9036)
#   ('STJ.L.csv', 9011)
#   ('CTRA.csv', 8994)
#   ('CSCO.csv', 8988)
#   ('EN.PA.csv', 8980)
#   ('HOLX.csv', 8980)
#   ('LH.csv', 8960)
#   ('TRMB.csv', 8882)
#
# Cluster 12 | size=23
#   ('AZO.csv', 8706)
#   ('REGN.csv', 8706)
#   ('IDXX.csv', 8649)
#   ('AES.csv', 8646)
#   ('VRTX.csv', 8627)
#   ('TEP.PA.csv', 8615)
#   ('ZBRA.csv', 8611)
#   ('BIIB.csv', 8589)
#   ('ODFL.csv', 8562)
#   ('APH.csv', 8551)
#   ('KIM.csv', 8541)
#   ('QCOM.csv', 8527)
#   ('HWDN.L.csv', 8519)
#   ('GILD.csv', 8501)
#   ('ROP.csv', 8485)
#   ('SNPS.csv', 8477)
#   ('STZ.csv', 8463)
#   ('MHK.csv', 8452)
#   ('BSX.csv', 8419)
#   ('STE.csv', 8411)
#   ('DHI.csv', 8407)
#   ('LIN.csv', 8399)
#   ('SBUX.csv', 8392)
#
# Cluster 13 | size=13
#   ('BNP.PA.csv', 8255)
#   ('MTCH.csv', 8250)
#   ('SPY.csv', 8242)
#   ('MS.csv', 8226)
#   ('INTU.csv', 8213)
#   ('MCHP.csv', 8208)
#   ('CB.csv', 8204)
#   ('ORLY.csv', 8184)
#   ('RCL.csv', 8181)
#   ('JBL.csv', 8178)
#   ('AZN.csv', 8171)
#   ('ALL.csv', 8156)
#   ('EQR.csv', 8107)
#
# Cluster 14 | size=13
#   ('IT.csv', 8070)
#   ('DECK.csv', 8062)
#   ('REG.csv', 8052)
#   ('INCY.csv', 8048)
#   ('EMN.csv', 8021)
#   ('SPG.csv', 8021)
#   ('III.L.csv', 7996)
#   ('MAA.csv', 7989)
#   ('TSCO.csv', 7975)
#   ('MLM.csv', 7975)
#   ('ALB.csv', 7973)
#   ('AVB.csv', 7960)
#   ('CPRT.csv', 7956)
#
# Cluster 15 | size=7
#   ('WPP.L.csv', 7816)
#   ('O.csv', 7808)
#   ('SJM.csv', 7799)
#   ('MCO.csv', 7799)
#   ('MCK.csv', 7791)
#   ('PARA.csv', 7787)
#   ('COF.csv', 7787)
#
# Cluster 16 | size=18
#   ('COR.csv', 7692)
#   ('MDY.csv', 7671)
#   ('DRI.csv', 7668)
#   ('RMD.csv', 7651)
#   ('WAB.csv', 7641)
#   ('NG.L.csv', 7632)
#   ('FCX.csv', 7626)
#   ('LLOY.L.csv', 7619)
#   ('IVZ.csv', 7592)
#   ('ACGL.csv', 7579)
#   ('EG.csv', 7566)
#   ('POOL.csv', 7558)
#   ('DVA.csv', 7546)
#   ('HSIC.csv', 7543)
#   ('EL.csv', 7533)
#   ('WAT.csv', 7533)
#   ('NTAP.csv', 7531)
#   ('HIG.csv', 7514)
#
# Cluster 17 | size=5
#   ('BMW.DE.csv', 7421)
#   ('SIE.DE.csv', 7421)
#   ('IMB.L.csv', 7420)
#   ('DBK.DE.csv', 7415)
#   ('DTE.DE.csv', 7415)
#
# Cluster 18 | size=7
#   ('JD.L.csv', 7406)
#   ('CBK.DE.csv', 7395)
#   ('ALV.DE.csv', 7395)
#   ('BAYN.DE.csv', 7395)
#   ('RWE.DE.csv', 7395)
#   ('BAS.DE.csv', 7395)
#   ('CON.DE.csv', 7395)
#
# Cluster 19 | size=8
#   ('KMX.csv', 7227)
#   ('ERF.PA.csv', 7205)
#   ('TTWO.csv', 7179)
#   ('VTR.csv', 7165)
#   ('AMZN.csv', 7157)
#   ('ARE.csv', 7149)
#   ('RL.csv', 7138)
#   ('BXP.csv', 7134)
#
# Cluster 20 | size=24
#   ('YUM.csv', 7071)
#   ('TSM.csv', 7055)
#   ('SAP.DE.csv', 7052)
#   ('CHRW.csv', 7050)
#   ('FE.csv', 7033)
#   ('MTD.csv', 7029)
#   ('PLD.csv', 7024)
#   ('URI.csv', 7006)
#   ('MUV2.DE.csv', 6998)
#   ('ADS.DE.csv', 6998)
#   ('HEN3.DE.csv', 6997)
#   ('AEE.csv', 6997)
#   ('MRK.DE.csv', 6996)
#   ('DIA.csv', 6986)
#   ('BEI.DE.csv', 6978)
#   ('QIA.DE.csv', 6978)
#   ('VRSN.csv', 6978)
#   ('VOW3.DE.csv', 6978)
#   ('HEI.DE.csv', 6975)
#   ('PWR.csv', 6969)
#   ('RHM.DE.csv', 6968)
#   ('AMT.csv', 6959)
#   ('FLTR.L.csv', 6945)
#   ('MAR.csv', 6943)
#
# Cluster 21 | size=9
#   ('FRE.DE.csv', 6900)
#   ('AIR.DE.csv', 6899)
#   ('MSTR.csv', 6887)
#   ('CTSH.csv', 6881)
#   ('SRE.csv', 6875)
#   ('CSGP.csv', 6873)
#   ('RSG.csv', 6873)
#   ('INF.L.csv', 6841)
#   ('CCI.csv', 6840)
#
# Cluster 22 | size=11
#   ('SRT3.DE.csv', 6778)
#   ('XLV.csv', 6752)
#   ('XLY.csv', 6752)
#   ('XLE.csv', 6752)
#   ('XLI.csv', 6752)
#   ('XLF.csv', 6752)
#   ('XLK.csv', 6752)
#   ('NVDA.csv', 6732)
#   ('AAL.L.csv', 6732)
#   ('UTG.L.csv', 6726)
#   ('QQQ.csv', 6700)
#
# Cluster 23 | size=25
#   ('GS.csv', 6662)
#   ('FFIV.csv', 6640)
#   ('RMS.PA.csv', 6635)
#   ('RI.PA.csv', 6635)
#   ('SGO.PA.csv', 6635)
#   ('SU.PA.csv', 6635)
#   ('SAN.PA.csv', 6635)
#   ('DG.PA.csv', 6635)
#   ('DSY.PA.csv', 6635)
#   ('CAP.PA.csv', 6635)
#   ('KER.PA.csv', 6635)
#   ('RNO.PA.csv', 6635)
#   ('GLE.PA.csv', 6635)
#   ('MC.PA.csv', 6635)
#   ('ENGI.PA.csv', 6635)
#   ('ORA.PA.csv', 6635)
#   ('EL.PA.csv', 6635)
#   ('SAF.PA.csv', 6635)
#   ('OR.PA.csv', 6635)
#   ('HO.PA.csv', 6635)
#   ('TTE.PA.csv', 6635)
#   ('AI.PA.csv', 6635)
#   ('ML.PA.csv', 6635)
#   ('CA.PA.csv', 6635)
#   ('SBAC.csv', 6632)
#
# Cluster 24 | size=31
#   ('EOAN.DE.csv', 6600)
#   ('ATCO-B.ST.csv', 6577)
#   ('CPG.L.csv', 6571)
#   ('DCC.L.csv', 6571)
#   ('BLK.csv', 6557)
#   ('ERIC-B.ST.csv', 6554)
#   ('AZN.ST.csv', 6554)
#   ('SKA-B.ST.csv', 6554)
#   ('ASSA-B.ST.csv', 6554)
#   ('SHB-A.ST.csv', 6554)
#   ('HEXA-B.ST.csv', 6554)
#   ('SWED-A.ST.csv', 6554)
#   ('GETI-B.ST.csv', 6554)
#   ('ELUX-B.ST.csv', 6554)
#   ('NDA-SE.ST.csv', 6554)
#   ('SKF-B.ST.csv', 6554)
#   ('ALIV-SDB.ST.csv', 6554)
#   ('TEL2-B.ST.csv', 6554)
#   ('ATCO-A.ST.csv', 6554)
#   ('SAND.ST.csv', 6554)
#   ('INVE-B.ST.csv', 6554)
#   ('VOLV-B.ST.csv', 6554)
#   ('HM-B.ST.csv', 6554)
#   ('SEB-A.ST.csv', 6554)
#   ('SCA-B.ST.csv', 6554)
#   ('KINV-B.ST.csv', 6554)
#   ('IFX.DE.csv', 6550)
#   ('AKAM.csv', 6537)
#   ('UPS.csv', 6529)
#   ('A.csv', 6523)
#   ('TDY.csv', 6520)
#
# Cluster 25 | size=30
#   ('PUB.PA.csv', 6449)
#   ('TELIA.ST.csv', 6438)
#   ('EW.csv', 6435)
#   ('MET.csv', 6428)
#   ('ON.csv', 6410)
#   ('IWB.csv', 6397)
#   ('IYW.csv', 6397)
#   ('IVV.csv', 6397)
#   ('IVW.csv', 6392)
#   ('IVE.csv', 6392)
#   ('IJH.csv', 6392)
#   ('IJR.csv', 6392)
#   ('IWM.csv', 6392)
#   ('IWF.csv', 6392)
#   ('IWD.csv', 6392)
#   ('HNR1.DE.csv', 6390)
#   ('SMH.csv', 6387)
#   ('ISRG.csv', 6378)
#   ('CRL.csv', 6373)
#   ('MRVL.csv', 6368)
#   ('IUSG.csv', 6349)
#   ('ILMN.csv', 6349)
#   ('EZJ.L.csv', 6345)
#   ('IUSV.csv', 6344)
#   ('EQIX.csv', 6339)
#   ('DHL.DE.csv', 6320)
#   ('DB1.DE.csv', 6315)
#   ('SPYG.csv', 6304)
#   ('SPYV.csv', 6304)
#   ('TPR.csv', 6300)
#
# Cluster 26 | size=6
#   ('GPN.csv', 6232)
#   ('ALGN.csv', 6222)
#   ('ABB.ST.csv', 6203)
#   ('STLAP.PA.csv', 6200)
#   ('STMPA.PA.csv', 6200)
#   ('AIR.PA.csv', 6200)
#
# Cluster 27 | size=13
#   ('LSEG.L.csv', 6168)
#   ('WTW.csv', 6130)
#   ('MDLZ.csv', 6129)
#   ('VTI.csv', 6127)
#   ('ACA.PA.csv', 6126)
#   ('AXON.csv', 6125)
#   ('FIS.csv', 6124)
#   ('ACN.csv', 6104)
#   ('ZBH.csv', 6100)
#   ('BG.csv', 6094)
#   ('IWR.csv', 6077)
#   ('EFA.csv', 6077)
#   ('PFG.csv', 6041)
#
# Cluster 28 | size=10
#   ('ITRK.L.csv', 5948)
#   ('BRBY.L.csv', 5913)
#   ('FRAS.L.csv', 5900)
#   ('NFLX.csv', 5895)
#   ('NDAQ.csv', 5869)
#   ('TLT.csv', 5849)
#   ('SHY.csv', 5849)
#   ('IEF.csv', 5849)
#   ('LQD.csv', 5849)
#   ('BEZ.L.csv', 5826)
#
# Cluster 29 | size=15
#   ('MRO.L.csv', 5576)
#   ('AGG.csv', 5555)
#   ('LKQ.csv', 5550)
#   ('DVY.csv', 5526)
#   ('NRG.csv', 5510)
#   ('ITOT.csv', 5475)
#   ('VUG.csv', 5470)
#   ('VTV.csv', 5470)
#   ('VO.csv', 5470)
#   ('VHT.csv', 5470)
#   ('VGT.csv', 5470)
#   ('VV.csv', 5470)
#   ('VB.csv', 5470)
#   ('VBR.csv', 5470)
#   ('AIZ.csv', 5466)
#
# Cluster 30 | size=23
#   ('CBRE.csv', 5379)
#   ('CRM.csv', 5371)
#   ('DPZ.csv', 5358)
#   ('ADM.L.csv', 5339)
#   ('EXR.csv', 5334)
#   ('GOOGL.csv', 5331)
#   ('GOOG.csv', 5331)
#   ('VNQ.csv', 5303)
#   ('DLR.csv', 5281)
#   ('MKTX.csv', 5276)
#   ('ENT.L.csv', 5276)
#   ('GLD.csv', 5267)
#   ('MPWR.csv', 5266)
#   ('LVS.csv', 5249)
#   ('CE.csv', 5224)
#   ('IAU.csv', 5219)
#   ('VWO.csv', 5191)
#   ('VGK.csv', 5191)
#   ('MT.AS.csv', 5190)
#   ('MTX.DE.csv', 5185)
#   ('ALO.PA.csv', 5178)
#   ('DXCM.csv', 5167)
#   ('BLDR.csv', 5115)
#
# Cluster 31 | size=16
#   ('WBD.csv', 5108)
#   ('EXPE.csv', 5099)
#   ('EFV.csv', 5088)
#   ('CF.csv', 5084)
#   ('AMP.csv', 5060)
#   ('AAL.csv', 5052)
#   ('HIK.L.csv', 5051)
#   ('SDY.csv', 5017)
#   ('SPLG.csv', 5017)
#   ('ICE.csv', 5016)
#   ('LR.PA.csv', 5001)
#   ('LYV.csv', 4992)
#   ('CMG.csv', 4969)
#   ('UAL.csv', 4962)
#   ('RMV.L.csv', 4959)
#   ('TDG.csv', 4936)
#
# Cluster 32 | size=25
#   ('LDOS.csv', 4786)
#   ('VYM.csv', 4764)
#   ('FSLR.csv', 4763)
#   ('IGSB.csv', 4728)
#   ('SHV.csv', 4728)
#   ('SKG.L.csv', 4703)
#   ('VEU.csv', 4690)
#   ('MBB.csv', 4684)
#   ('BR.csv', 4680)
#   ('SMCI.csv', 4675)
#   ('BND.csv', 4668)
#   ('BIV.csv', 4668)
#   ('BSV.csv', 4668)
#   ('TMUS.csv', 4661)
#   ('SPDW.csv', 4656)
#   ('DAL.csv', 4651)
#   ('PODD.csv', 4643)
#   ('BIL.csv', 4633)
#   ('MNDI.L.csv', 4631)
#   ('TEL.csv', 4622)
#   ('BX.csv', 4616)
#   ('VEA.csv', 4593)
#   ('LULU.csv', 4592)
#   ('MELI.csv', 4582)
#   ('MUB.csv', 4562)
#
# Cluster 33 | size=8
#   ('ULTA.csv', 4529)
#   ('MGK.csv', 4486)
#   ('PM.csv', 4432)
#   ('V.csv', 4430)
#   ('ACWI.csv', 4424)
#   ('FRES.L.csv', 4413)
#   ('AWK.csv', 4406)
#   ('KDP.csv', 4396)
#
# Cluster 34 | size=16
#   ('VRSK.csv', 4038)
#   ('PHNX.L.csv', 4026)
#   ('SCHX.csv', 4019)
#   ('SCHF.csv', 4019)
#   ('SCHB.csv', 4019)
#   ('DG.csv', 4011)
#   ('FTNT.csv', 4008)
#   ('VCIT.csv', 4005)
#   ('VGSH.csv', 4005)
#   ('VCSH.csv', 4005)
#   ('VGIT.csv', 4005)
#   ('SCHG.csv', 3978)
#   ('CHTR.csv', 3977)
#   ('BNR.DE.csv', 3960)
#   ('TQQQ.csv', 3951)
#   ('GNRC.csv', 3951)
#
# Cluster 35 | size=8
#   ('LYB.csv', 3899)
#   ('OCDO.L.csv', 3857)
#   ('TSLA.csv', 3856)
#   ('NXPI.csv', 3829)
#   ('VOO.csv', 3806)
#   ('GM.csv', 3756)
#   ('VXUS.csv', 3708)
#   ('KMI.csv', 3698)
#
# Cluster 36 | size=6
#   ('GOVT.csv', 3438)
#   ('ENPH.csv', 3413)
#   ('PSX.csv', 3405)
#   ('AMCR.csv', 3382)
#   ('META.csv', 3379)
#   ('PANW.csv', 3336)
#
# Cluster 37 | size=6
#   ('FANG.csv', 3277)
#   ('WDAY.csv', 3277)
#   ('IEFA.csv', 3269)
#   ('IXUS.csv', 3269)
#   ('IEMG.csv', 3269)
#   ('ABBV.csv', 3224)
#
# Cluster 38 | size=9
#   ('NCLH.csv', 3212)
#   ('CCH.L.csv', 3158)
#   ('IQV.csv', 3136)
#   ('VNA.DE.csv', 3122)
#   ('BNDX.csv', 3119)
#   ('NWS.csv', 3108)
#   ('NWSA.csv', 3108)
#   ('CDW.csv', 3102)
#   ('QUAL.csv', 3088)
#
# Cluster 39 | size=12
#   ('WLN.PA.csv', 2902)
#   ('PAYC.csv', 2901)
#   ('BME.L.csv', 2874)
#   ('ANET.csv', 2865)
#   ('DGRO.csv', 2861)
#   ('IUSB.csv', 2861)
#   ('SYF.csv', 2827)
#   ('ZAL.DE.csv', 2812)
#   ('CZR.csv', 2791)
#   ('CFG.csv', 2789)
#   ('KEYS.csv', 2771)
#   ('QRVO.csv', 2720)
#
# Cluster 40 | size=7
#   ('ETSY.csv', 2649)
#   ('SHOP.csv', 2625)
#   ('PYPL.csv', 2594)
#   ('KHC.csv', 2594)
#   ('1COV.DE.csv', 2558)
#   ('VTEB.csv', 2558)
#   ('SINCH.ST.csv', 2528)
#
# Cluster 41 | size=7
#   ('FTV.csv', 2342)
#   ('TTD.csv', 2287)
#   ('CTEC.L.csv', 2272)
#   ('HWM.csv', 2258)
#   ('LW.csv', 2251)
#   ('COWZ.csv', 2222)
#   ('INVH.csv', 2196)
#
# Noise (-1) | size=79
#   ('HUBB.csv', 13341)
#   ('WRB.csv', 13113)
#   ('IFF.csv', 12822)
#   ('TAP.csv', 12700)
#   ('TRV.csv', 12590)
#   ('PNC.csv', 12590)
#   ('C.csv', 12306)
#   ('FDX.csv', 11985)
#   ('WDC.csv', 11844)
#   ('DHR.csv', 11803)
#   ('APA.csv', 11709)
#   ('BRO.csv', 11268)
#   ('COO.csv', 10776)
#   ('UNH.csv', 10336)
#   ('CCEP.csv', 9805)
#   ('WM.csv', 9407)
#   ('SSE.L.csv', 8802)
#   ('AZN.L.csv', 8298)
#   ('CPT.csv', 8122)
#   ('BWA.csv', 8106)
#   ('ESS.csv', 7901)
#   ('BATS.L.csv', 7876)
#   ('DLTR.csv', 7712)
#   ('ASML.csv', 7706)
#   ('IRM.csv', 7482)
#   ('SHEL.L.csv', 7444)
#   ('MBG.DE.csv', 7428)
#   ('FDS.csv', 7379)
#   ('CNA.L.csv', 7322)
#   ('STLD.csv', 7276)
#   ('DGX.csv', 7260)
#   ('EBAY.csv', 6814)
#   ('BKNG.csv', 6685)
#   ('VIE.PA.csv', 6492)
#   ('PKG.csv', 6475)
#   ('GRMN.csv', 6256)
#   ('BOL.ST.csv', 6052)
#   ('ELV.csv', 6036)
#   ('CNC.csv', 6005)
#   ('PRU.csv', 6005)
#   ('VXF.csv', 5991)
#   ('ALFA.ST.csv', 5935)
#   ('WYNN.csv', 5787)
#   ('IAG.L.csv', 5784)
#   ('CME.csv', 5758)
#   ('STX.csv', 5755)
#   ('IHG.L.csv', 5727)
#   ('RSP.csv', 5659)
#   ('MOH.csv', 5616)
#   ('VIG.csv', 4903)
#   ('MA.csv', 4886)
#   ('EXPN.L.csv', 4813)
#   ('SY1.DE.csv', 4793)
#   ('MSCI.csv', 4514)
#   ('VT.csv', 4361)
#   ('PAH3.DE.csv', 4256)
#   ('AVGO.csv', 4081)
#   ('EDEN.PA.csv', 3922)
#   ('CBOE.csv', 3866)
#   ('VONG.csv', 3797)
#   ('TRGP.csv', 3744)
#   ('CPAY.csv', 3738)
#   ('HCA.csv', 3680)
#   ('HII.csv', 3672)
#   ('GLEN.L.csv', 3646)
#   ('MPC.csv', 3606)
#   ('XYL.csv', 3529)
#   ('SCHD.csv', 3524)
#   ('USMV.csv', 3524)
#   ('APTV.csv', 3504)
#   ('EPAM.csv', 3449)
#   ('NOW.csv', 3350)
#   ('ZTS.csv', 3203)
#   ('ALLE.csv', 3002)
#   ('HLT.csv', 2985)
#   ('AUTO.L.csv', 2679)
#   ('EVO.ST.csv', 2667)
#   ('HPE.csv', 2520)
#   ('TEAM.csv', 2484)

# %%
clusters
# Out:
# {0: [('HPQ.csv', 16062),
#   ('PG.csv', 16062),
#   ('IP.csv', 16062),
#   ('DIS.csv', 16062),
#   ('MRK.csv', 16062),
#   ('HON.csv', 16062),
#   ('CAT.csv', 16062),
#   ('GE.csv', 16062),
#   ('IBM.csv', 16062),
#   ('GD.csv', 16062),
#   ('JNJ.csv', 16062),
#   ('ED.csv', 16062),
#   ('DTE.csv', 16062),
#   ('XOM.csv', 16062),
#   ('MMM.csv', 16062),
#   ('CVX.csv', 16062),
#   ('BA.csv', 16062),
#   ('KO.csv', 16062),
#   ('MSI.csv', 16062),
#   ('CNP.csv', 16062),
#   ('MO.csv', 16062),
#   ('KR.csv', 16062),
#   ('AEP.csv', 16062),
#   ('LMT.csv', 16061),
#   ('RTX.csv', 15999),
#   ('MCD.csv', 14927),
#   ('FCIT.L.csv', 14660),
#   ('SMT.L.csv', 14660)],
#  1: [('F.csv', 13463),
#   ('LLY.csv', 13463),
#   ('HAL.csv', 13463),
#   ('PCG.csv', 13463),
#   ('AXP.csv', 13463),
#   ('EMR.csv', 13463),
#   ('PFE.csv', 13463),
#   ('DE.csv', 13463),
#   ('TXN.csv', 13463),
#   ('BMY.csv', 13463),
#   ('ETN.csv', 13463),
#   ('DD.csv', 13463),
#   ('ETR.csv', 13463),
#   ('WFC.csv', 13463),
#   ('PEP.csv', 13463),
#   ('WMT.csv', 13403),
#   ('WBA.csv', 13345)],
#  2: [('AIG.csv', 13317),
#   ('ES.csv', 13283),
#   ('CLX.csv', 13283),
#   ('CVS.csv', 13283),
#   ('VMC.csv', 13283),
#   ('BDX.csv', 13283),
#   ('EVRG.csv', 13283),
#   ('MKC.csv', 13283),
#   ('BAC.csv', 13283),
#   ('TGT.csv', 13283),
#   ('K.csv', 13283),
#   ('RVTY.csv', 13283),
#   ('CMS.csv', 13283),
#   ('BALL.csv', 13283),
#   ('TER.csv', 13283),
#   ('MMC.csv', 13283),
#   ('XEL.csv', 13283),
#   ('NEE.csv', 13283),
#   ('NI.csv', 13283),
#   ('ECL.csv', 13283),
#   ('CMI.csv', 13283),
#   ('PNW.csv', 13283),
#   ('CPB.csv', 13283),
#   ('AVY.csv', 13283),
#   ('SPGI.csv', 13283),
#   ('TXT.csv', 13283),
#   ('LNT.csv', 13283),
#   ('SNA.csv', 13283),
#   ('GWW.csv', 13283),
#   ('ITW.csv', 13269)],
#  3: [('CL.csv', 13234),
#   ('MDT.csv', 13234),
#   ('EXC.csv', 13234),
#   ('BK.csv', 13233),
#   ('USB.csv', 13233),
#   ('FRT.csv', 13233),
#   ('EIX.csv', 13233),
#   ('PNR.csv', 13233),
#   ('WY.csv', 13233),
#   ('SYY.csv', 13230)],
#  4: [('PEG.csv', 11549),
#   ('UNP.csv', 11549),
#   ('LUV.csv', 11549),
#   ('BIO.csv', 11510),
#   ('TYL.csv', 11497),
#   ('CAG.csv', 11497),
#   ('HAS.csv', 11497),
#   ('RHI.csv', 11497),
#   ('MAS.csv', 11497),
#   ('TT.csv', 11497),
#   ('NUE.csv', 11497),
#   ('ABT.csv', 11497),
#   ('IPG.csv', 11497),
#   ('VTRS.csv', 11497),
#   ('J.csv', 11497),
#   ('JPM.csv', 11497),
#   ('NTRS.csv', 11497),
#   ('PCAR.csv', 11497),
#   ('WST.csv', 11497),
#   ('WEC.csv', 11497),
#   ('PH.csv', 11497),
#   ('ADM.csv', 11497),
#   ('OMC.csv', 11497),
#   ('CINF.csv', 11497),
#   ('AMD.csv', 11497),
#   ('GIS.csv', 11497),
#   ('FITB.csv', 11497),
#   ('PPL.csv', 11497),
#   ('EQT.csv', 11497),
#   ('DOV.csv', 11497),
#   ('SWK.csv', 11497),
#   ('TFX.csv', 11497),
#   ('INTC.csv', 11497),
#   ('ADI.csv', 11497),
#   ('AFL.csv', 11497),
#   ('STT.csv', 11497),
#   ('PGR.csv', 11497),
#   ('CMA.csv', 11497),
#   ('SHW.csv', 11497),
#   ('UDR.csv', 11497),
#   ('D.csv', 11497),
#   ('SYK.csv', 11497),
#   ('ROL.csv', 11497),
#   ('CHD.csv', 11497),
#   ('HSY.csv', 11497),
#   ('CMCSA.csv', 11497),
#   ('HRL.csv', 11497),
#   ('LEN.csv', 11497),
#   ('TMO.csv', 11497),
#   ('TSN.csv', 11497),
#   ('AMAT.csv', 11497),
#   ('RF.csv', 11497),
#   ('LOW.csv', 11497),
#   ('HBAN.csv', 11497),
#   ('EFX.csv', 11497),
#   ('MTB.csv', 11497),
#   ('FMC.csv', 11497),
#   ('L.csv', 11497),
#   ('GPC.csv', 11497),
#   ('PHM.csv', 11497),
#   ('PPG.csv', 11497),
#   ('APD.csv', 11497),
#   ('NEM.csv', 11497),
#   ('DUK.csv', 11497),
#   ('KMB.csv', 11497),
#   ('ADP.csv', 11497),
#   ('HST.csv', 11497),
#   ('NDSN.csv', 11496),
#   ('TFC.csv', 11496),
#   ('WELL.csv', 11495),
#   ('AON.csv', 11444)],
#  5: [('GL.csv', 11359),
#   ('OKE.csv', 11359),
#   ('KLAC.csv', 11354),
#   ('CSX.csv', 11336),
#   ('PSA.csv', 11326),
#   ('NKE.csv', 11317),
#   ('AAPL.csv', 11309)],
#  6: [('UHS.csv', 11166),
#   ('HD.csv', 11114),
#   ('BAX.csv', 11089),
#   ('GLW.csv', 11044),
#   ('OXY.csv', 11044),
#   ('SO.csv', 11044),
#   ('SLB.csv', 11044),
#   ('LHX.csv', 11044),
#   ('COP.csv', 11044),
#   ('HUM.csv', 11044),
#   ('NOC.csv', 11044),
#   ('ROK.csv', 11044),
#   ('WMB.csv', 11044),
#   ('VLO.csv', 11043),
#   ('CI.csv', 10982),
#   ('BBWI.csv', 10981),
#   ('NSC.csv', 10939)],
#  7: [('AMGN.csv', 10674),
#   ('RJF.csv', 10664),
#   ('CAH.csv', 10641),
#   ('CTAS.csv', 10630),
#   ('PAYX.csv', 10625),
#   ('BEN.csv', 10606),
#   ('AOS.csv', 10601),
#   ('VZ.csv', 10565),
#   ('T.csv', 10565),
#   ('JBHT.csv', 10564),
#   ('ATO.csv', 10540),
#   ('LRCX.csv', 10451)],
#  8: [('MU.csv', 10432),
#   ('AJG.csv', 10419),
#   ('AME.csv', 10399),
#   ('SWKS.csv', 10364),
#   ('EXPD.csv', 10351)],
#  9: [('BBY.csv', 10210),
#   ('DOC.csv', 10185),
#   ('ADSK.csv', 10160),
#   ('NVR.csv', 10145),
#   ('DVN.csv', 10145),
#   ('ROST.csv', 10132),
#   ('JKHY.csv', 10060),
#   ('MNST.csv', 10048),
#   ('ORCL.csv', 9984),
#   ('MSFT.csv', 9983),
#   ('TROW.csv', 9970),
#   ('COST.csv', 9902),
#   ('ADBE.csv', 9877)],
#  10: [('FI.csv', 9847),
#   ('BKR.csv', 9714),
#   ('CDNS.csv', 9669),
#   ('TJX.csv', 9657),
#   ('FICO.csv', 9640),
#   ('CCL.csv', 9638),
#   ('FAST.csv', 9619),
#   ('DGE.L.csv', 9615),
#   ('SCHW.csv', 9597),
#   ('JCI.csv', 9593),
#   ('RS1.L.csv', 9573),
#   ('ABF.L.csv', 9573),
#   ('TSCO.L.csv', 9573),
#   ('TW.L.csv', 9573),
#   ('RR.L.csv', 9573),
#   ('DPLM.L.csv', 9573),
#   ('SMIN.L.csv', 9573),
#   ('RKT.L.csv', 9573),
#   ('AHT.L.csv', 9573),
#   ('MKS.L.csv', 9573),
#   ('BA.L.csv', 9573),
#   ('WTB.L.csv', 9573),
#   ('RIO.L.csv', 9573),
#   ('BT-A.L.csv', 9573),
#   ('ANTO.L.csv', 9573),
#   ('PSON.L.csv', 9573),
#   ('LAND.L.csv', 9573),
#   ('STAN.L.csv', 9573),
#   ('KGF.L.csv', 9573),
#   ('REL.L.csv', 9573),
#   ('LGEN.L.csv', 9573),
#   ('BNZL.L.csv', 9573),
#   ('IMI.L.csv', 9573),
#   ('SDR.L.csv', 9573),
#   ('AV.L.csv', 9573),
#   ('WEIR.L.csv', 9573),
#   ('BARC.L.csv', 9573),
#   ('RTO.L.csv', 9573),
#   ('HLMA.L.csv', 9573),
#   ('ULVR.L.csv', 9573),
#   ('SBRY.L.csv', 9573),
#   ('GSK.L.csv', 9573),
#   ('PRU.L.csv', 9573),
#   ('PSN.L.csv', 9573),
#   ('BKG.L.csv', 9573),
#   ('SPX.L.csv', 9573),
#   ('NXT.L.csv', 9573),
#   ('SGRO.L.csv', 9573),
#   ('NWG.L.csv', 9573),
#   ('CRDA.L.csv', 9572),
#   ('BP.L.csv', 9572),
#   ('SN.L.csv', 9572),
#   ('HSBA.L.csv', 9571),
#   ('KEY.csv', 9565),
#   ('MOS.csv', 9510),
#   ('BN.PA.csv', 9495),
#   ('VOD.L.csv', 9491),
#   ('MGM.csv', 9443)],
#  11: [('TECH.csv', 9246),
#   ('SVT.L.csv', 9197),
#   ('UU.L.csv', 9197),
#   ('SGE.L.csv', 9195),
#   ('IEX.csv', 9168),
#   ('GEN.csv', 9153),
#   ('EA.csv', 9092),
#   ('EOG.csv', 9082),
#   ('CS.PA.csv', 9076),
#   ('PTC.csv', 9036),
#   ('STJ.L.csv', 9011),
#   ('CTRA.csv', 8994),
#   ('CSCO.csv', 8988),
#   ('EN.PA.csv', 8980),
#   ('HOLX.csv', 8980),
#   ('LH.csv', 8960),
#   ('TRMB.csv', 8882)],
#  12: [('AZO.csv', 8706),
#   ('REGN.csv', 8706),
#   ('IDXX.csv', 8649),
#   ('AES.csv', 8646),
#   ('VRTX.csv', 8627),
#   ('TEP.PA.csv', 8615),
#   ('ZBRA.csv', 8611),
#   ('BIIB.csv', 8589),
#   ('ODFL.csv', 8562),
#   ('APH.csv', 8551),
#   ('KIM.csv', 8541),
#   ('QCOM.csv', 8527),
#   ('HWDN.L.csv', 8519),
#   ('GILD.csv', 8501),
#   ('ROP.csv', 8485),
#   ('SNPS.csv', 8477),
#   ('STZ.csv', 8463),
#   ('MHK.csv', 8452),
#   ('BSX.csv', 8419),
#   ('STE.csv', 8411),
#   ('DHI.csv', 8407),
#   ('LIN.csv', 8399),
#   ('SBUX.csv', 8392)],
#  13: [('BNP.PA.csv', 8255),
#   ('MTCH.csv', 8250),
#   ('SPY.csv', 8242),
#   ('MS.csv', 8226),
#   ('INTU.csv', 8213),
#   ('MCHP.csv', 8208),
#   ('CB.csv', 8204),
#   ('ORLY.csv', 8184),
#   ('RCL.csv', 8181),
#   ('JBL.csv', 8178),
#   ('AZN.csv', 8171),
#   ('ALL.csv', 8156),
#   ('EQR.csv', 8107)],
#  14: [('IT.csv', 8070),
#   ('DECK.csv', 8062),
#   ('REG.csv', 8052),
#   ('INCY.csv', 8048),
#   ('EMN.csv', 8021),
#   ('SPG.csv', 8021),
#   ('III.L.csv', 7996),
#   ('MAA.csv', 7989),
#   ('TSCO.csv', 7975),
#   ('MLM.csv', 7975),
#   ('ALB.csv', 7973),
#   ('AVB.csv', 7960),
#   ('CPRT.csv', 7956)],
#  15: [('WPP.L.csv', 7816),
#   ('O.csv', 7808),
#   ('SJM.csv', 7799),
#   ('MCO.csv', 7799),
#   ('MCK.csv', 7791),
#   ('PARA.csv', 7787),
#   ('COF.csv', 7787)],
#  16: [('COR.csv', 7692),
#   ('MDY.csv', 7671),
#   ('DRI.csv', 7668),
#   ('RMD.csv', 7651),
#   ('WAB.csv', 7641),
#   ('NG.L.csv', 7632),
#   ('FCX.csv', 7626),
#   ('LLOY.L.csv', 7619),
#   ('IVZ.csv', 7592),
#   ('ACGL.csv', 7579),
#   ('EG.csv', 7566),
#   ('POOL.csv', 7558),
#   ('DVA.csv', 7546),
#   ('HSIC.csv', 7543),
#   ('EL.csv', 7533),
#   ('WAT.csv', 7533),
#   ('NTAP.csv', 7531),
#   ('HIG.csv', 7514)],
#  17: [('BMW.DE.csv', 7421),
#   ('SIE.DE.csv', 7421),
#   ('IMB.L.csv', 7420),
#   ('DBK.DE.csv', 7415),
#   ('DTE.DE.csv', 7415)],
#  18: [('JD.L.csv', 7406),
#   ('CBK.DE.csv', 7395),
#   ('ALV.DE.csv', 7395),
#   ('BAYN.DE.csv', 7395),
#   ('RWE.DE.csv', 7395),
#   ('BAS.DE.csv', 7395),
#   ('CON.DE.csv', 7395)],
#  19: [('KMX.csv', 7227),
#   ('ERF.PA.csv', 7205),
#   ('TTWO.csv', 7179),
#   ('VTR.csv', 7165),
#   ('AMZN.csv', 7157),
#   ('ARE.csv', 7149),
#   ('RL.csv', 7138),
#   ('BXP.csv', 7134)],
#  20: [('YUM.csv', 7071),
#   ('TSM.csv', 7055),
#   ('SAP.DE.csv', 7052),
#   ('CHRW.csv', 7050),
#   ('FE.csv', 7033),
#   ('MTD.csv', 7029),
#   ('PLD.csv', 7024),
#   ('URI.csv', 7006),
#   ('MUV2.DE.csv', 6998),
#   ('ADS.DE.csv', 6998),
#   ('HEN3.DE.csv', 6997),
#   ('AEE.csv', 6997),
#   ('MRK.DE.csv', 6996),
#   ('DIA.csv', 6986),
#   ('BEI.DE.csv', 6978),
#   ('QIA.DE.csv', 6978),
#   ('VRSN.csv', 6978),
#   ('VOW3.DE.csv', 6978),
#   ('HEI.DE.csv', 6975),
#   ('PWR.csv', 6969),
#   ('RHM.DE.csv', 6968),
#   ('AMT.csv', 6959),
#   ('FLTR.L.csv', 6945),
#   ('MAR.csv', 6943)],
#  21: [('FRE.DE.csv', 6900),
#   ('AIR.DE.csv', 6899),
#   ('MSTR.csv', 6887),
#   ('CTSH.csv', 6881),
#   ('SRE.csv', 6875),
#   ('CSGP.csv', 6873),
#   ('RSG.csv', 6873),
#   ('INF.L.csv', 6841),
#   ('CCI.csv', 6840)],
#  22: [('SRT3.DE.csv', 6778),
#   ('XLV.csv', 6752),
#   ('XLY.csv', 6752),
#   ('XLE.csv', 6752),
#   ('XLI.csv', 6752),
#   ('XLF.csv', 6752),
#   ('XLK.csv', 6752),
#   ('NVDA.csv', 6732),
#   ('AAL.L.csv', 6732),
#   ('UTG.L.csv', 6726),
#   ('QQQ.csv', 6700)],
#  23: [('GS.csv', 6662),
#   ('FFIV.csv', 6640),
#   ('RMS.PA.csv', 6635),
#   ('RI.PA.csv', 6635),
#   ('SGO.PA.csv', 6635),
#   ('SU.PA.csv', 6635),
#   ('SAN.PA.csv', 6635),
#   ('DG.PA.csv', 6635),
#   ('DSY.PA.csv', 6635),
#   ('CAP.PA.csv', 6635),
#   ('KER.PA.csv', 6635),
#   ('RNO.PA.csv', 6635),
#   ('GLE.PA.csv', 6635),
#   ('MC.PA.csv', 6635),
#   ('ENGI.PA.csv', 6635),
#   ('ORA.PA.csv', 6635),
#   ('EL.PA.csv', 6635),
#   ('SAF.PA.csv', 6635),
#   ('OR.PA.csv', 6635),
#   ('HO.PA.csv', 6635),
#   ('TTE.PA.csv', 6635),
#   ('AI.PA.csv', 6635),
#   ('ML.PA.csv', 6635),
#   ('CA.PA.csv', 6635),
#   ('SBAC.csv', 6632)],
#  24: [('EOAN.DE.csv', 6600),
#   ('ATCO-B.ST.csv', 6577),
#   ('CPG.L.csv', 6571),
#   ('DCC.L.csv', 6571),
#   ('BLK.csv', 6557),
#   ('ERIC-B.ST.csv', 6554),
#   ('AZN.ST.csv', 6554),
#   ('SKA-B.ST.csv', 6554),
#   ('ASSA-B.ST.csv', 6554),
#   ('SHB-A.ST.csv', 6554),
#   ('HEXA-B.ST.csv', 6554),
#   ('SWED-A.ST.csv', 6554),
#   ('GETI-B.ST.csv', 6554),
#   ('ELUX-B.ST.csv', 6554),
#   ('NDA-SE.ST.csv', 6554),
#   ('SKF-B.ST.csv', 6554),
#   ('ALIV-SDB.ST.csv', 6554),
#   ('TEL2-B.ST.csv', 6554),
#   ('ATCO-A.ST.csv', 6554),
#   ('SAND.ST.csv', 6554),
#   ('INVE-B.ST.csv', 6554),
#   ('VOLV-B.ST.csv', 6554),
#   ('HM-B.ST.csv', 6554),
#   ('SEB-A.ST.csv', 6554),
#   ('SCA-B.ST.csv', 6554),
#   ('KINV-B.ST.csv', 6554),
#   ('IFX.DE.csv', 6550),
#   ('AKAM.csv', 6537),
#   ('UPS.csv', 6529),
#   ('A.csv', 6523),
#   ('TDY.csv', 6520)],
#  25: [('PUB.PA.csv', 6449),
#   ('TELIA.ST.csv', 6438),
#   ('EW.csv', 6435),
#   ('MET.csv', 6428),
#   ('ON.csv', 6410),
#   ('IWB.csv', 6397),
#   ('IYW.csv', 6397),
#   ('IVV.csv', 6397),
#   ('IVW.csv', 6392),
#   ('IVE.csv', 6392),
#   ('IJH.csv', 6392),
#   ('IJR.csv', 6392),
#   ('IWM.csv', 6392),
#   ('IWF.csv', 6392),
#   ('IWD.csv', 6392),
#   ('HNR1.DE.csv', 6390),
#   ('SMH.csv', 6387),
#   ('ISRG.csv', 6378),
#   ('CRL.csv', 6373),
#   ('MRVL.csv', 6368),
#   ('IUSG.csv', 6349),
#   ('ILMN.csv', 6349),
#   ('EZJ.L.csv', 6345),
#   ('IUSV.csv', 6344),
#   ('EQIX.csv', 6339),
#   ('DHL.DE.csv', 6320),
#   ('DB1.DE.csv', 6315),
#   ('SPYG.csv', 6304),
#   ('SPYV.csv', 6304),
#   ('TPR.csv', 6300)],
#  26: [('GPN.csv', 6232),
#   ('ALGN.csv', 6222),
#   ('ABB.ST.csv', 6203),
#   ('STLAP.PA.csv', 6200),
#   ('STMPA.PA.csv', 6200),
#   ('AIR.PA.csv', 6200)],
#  27: [('LSEG.L.csv', 6168),
#   ('WTW.csv', 6130),
#   ('MDLZ.csv', 6129),
#   ('VTI.csv', 6127),
#   ('ACA.PA.csv', 6126),
#   ('AXON.csv', 6125),
#   ('FIS.csv', 6124),
#   ('ACN.csv', 6104),
#   ('ZBH.csv', 6100),
#   ('BG.csv', 6094),
#   ('IWR.csv', 6077),
#   ('EFA.csv', 6077),
#   ('PFG.csv', 6041)],
#  28: [('ITRK.L.csv', 5948),
#   ('BRBY.L.csv', 5913),
#   ('FRAS.L.csv', 5900),
#   ('NFLX.csv', 5895),
#   ('NDAQ.csv', 5869),
#   ('TLT.csv', 5849),
#   ('SHY.csv', 5849),
#   ('IEF.csv', 5849),
#   ('LQD.csv', 5849),
#   ('BEZ.L.csv', 5826)],
#  29: [('MRO.L.csv', 5576),
#   ('AGG.csv', 5555),
#   ('LKQ.csv', 5550),
#   ('DVY.csv', 5526),
#   ('NRG.csv', 5510),
#   ('ITOT.csv', 5475),
#   ('VUG.csv', 5470),
#   ('VTV.csv', 5470),
#   ('VO.csv', 5470),
#   ('VHT.csv', 5470),
#   ('VGT.csv', 5470),
#   ('VV.csv', 5470),
#   ('VB.csv', 5470),
#   ('VBR.csv', 5470),
#   ('AIZ.csv', 5466)],
#  30: [('CBRE.csv', 5379),
#   ('CRM.csv', 5371),
#   ('DPZ.csv', 5358),
#   ('ADM.L.csv', 5339),
#   ('EXR.csv', 5334),
#   ('GOOGL.csv', 5331),
#   ('GOOG.csv', 5331),
#   ('VNQ.csv', 5303),
#   ('DLR.csv', 5281),
#   ('MKTX.csv', 5276),
#   ('ENT.L.csv', 5276),
#   ('GLD.csv', 5267),
#   ('MPWR.csv', 5266),
#   ('LVS.csv', 5249),
#   ('CE.csv', 5224),
#   ('IAU.csv', 5219),
#   ('VWO.csv', 5191),
#   ('VGK.csv', 5191),
#   ('MT.AS.csv', 5190),
#   ('MTX.DE.csv', 5185),
#   ('ALO.PA.csv', 5178),
#   ('DXCM.csv', 5167),
#   ('BLDR.csv', 5115)],
#  31: [('WBD.csv', 5108),
#   ('EXPE.csv', 5099),
#   ('EFV.csv', 5088),
#   ('CF.csv', 5084),
#   ('AMP.csv', 5060),
#   ('AAL.csv', 5052),
#   ('HIK.L.csv', 5051),
#   ('SDY.csv', 5017),
#   ('SPLG.csv', 5017),
#   ('ICE.csv', 5016),
#   ('LR.PA.csv', 5001),
#   ('LYV.csv', 4992),
#   ('CMG.csv', 4969),
#   ('UAL.csv', 4962),
#   ('RMV.L.csv', 4959),
#   ('TDG.csv', 4936)],
#  32: [('LDOS.csv', 4786),
#   ('VYM.csv', 4764),
#   ('FSLR.csv', 4763),
#   ('IGSB.csv', 4728),
#   ('SHV.csv', 4728),
#   ('SKG.L.csv', 4703),
#   ('VEU.csv', 4690),
#   ('MBB.csv', 4684),
#   ('BR.csv', 4680),
#   ('SMCI.csv', 4675),
#   ('BND.csv', 4668),
#   ('BIV.csv', 4668),
#   ('BSV.csv', 4668),
#   ('TMUS.csv', 4661),
#   ('SPDW.csv', 4656),
#   ('DAL.csv', 4651),
#   ('PODD.csv', 4643),
#   ('BIL.csv', 4633),
#   ('MNDI.L.csv', 4631),
#   ('TEL.csv', 4622),
#   ('BX.csv', 4616),
#   ('VEA.csv', 4593),
#   ('LULU.csv', 4592),
#   ('MELI.csv', 4582),
#   ('MUB.csv', 4562)],
#  33: [('ULTA.csv', 4529),
#   ('MGK.csv', 4486),
#   ('PM.csv', 4432),
#   ('V.csv', 4430),
#   ('ACWI.csv', 4424),
#   ('FRES.L.csv', 4413),
#   ('AWK.csv', 4406),
#   ('KDP.csv', 4396)],
#  34: [('VRSK.csv', 4038),
#   ('PHNX.L.csv', 4026),
#   ('SCHX.csv', 4019),
#   ('SCHF.csv', 4019),
#   ('SCHB.csv', 4019),
#   ('DG.csv', 4011),
#   ('FTNT.csv', 4008),
#   ('VCIT.csv', 4005),
#   ('VGSH.csv', 4005),
#   ('VCSH.csv', 4005),
#   ('VGIT.csv', 4005),
#   ('SCHG.csv', 3978),
#   ('CHTR.csv', 3977),
#   ('BNR.DE.csv', 3960),
#   ('TQQQ.csv', 3951),
#   ('GNRC.csv', 3951)],
#  35: [('LYB.csv', 3899),
#   ('OCDO.L.csv', 3857),
#   ('TSLA.csv', 3856),
#   ('NXPI.csv', 3829),
#   ('VOO.csv', 3806),
#   ('GM.csv', 3756),
#   ('VXUS.csv', 3708),
#   ('KMI.csv', 3698)],
#  36: [('GOVT.csv', 3438),
#   ('ENPH.csv', 3413),
#   ('PSX.csv', 3405),
#   ('AMCR.csv', 3382),
#   ('META.csv', 3379),
#   ('PANW.csv', 3336)],
#  37: [('FANG.csv', 3277),
#   ('WDAY.csv', 3277),
#   ('IEFA.csv', 3269),
#   ('IXUS.csv', 3269),
#   ('IEMG.csv', 3269),
#   ('ABBV.csv', 3224)],
#  38: [('NCLH.csv', 3212),
#   ('CCH.L.csv', 3158),
#   ('IQV.csv', 3136),
#   ('VNA.DE.csv', 3122),
#   ('BNDX.csv', 3119),
#   ('NWS.csv', 3108),
#   ('NWSA.csv', 3108),
#   ('CDW.csv', 3102),
#   ('QUAL.csv', 3088)],
#  39: [('WLN.PA.csv', 2902),
#   ('PAYC.csv', 2901),
#   ('BME.L.csv', 2874),
#   ('ANET.csv', 2865),
#   ('DGRO.csv', 2861),
#   ('IUSB.csv', 2861),
#   ('SYF.csv', 2827),
#   ('ZAL.DE.csv', 2812),
#   ('CZR.csv', 2791),
#   ('CFG.csv', 2789),
#   ('KEYS.csv', 2771),
#   ('QRVO.csv', 2720)],
#  40: [('ETSY.csv', 2649),
#   ('SHOP.csv', 2625),
#   ('PYPL.csv', 2594),
#   ('KHC.csv', 2594),
#   ('1COV.DE.csv', 2558),
#   ('VTEB.csv', 2558),
#   ('SINCH.ST.csv', 2528)],
#  41: [('FTV.csv', 2342),
#   ('TTD.csv', 2287),
#   ('CTEC.L.csv', 2272),
#   ('HWM.csv', 2258),
#   ('LW.csv', 2251),
#   ('COWZ.csv', 2222),
#   ('INVH.csv', 2196)],
#  -1: [('HUBB.csv', 13341),
#   ('WRB.csv', 13113),
#   ('IFF.csv', 12822),
#   ('TAP.csv', 12700),
#   ('TRV.csv', 12590),
#   ('PNC.csv', 12590),
#   ('C.csv', 12306),
#   ('FDX.csv', 11985),
#   ('WDC.csv', 11844),
#   ('DHR.csv', 11803),
#   ('APA.csv', 11709),
#   ('BRO.csv', 11268),
#   ('COO.csv', 10776),
#   ('UNH.csv', 10336),
#   ('CCEP.csv', 9805),
#   ('WM.csv', 9407),
#   ('SSE.L.csv', 8802),
#   ('AZN.L.csv', 8298),
#   ('CPT.csv', 8122),
#   ('BWA.csv', 8106),
#   ('ESS.csv', 7901),
#   ('BATS.L.csv', 7876),
#   ('DLTR.csv', 7712),
#   ('ASML.csv', 7706),
#   ('IRM.csv', 7482),
#   ('SHEL.L.csv', 7444),
#   ('MBG.DE.csv', 7428),
#   ('FDS.csv', 7379),
#   ('CNA.L.csv', 7322),
#   ('STLD.csv', 7276),
#   ('DGX.csv', 7260),
#   ('EBAY.csv', 6814),
#   ('BKNG.csv', 6685),
#   ('VIE.PA.csv', 6492),
#   ('PKG.csv', 6475),
#   ('GRMN.csv', 6256),
#   ('BOL.ST.csv', 6052),
#   ('ELV.csv', 6036),
#   ('CNC.csv', 6005),
#   ('PRU.csv', 6005),
#   ('VXF.csv', 5991),
#   ('ALFA.ST.csv', 5935),
#   ('WYNN.csv', 5787),
#   ('IAG.L.csv', 5784),
#   ('CME.csv', 5758),
#   ('STX.csv', 5755),
#   ('IHG.L.csv', 5727),
#   ('RSP.csv', 5659),
#   ('MOH.csv', 5616),
#   ('VIG.csv', 4903),
#   ('MA.csv', 4886),
#   ('EXPN.L.csv', 4813),
#   ('SY1.DE.csv', 4793),
#   ('MSCI.csv', 4514),
#   ('VT.csv', 4361),
#   ('PAH3.DE.csv', 4256),
#   ('AVGO.csv', 4081),
#   ('EDEN.PA.csv', 3922),
#   ('CBOE.csv', 3866),
#   ('VONG.csv', 3797),
#   ('TRGP.csv', 3744),
#   ('CPAY.csv', 3738),
#   ('HCA.csv', 3680),
#   ('HII.csv', 3672),
#   ('GLEN.L.csv', 3646),
#   ('MPC.csv', 3606),
#   ('XYL.csv', 3529),
#   ('SCHD.csv', 3524),
#   ('USMV.csv', 3524),
#   ('APTV.csv', 3504),
#   ('EPAM.csv', 3449),
#   ('NOW.csv', 3350),
#   ('ZTS.csv', 3203),
#   ('ALLE.csv', 3002),
#   ('HLT.csv', 2985),
#   ('AUTO.L.csv', 2679),
#   ('EVO.ST.csv', 2667),
#   ('HPE.csv', 2520),
#   ('TEAM.csv', 2484)]}

# %%
# to get a big table for all stocks
dataframes_vol = []
for cluster_id in range(len(clusters)-1):
   
    for filename, rows in clusters[cluster_id]:
        print(f"File: {filename}, Rows: {rows}")
        # make one single pandas dataframe contains the data from above stock IDs, the index is the data, the columns are the stock IDs
        stock_id = filename[:-4]  

        file_path = Path(data_directory) / filename
        df_vol = pd.read_csv(file_path, usecols=['Date', 'Adj Close', 'Volume'], parse_dates=['Date'])
        df_vol.set_index('Date', inplace=True)
        df_vol.rename(columns={'Adj Close': f"{stock_id}_price", 'Volume': f"{stock_id}_vol"}, inplace=True)
        dataframes_vol.append(df_vol)

combined_df_vol = pd.concat(dataframes_vol, axis=1)

price_columns = [col for col in combined_df_vol.columns if col.endswith('_price')]
volume_columns = [col for col in combined_df_vol.columns if col.endswith('_vol')]

combined_df_vol[price_columns] = (
    combined_df_vol[price_columns]
        .ffill()
        .bfill()
)

combined_df_vol[volume_columns] = (
    combined_df_vol[volume_columns].fillna(0)
)

log_returns_df_vol = np.log(combined_df_vol / (combined_df_vol.shift(1) + 1e-9 ) + 1e-9)
# drop the first row
#log_returns_df_vol = log_returns_df_vol.iloc[1:]
log_returns_df_vol = log_returns_df_vol.dropna()  # Drop the first row with

price_columns = [col for col in log_returns_df_vol.columns if col.endswith('_price')]
volume_columns = [col for col in log_returns_df_vol.columns if col.endswith('_vol')]
log_returns_df_vol = log_returns_df_vol[price_columns + volume_columns]
# find out the earliest date in the dataframe
start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
log_returns_df_vol.to_csv(f"stock_data_vol-all-in-one-startdate-{start_date}.csv")
# Out:
# File: HPQ.csv, Rows: 16062
# File: PG.csv, Rows: 16062
# File: IP.csv, Rows: 16062
# File: DIS.csv, Rows: 16062
# File: MRK.csv, Rows: 16062
# File: HON.csv, Rows: 16062
# File: CAT.csv, Rows: 16062
# File: GE.csv, Rows: 16062
# File: IBM.csv, Rows: 16062
# File: GD.csv, Rows: 16062
# File: JNJ.csv, Rows: 16062
# File: ED.csv, Rows: 16062
# File: DTE.csv, Rows: 16062
# File: XOM.csv, Rows: 16062
# File: MMM.csv, Rows: 16062
# File: CVX.csv, Rows: 16062
# File: BA.csv, Rows: 16062
# File: KO.csv, Rows: 16062
# File: MSI.csv, Rows: 16062
# File: CNP.csv, Rows: 16062
# File: MO.csv, Rows: 16062
# File: KR.csv, Rows: 16062
# File: AEP.csv, Rows: 16062
# File: LMT.csv, Rows: 16061
# File: RTX.csv, Rows: 15999
# File: MCD.csv, Rows: 14927
# File: FCIT.L.csv, Rows: 14660
# File: SMT.L.csv, Rows: 14660
# File: F.csv, Rows: 13463
# File: LLY.csv, Rows: 13463
# File: HAL.csv, Rows: 13463
# File: PCG.csv, Rows: 13463
# File: AXP.csv, Rows: 13463
# File: EMR.csv, Rows: 13463
# File: PFE.csv, Rows: 13463
# File: DE.csv, Rows: 13463
# File: TXN.csv, Rows: 13463
# File: BMY.csv, Rows: 13463
# File: ETN.csv, Rows: 13463
# File: DD.csv, Rows: 13463
# File: ETR.csv, Rows: 13463
# File: WFC.csv, Rows: 13463
# File: PEP.csv, Rows: 13463
# File: WMT.csv, Rows: 13403
# File: WBA.csv, Rows: 13345
# File: AIG.csv, Rows: 13317
# File: ES.csv, Rows: 13283
# File: CLX.csv, Rows: 13283
# File: CVS.csv, Rows: 13283
# File: VMC.csv, Rows: 13283
# File: BDX.csv, Rows: 13283
# File: EVRG.csv, Rows: 13283
# File: MKC.csv, Rows: 13283
# File: BAC.csv, Rows: 13283
# File: TGT.csv, Rows: 13283
# File: K.csv, Rows: 13283
# File: RVTY.csv, Rows: 13283
# File: CMS.csv, Rows: 13283
# File: BALL.csv, Rows: 13283
# File: TER.csv, Rows: 13283
# File: MMC.csv, Rows: 13283
# File: XEL.csv, Rows: 13283
# File: NEE.csv, Rows: 13283
# File: NI.csv, Rows: 13283
# File: ECL.csv, Rows: 13283
# File: CMI.csv, Rows: 13283
# File: PNW.csv, Rows: 13283
# File: CPB.csv, Rows: 13283
# File: AVY.csv, Rows: 13283
# File: SPGI.csv, Rows: 13283
# File: TXT.csv, Rows: 13283
# File: LNT.csv, Rows: 13283
# File: SNA.csv, Rows: 13283
# File: GWW.csv, Rows: 13283
# File: ITW.csv, Rows: 13269
# File: CL.csv, Rows: 13234
# File: MDT.csv, Rows: 13234
# File: EXC.csv, Rows: 13234
# File: BK.csv, Rows: 13233
# File: USB.csv, Rows: 13233
# File: FRT.csv, Rows: 13233
# File: EIX.csv, Rows: 13233
# File: PNR.csv, Rows: 13233
# File: WY.csv, Rows: 13233
# File: SYY.csv, Rows: 13230
# File: PEG.csv, Rows: 11549
# File: UNP.csv, Rows: 11549
# File: LUV.csv, Rows: 11549
# File: BIO.csv, Rows: 11510
# File: TYL.csv, Rows: 11497
# File: CAG.csv, Rows: 11497
# File: HAS.csv, Rows: 11497
# File: RHI.csv, Rows: 11497
# File: MAS.csv, Rows: 11497
# File: TT.csv, Rows: 11497
# File: NUE.csv, Rows: 11497
# File: ABT.csv, Rows: 11497
# File: IPG.csv, Rows: 11497
# File: VTRS.csv, Rows: 11497
# File: J.csv, Rows: 11497
# File: JPM.csv, Rows: 11497
# File: NTRS.csv, Rows: 11497
# File: PCAR.csv, Rows: 11497
# File: WST.csv, Rows: 11497
# File: WEC.csv, Rows: 11497
# File: PH.csv, Rows: 11497
# File: ADM.csv, Rows: 11497
# File: OMC.csv, Rows: 11497
# File: CINF.csv, Rows: 11497
# File: AMD.csv, Rows: 11497
# File: GIS.csv, Rows: 11497
# File: FITB.csv, Rows: 11497
# File: PPL.csv, Rows: 11497
# File: EQT.csv, Rows: 11497
# File: DOV.csv, Rows: 11497
# File: SWK.csv, Rows: 11497
# File: TFX.csv, Rows: 11497
# File: INTC.csv, Rows: 11497
# File: ADI.csv, Rows: 11497
# File: AFL.csv, Rows: 11497
# File: STT.csv, Rows: 11497
# File: PGR.csv, Rows: 11497
# File: CMA.csv, Rows: 11497
# File: SHW.csv, Rows: 11497
# File: UDR.csv, Rows: 11497
# File: D.csv, Rows: 11497
# File: SYK.csv, Rows: 11497
# File: ROL.csv, Rows: 11497
# File: CHD.csv, Rows: 11497
# File: HSY.csv, Rows: 11497
# File: CMCSA.csv, Rows: 11497
# File: HRL.csv, Rows: 11497
# File: LEN.csv, Rows: 11497
# File: TMO.csv, Rows: 11497
# File: TSN.csv, Rows: 11497
# File: AMAT.csv, Rows: 11497
# File: RF.csv, Rows: 11497
# File: LOW.csv, Rows: 11497
# File: HBAN.csv, Rows: 11497
# File: EFX.csv, Rows: 11497
# File: MTB.csv, Rows: 11497
# File: FMC.csv, Rows: 11497
# File: L.csv, Rows: 11497
# File: GPC.csv, Rows: 11497
# File: PHM.csv, Rows: 11497
# File: PPG.csv, Rows: 11497
# File: APD.csv, Rows: 11497
# File: NEM.csv, Rows: 11497
# File: DUK.csv, Rows: 11497
# File: KMB.csv, Rows: 11497
# File: ADP.csv, Rows: 11497
# File: HST.csv, Rows: 11497
# File: NDSN.csv, Rows: 11496
# File: TFC.csv, Rows: 11496
# File: WELL.csv, Rows: 11495
# File: AON.csv, Rows: 11444
# File: GL.csv, Rows: 11359
# File: OKE.csv, Rows: 11359
# File: KLAC.csv, Rows: 11354
# File: CSX.csv, Rows: 11336
# File: PSA.csv, Rows: 11326
# File: NKE.csv, Rows: 11317
# File: AAPL.csv, Rows: 11309
# File: UHS.csv, Rows: 11166
# File: HD.csv, Rows: 11114
# File: BAX.csv, Rows: 11089
# File: GLW.csv, Rows: 11044
# File: OXY.csv, Rows: 11044
# File: SO.csv, Rows: 11044
# File: SLB.csv, Rows: 11044
# File: LHX.csv, Rows: 11044
# File: COP.csv, Rows: 11044
# File: HUM.csv, Rows: 11044
# File: NOC.csv, Rows: 11044
# File: ROK.csv, Rows: 11044
# File: WMB.csv, Rows: 11044
# File: VLO.csv, Rows: 11043
# File: CI.csv, Rows: 10982
# File: BBWI.csv, Rows: 10981
# File: NSC.csv, Rows: 10939
# File: AMGN.csv, Rows: 10674
# File: RJF.csv, Rows: 10664
# File: CAH.csv, Rows: 10641
# File: CTAS.csv, Rows: 10630
# File: PAYX.csv, Rows: 10625
# File: BEN.csv, Rows: 10606
# File: AOS.csv, Rows: 10601
# File: VZ.csv, Rows: 10565
# File: T.csv, Rows: 10565
# File: JBHT.csv, Rows: 10564
# File: ATO.csv, Rows: 10540
# File: LRCX.csv, Rows: 10451
# File: MU.csv, Rows: 10432
# File: AJG.csv, Rows: 10419
# File: AME.csv, Rows: 10399
# File: SWKS.csv, Rows: 10364
# File: EXPD.csv, Rows: 10351
# File: BBY.csv, Rows: 10210
# File: DOC.csv, Rows: 10185
# File: ADSK.csv, Rows: 10160
# File: NVR.csv, Rows: 10145
# File: DVN.csv, Rows: 10145
# File: ROST.csv, Rows: 10132
# File: JKHY.csv, Rows: 10060
# File: MNST.csv, Rows: 10048
# File: ORCL.csv, Rows: 9984
# File: MSFT.csv, Rows: 9983
# File: TROW.csv, Rows: 9970
# File: COST.csv, Rows: 9902
# File: ADBE.csv, Rows: 9877
# File: FI.csv, Rows: 9847
# File: BKR.csv, Rows: 9714
# File: CDNS.csv, Rows: 9669
# File: TJX.csv, Rows: 9657
# File: FICO.csv, Rows: 9640
# File: CCL.csv, Rows: 9638
# File: FAST.csv, Rows: 9619
# File: DGE.L.csv, Rows: 9615
# File: SCHW.csv, Rows: 9597
# File: JCI.csv, Rows: 9593
# File: RS1.L.csv, Rows: 9573
# File: ABF.L.csv, Rows: 9573
# File: TSCO.L.csv, Rows: 9573
# File: TW.L.csv, Rows: 9573
# File: RR.L.csv, Rows: 9573
# File: DPLM.L.csv, Rows: 9573
# File: SMIN.L.csv, Rows: 9573
# File: RKT.L.csv, Rows: 9573
# File: AHT.L.csv, Rows: 9573
# File: MKS.L.csv, Rows: 9573
# File: BA.L.csv, Rows: 9573
# File: WTB.L.csv, Rows: 9573
# File: RIO.L.csv, Rows: 9573
# File: BT-A.L.csv, Rows: 9573
# File: ANTO.L.csv, Rows: 9573
# File: PSON.L.csv, Rows: 9573
# File: LAND.L.csv, Rows: 9573
# File: STAN.L.csv, Rows: 9573
# File: KGF.L.csv, Rows: 9573
# File: REL.L.csv, Rows: 9573
# File: LGEN.L.csv, Rows: 9573
# File: BNZL.L.csv, Rows: 9573
# File: IMI.L.csv, Rows: 9573
# File: SDR.L.csv, Rows: 9573
# File: AV.L.csv, Rows: 9573
# File: WEIR.L.csv, Rows: 9573
# File: BARC.L.csv, Rows: 9573
# File: RTO.L.csv, Rows: 9573
# File: HLMA.L.csv, Rows: 9573
# File: ULVR.L.csv, Rows: 9573
# File: SBRY.L.csv, Rows: 9573
# File: GSK.L.csv, Rows: 9573
# File: PRU.L.csv, Rows: 9573
# File: PSN.L.csv, Rows: 9573
# File: BKG.L.csv, Rows: 9573
# File: SPX.L.csv, Rows: 9573
# File: NXT.L.csv, Rows: 9573
# File: SGRO.L.csv, Rows: 9573
# File: NWG.L.csv, Rows: 9573
# File: CRDA.L.csv, Rows: 9572
# File: BP.L.csv, Rows: 9572
# File: SN.L.csv, Rows: 9572
# File: HSBA.L.csv, Rows: 9571
# File: KEY.csv, Rows: 9565
# File: MOS.csv, Rows: 9510
# File: BN.PA.csv, Rows: 9495
# File: VOD.L.csv, Rows: 9491
# File: MGM.csv, Rows: 9443
# File: TECH.csv, Rows: 9246
# File: SVT.L.csv, Rows: 9197
# File: UU.L.csv, Rows: 9197
# File: SGE.L.csv, Rows: 9195
# File: IEX.csv, Rows: 9168
# File: GEN.csv, Rows: 9153
# File: EA.csv, Rows: 9092
# File: EOG.csv, Rows: 9082
# File: CS.PA.csv, Rows: 9076
# File: PTC.csv, Rows: 9036
# File: STJ.L.csv, Rows: 9011
# File: CTRA.csv, Rows: 8994
# File: CSCO.csv, Rows: 8988
# File: EN.PA.csv, Rows: 8980
# File: HOLX.csv, Rows: 8980
# File: LH.csv, Rows: 8960
# File: TRMB.csv, Rows: 8882
# File: AZO.csv, Rows: 8706
# File: REGN.csv, Rows: 8706
# File: IDXX.csv, Rows: 8649
# File: AES.csv, Rows: 8646
# File: VRTX.csv, Rows: 8627
# File: TEP.PA.csv, Rows: 8615
# File: ZBRA.csv, Rows: 8611
# File: BIIB.csv, Rows: 8589
# File: ODFL.csv, Rows: 8562
# File: APH.csv, Rows: 8551
# File: KIM.csv, Rows: 8541
# File: QCOM.csv, Rows: 8527
# File: HWDN.L.csv, Rows: 8519
# File: GILD.csv, Rows: 8501
# File: ROP.csv, Rows: 8485
# File: SNPS.csv, Rows: 8477
# File: STZ.csv, Rows: 8463
# File: MHK.csv, Rows: 8452
# File: BSX.csv, Rows: 8419
# File: STE.csv, Rows: 8411
# File: DHI.csv, Rows: 8407
# File: LIN.csv, Rows: 8399
# File: SBUX.csv, Rows: 8392
# File: BNP.PA.csv, Rows: 8255
# File: MTCH.csv, Rows: 8250
# File: SPY.csv, Rows: 8242
# File: MS.csv, Rows: 8226
# File: INTU.csv, Rows: 8213
# File: MCHP.csv, Rows: 8208
# File: CB.csv, Rows: 8204
# File: ORLY.csv, Rows: 8184
# File: RCL.csv, Rows: 8181
# File: JBL.csv, Rows: 8178
# File: AZN.csv, Rows: 8171
# File: ALL.csv, Rows: 8156
# File: EQR.csv, Rows: 8107
# File: IT.csv, Rows: 8070
# File: DECK.csv, Rows: 8062
# File: REG.csv, Rows: 8052
# File: INCY.csv, Rows: 8048
# File: EMN.csv, Rows: 8021
# File: SPG.csv, Rows: 8021
# File: III.L.csv, Rows: 7996
# File: MAA.csv, Rows: 7989
# File: TSCO.csv, Rows: 7975
# File: MLM.csv, Rows: 7975
# File: ALB.csv, Rows: 7973
# File: AVB.csv, Rows: 7960
# File: CPRT.csv, Rows: 7956
# File: WPP.L.csv, Rows: 7816
# File: O.csv, Rows: 7808
# File: SJM.csv, Rows: 7799
# File: MCO.csv, Rows: 7799
# File: MCK.csv, Rows: 7791
# File: PARA.csv, Rows: 7787
# File: COF.csv, Rows: 7787
# File: COR.csv, Rows: 7692
# File: MDY.csv, Rows: 7671
# File: DRI.csv, Rows: 7668
# File: RMD.csv, Rows: 7651
# File: WAB.csv, Rows: 7641
# File: NG.L.csv, Rows: 7632
# File: FCX.csv, Rows: 7626
# File: LLOY.L.csv, Rows: 7619
# File: IVZ.csv, Rows: 7592
# File: ACGL.csv, Rows: 7579
# File: EG.csv, Rows: 7566
# File: POOL.csv, Rows: 7558
# File: DVA.csv, Rows: 7546
# File: HSIC.csv, Rows: 7543
# File: EL.csv, Rows: 7533
# File: WAT.csv, Rows: 7533
# File: NTAP.csv, Rows: 7531
# File: HIG.csv, Rows: 7514
# File: BMW.DE.csv, Rows: 7421
# File: SIE.DE.csv, Rows: 7421
# File: IMB.L.csv, Rows: 7420
# File: DBK.DE.csv, Rows: 7415
# File: DTE.DE.csv, Rows: 7415
# File: JD.L.csv, Rows: 7406
# File: CBK.DE.csv, Rows: 7395
# File: ALV.DE.csv, Rows: 7395
# File: BAYN.DE.csv, Rows: 7395
# File: RWE.DE.csv, Rows: 7395
# File: BAS.DE.csv, Rows: 7395
# File: CON.DE.csv, Rows: 7395
# File: KMX.csv, Rows: 7227
# File: ERF.PA.csv, Rows: 7205
# File: TTWO.csv, Rows: 7179
# File: VTR.csv, Rows: 7165
# File: AMZN.csv, Rows: 7157
# File: ARE.csv, Rows: 7149
# File: RL.csv, Rows: 7138
# File: BXP.csv, Rows: 7134
# File: YUM.csv, Rows: 7071
# File: TSM.csv, Rows: 7055
# File: SAP.DE.csv, Rows: 7052
# File: CHRW.csv, Rows: 7050
# File: FE.csv, Rows: 7033
# File: MTD.csv, Rows: 7029
# File: PLD.csv, Rows: 7024
# File: URI.csv, Rows: 7006
# File: MUV2.DE.csv, Rows: 6998
# File: ADS.DE.csv, Rows: 6998
# File: HEN3.DE.csv, Rows: 6997
# File: AEE.csv, Rows: 6997
# File: MRK.DE.csv, Rows: 6996
# File: DIA.csv, Rows: 6986
# File: BEI.DE.csv, Rows: 6978
# File: QIA.DE.csv, Rows: 6978
# File: VRSN.csv, Rows: 6978
# File: VOW3.DE.csv, Rows: 6978
# File: HEI.DE.csv, Rows: 6975
# File: PWR.csv, Rows: 6969
# File: RHM.DE.csv, Rows: 6968
# File: AMT.csv, Rows: 6959
# File: FLTR.L.csv, Rows: 6945
# File: MAR.csv, Rows: 6943
# File: FRE.DE.csv, Rows: 6900
# File: AIR.DE.csv, Rows: 6899
# File: MSTR.csv, Rows: 6887
# File: CTSH.csv, Rows: 6881
# File: SRE.csv, Rows: 6875
# File: CSGP.csv, Rows: 6873
# File: RSG.csv, Rows: 6873
# File: INF.L.csv, Rows: 6841
# File: CCI.csv, Rows: 6840
# File: SRT3.DE.csv, Rows: 6778
# File: XLV.csv, Rows: 6752
# File: XLY.csv, Rows: 6752
# File: XLE.csv, Rows: 6752
# File: XLI.csv, Rows: 6752
# File: XLF.csv, Rows: 6752
# File: XLK.csv, Rows: 6752
# File: NVDA.csv, Rows: 6732
# File: AAL.L.csv, Rows: 6732
# File: UTG.L.csv, Rows: 6726
# File: QQQ.csv, Rows: 6700
# File: GS.csv, Rows: 6662
# File: FFIV.csv, Rows: 6640
# File: RMS.PA.csv, Rows: 6635
# File: RI.PA.csv, Rows: 6635
# File: SGO.PA.csv, Rows: 6635
# File: SU.PA.csv, Rows: 6635
# File: SAN.PA.csv, Rows: 6635
# File: DG.PA.csv, Rows: 6635
# File: DSY.PA.csv, Rows: 6635
# File: CAP.PA.csv, Rows: 6635
# File: KER.PA.csv, Rows: 6635
# File: RNO.PA.csv, Rows: 6635
# File: GLE.PA.csv, Rows: 6635
# File: MC.PA.csv, Rows: 6635
# File: ENGI.PA.csv, Rows: 6635
# File: ORA.PA.csv, Rows: 6635
# File: EL.PA.csv, Rows: 6635
# File: SAF.PA.csv, Rows: 6635
# File: OR.PA.csv, Rows: 6635
# File: HO.PA.csv, Rows: 6635
# File: TTE.PA.csv, Rows: 6635
# File: AI.PA.csv, Rows: 6635
# File: ML.PA.csv, Rows: 6635
# File: CA.PA.csv, Rows: 6635
# File: SBAC.csv, Rows: 6632
# File: EOAN.DE.csv, Rows: 6600
# File: ATCO-B.ST.csv, Rows: 6577
# File: CPG.L.csv, Rows: 6571
# File: DCC.L.csv, Rows: 6571
# File: BLK.csv, Rows: 6557
# File: ERIC-B.ST.csv, Rows: 6554
# File: AZN.ST.csv, Rows: 6554
# File: SKA-B.ST.csv, Rows: 6554
# File: ASSA-B.ST.csv, Rows: 6554
# File: SHB-A.ST.csv, Rows: 6554
# File: HEXA-B.ST.csv, Rows: 6554
# File: SWED-A.ST.csv, Rows: 6554
# File: GETI-B.ST.csv, Rows: 6554
# File: ELUX-B.ST.csv, Rows: 6554
# File: NDA-SE.ST.csv, Rows: 6554
# File: SKF-B.ST.csv, Rows: 6554
# File: ALIV-SDB.ST.csv, Rows: 6554
# File: TEL2-B.ST.csv, Rows: 6554
# File: ATCO-A.ST.csv, Rows: 6554
# File: SAND.ST.csv, Rows: 6554
# File: INVE-B.ST.csv, Rows: 6554
# File: VOLV-B.ST.csv, Rows: 6554
# File: HM-B.ST.csv, Rows: 6554
# File: SEB-A.ST.csv, Rows: 6554
# File: SCA-B.ST.csv, Rows: 6554
# File: KINV-B.ST.csv, Rows: 6554
# File: IFX.DE.csv, Rows: 6550
# File: AKAM.csv, Rows: 6537
# File: UPS.csv, Rows: 6529
# File: A.csv, Rows: 6523
# File: TDY.csv, Rows: 6520
# File: PUB.PA.csv, Rows: 6449
# File: TELIA.ST.csv, Rows: 6438
# File: EW.csv, Rows: 6435
# File: MET.csv, Rows: 6428
# File: ON.csv, Rows: 6410
# File: IWB.csv, Rows: 6397
# File: IYW.csv, Rows: 6397
# File: IVV.csv, Rows: 6397
# File: IVW.csv, Rows: 6392
# File: IVE.csv, Rows: 6392
# File: IJH.csv, Rows: 6392
# File: IJR.csv, Rows: 6392
# File: IWM.csv, Rows: 6392
# File: IWF.csv, Rows: 6392
# File: IWD.csv, Rows: 6392
# File: HNR1.DE.csv, Rows: 6390
# File: SMH.csv, Rows: 6387
# File: ISRG.csv, Rows: 6378
# File: CRL.csv, Rows: 6373
# File: MRVL.csv, Rows: 6368
# File: IUSG.csv, Rows: 6349
# File: ILMN.csv, Rows: 6349
# File: EZJ.L.csv, Rows: 6345
# File: IUSV.csv, Rows: 6344
# File: EQIX.csv, Rows: 6339
# File: DHL.DE.csv, Rows: 6320
# File: DB1.DE.csv, Rows: 6315
# File: SPYG.csv, Rows: 6304
# File: SPYV.csv, Rows: 6304
# File: TPR.csv, Rows: 6300
# File: GPN.csv, Rows: 6232
# File: ALGN.csv, Rows: 6222
# File: ABB.ST.csv, Rows: 6203
# File: STLAP.PA.csv, Rows: 6200
# File: STMPA.PA.csv, Rows: 6200
# File: AIR.PA.csv, Rows: 6200
# File: LSEG.L.csv, Rows: 6168
# File: WTW.csv, Rows: 6130
# File: MDLZ.csv, Rows: 6129
# File: VTI.csv, Rows: 6127
# File: ACA.PA.csv, Rows: 6126
# File: AXON.csv, Rows: 6125
# File: FIS.csv, Rows: 6124
# File: ACN.csv, Rows: 6104
# File: ZBH.csv, Rows: 6100
# File: BG.csv, Rows: 6094
# File: IWR.csv, Rows: 6077
# File: EFA.csv, Rows: 6077
# File: PFG.csv, Rows: 6041
# File: ITRK.L.csv, Rows: 5948
# File: BRBY.L.csv, Rows: 5913
# File: FRAS.L.csv, Rows: 5900
# File: NFLX.csv, Rows: 5895
# File: NDAQ.csv, Rows: 5869
# File: TLT.csv, Rows: 5849
# File: SHY.csv, Rows: 5849
# File: IEF.csv, Rows: 5849
# File: LQD.csv, Rows: 5849
# File: BEZ.L.csv, Rows: 5826
# File: MRO.L.csv, Rows: 5576
# File: AGG.csv, Rows: 5555
# File: LKQ.csv, Rows: 5550
# File: DVY.csv, Rows: 5526
# File: NRG.csv, Rows: 5510
# File: ITOT.csv, Rows: 5475
# File: VUG.csv, Rows: 5470
# File: VTV.csv, Rows: 5470
# File: VO.csv, Rows: 5470
# File: VHT.csv, Rows: 5470
# File: VGT.csv, Rows: 5470
# File: VV.csv, Rows: 5470
# File: VB.csv, Rows: 5470
# File: VBR.csv, Rows: 5470
# File: AIZ.csv, Rows: 5466
# File: CBRE.csv, Rows: 5379
# File: CRM.csv, Rows: 5371
# File: DPZ.csv, Rows: 5358
# File: ADM.L.csv, Rows: 5339
# File: EXR.csv, Rows: 5334
# File: GOOGL.csv, Rows: 5331
# File: GOOG.csv, Rows: 5331
# File: VNQ.csv, Rows: 5303
# File: DLR.csv, Rows: 5281
# File: MKTX.csv, Rows: 5276
# File: ENT.L.csv, Rows: 5276
# File: GLD.csv, Rows: 5267
# File: MPWR.csv, Rows: 5266
# File: LVS.csv, Rows: 5249
# File: CE.csv, Rows: 5224
# File: IAU.csv, Rows: 5219
# File: VWO.csv, Rows: 5191
# File: VGK.csv, Rows: 5191
# File: MT.AS.csv, Rows: 5190
# File: MTX.DE.csv, Rows: 5185
# File: ALO.PA.csv, Rows: 5178
# File: DXCM.csv, Rows: 5167
# File: BLDR.csv, Rows: 5115
# File: WBD.csv, Rows: 5108
# File: EXPE.csv, Rows: 5099
# File: EFV.csv, Rows: 5088
# File: CF.csv, Rows: 5084
# File: AMP.csv, Rows: 5060
# File: AAL.csv, Rows: 5052
# File: HIK.L.csv, Rows: 5051
# File: SDY.csv, Rows: 5017
# File: SPLG.csv, Rows: 5017
# File: ICE.csv, Rows: 5016
# File: LR.PA.csv, Rows: 5001
# File: LYV.csv, Rows: 4992
# File: CMG.csv, Rows: 4969
# File: UAL.csv, Rows: 4962
# File: RMV.L.csv, Rows: 4959
# File: TDG.csv, Rows: 4936
# File: LDOS.csv, Rows: 4786
# File: VYM.csv, Rows: 4764
# File: FSLR.csv, Rows: 4763
# File: IGSB.csv, Rows: 4728
# File: SHV.csv, Rows: 4728
# File: SKG.L.csv, Rows: 4703
# File: VEU.csv, Rows: 4690
# File: MBB.csv, Rows: 4684
# File: BR.csv, Rows: 4680
# File: SMCI.csv, Rows: 4675
# File: BND.csv, Rows: 4668
# File: BIV.csv, Rows: 4668
# File: BSV.csv, Rows: 4668
# File: TMUS.csv, Rows: 4661
# File: SPDW.csv, Rows: 4656
# File: DAL.csv, Rows: 4651
# File: PODD.csv, Rows: 4643
# File: BIL.csv, Rows: 4633
# File: MNDI.L.csv, Rows: 4631
# File: TEL.csv, Rows: 4622
# File: BX.csv, Rows: 4616
# File: VEA.csv, Rows: 4593
# File: LULU.csv, Rows: 4592
# File: MELI.csv, Rows: 4582
# File: MUB.csv, Rows: 4562
# File: ULTA.csv, Rows: 4529
# File: MGK.csv, Rows: 4486
# File: PM.csv, Rows: 4432
# File: V.csv, Rows: 4430
# File: ACWI.csv, Rows: 4424
# File: FRES.L.csv, Rows: 4413
# File: AWK.csv, Rows: 4406
# File: KDP.csv, Rows: 4396
# File: VRSK.csv, Rows: 4038
# File: PHNX.L.csv, Rows: 4026
# File: SCHX.csv, Rows: 4019
# File: SCHF.csv, Rows: 4019
# File: SCHB.csv, Rows: 4019
# File: DG.csv, Rows: 4011
# File: FTNT.csv, Rows: 4008
# File: VCIT.csv, Rows: 4005
# File: VGSH.csv, Rows: 4005
# File: VCSH.csv, Rows: 4005
# File: VGIT.csv, Rows: 4005
# File: SCHG.csv, Rows: 3978
# File: CHTR.csv, Rows: 3977
# File: BNR.DE.csv, Rows: 3960
# File: TQQQ.csv, Rows: 3951
# File: GNRC.csv, Rows: 3951
# File: LYB.csv, Rows: 3899
# File: OCDO.L.csv, Rows: 3857
# File: TSLA.csv, Rows: 3856
# File: NXPI.csv, Rows: 3829
# File: VOO.csv, Rows: 3806
# File: GM.csv, Rows: 3756
# File: VXUS.csv, Rows: 3708
# File: KMI.csv, Rows: 3698
# File: GOVT.csv, Rows: 3438
# File: ENPH.csv, Rows: 3413
# File: PSX.csv, Rows: 3405
# File: AMCR.csv, Rows: 3382
# File: META.csv, Rows: 3379
# File: PANW.csv, Rows: 3336
# File: FANG.csv, Rows: 3277
# File: WDAY.csv, Rows: 3277
# File: IEFA.csv, Rows: 3269
# File: IXUS.csv, Rows: 3269
# File: IEMG.csv, Rows: 3269
# File: ABBV.csv, Rows: 3224
# File: NCLH.csv, Rows: 3212
# File: CCH.L.csv, Rows: 3158
# File: IQV.csv, Rows: 3136
# File: VNA.DE.csv, Rows: 3122
# File: BNDX.csv, Rows: 3119
# File: NWS.csv, Rows: 3108
# File: NWSA.csv, Rows: 3108
# File: CDW.csv, Rows: 3102
# File: QUAL.csv, Rows: 3088
# File: WLN.PA.csv, Rows: 2902
# File: PAYC.csv, Rows: 2901
# File: BME.L.csv, Rows: 2874
# File: ANET.csv, Rows: 2865
# File: DGRO.csv, Rows: 2861
# File: IUSB.csv, Rows: 2861
# File: SYF.csv, Rows: 2827
# File: ZAL.DE.csv, Rows: 2812
# File: CZR.csv, Rows: 2791
# File: CFG.csv, Rows: 2789
# File: KEYS.csv, Rows: 2771
# File: QRVO.csv, Rows: 2720
# File: ETSY.csv, Rows: 2649
# File: SHOP.csv, Rows: 2625
# File: PYPL.csv, Rows: 2594
# File: KHC.csv, Rows: 2594
# File: 1COV.DE.csv, Rows: 2558
# File: VTEB.csv, Rows: 2558
# File: SINCH.ST.csv, Rows: 2528
# File: FTV.csv, Rows: 2342
# File: TTD.csv, Rows: 2287
# File: CTEC.L.csv, Rows: 2272
# File: HWM.csv, Rows: 2258
# File: LW.csv, Rows: 2251
# File: COWZ.csv, Rows: 2222
# File: INVH.csv, Rows: 2196

# %%
for cluster_id in range(len(clusters)-1):
    print(f"Processing cluster {cluster_id}")
    dataframes_vol = []
    for filename, rows in clusters[cluster_id]:
        print(f"File: {filename}, Rows: {rows}")
        # make one single pandas dataframe contains the data from above stock IDs, the index is the data, the columns are the stock IDs
        stock_id = filename[:-4]  

        file_path = Path(data_directory) / filename
        df_vol = pd.read_csv(file_path, usecols=['Date', 'Adj Close', 'Volume'], parse_dates=['Date'])
        df_vol.set_index('Date', inplace=True)
        df_vol.rename(columns={'Adj Close': f"{stock_id}_price", 'Volume': f"{stock_id}_vol"}, inplace=True)
        dataframes_vol.append(df_vol)

    combined_df_vol = pd.concat(dataframes_vol, axis=1)
    combined_df_vol.fillna(method='ffill', inplace=True)
    combined_df_vol.fillna(method='bfill', inplace=True)
    log_returns_df_vol = np.log(combined_df_vol / (combined_df_vol.shift(1) + 1e-9 ) + 1e-9)
    # drop the first row
    #log_returns_df_vol = log_returns_df_vol.iloc[1:]
    log_returns_df_vol = log_returns_df_vol.dropna()  # Drop the first row with

    price_columns = [col for col in log_returns_df_vol.columns if col.endswith('_price')]
    volume_columns = [col for col in log_returns_df_vol.columns if col.endswith('_vol')]
    log_returns_df_vol = log_returns_df_vol[price_columns + volume_columns]
    # find out the earliest date in the dataframe
    start_date = log_returns_df_vol.index.min().strftime('%Y-%m-%d')
    log_returns_df_vol.to_csv(f"stock_data_vol-cluster-{cluster_id}-startdate-{start_date}.csv")
# Out:
# Processing cluster 0
# File: HPQ.csv, Rows: 16062
# File: PG.csv, Rows: 16062
# File: IP.csv, Rows: 16062
# File: DIS.csv, Rows: 16062
# File: MRK.csv, Rows: 16062
# File: HON.csv, Rows: 16062
# File: CAT.csv, Rows: 16062
# File: GE.csv, Rows: 16062
# File: IBM.csv, Rows: 16062
# File: GD.csv, Rows: 16062
# File: JNJ.csv, Rows: 16062
# File: ED.csv, Rows: 16062
# File: DTE.csv, Rows: 16062
# File: XOM.csv, Rows: 16062
# File: MMM.csv, Rows: 16062
# File: CVX.csv, Rows: 16062
# File: BA.csv, Rows: 16062
# File: KO.csv, Rows: 16062
# File: MSI.csv, Rows: 16062
# File: CNP.csv, Rows: 16062
# File: MO.csv, Rows: 16062
# File: KR.csv, Rows: 16062
# File: AEP.csv, Rows: 16062
# File: LMT.csv, Rows: 16061
# File: RTX.csv, Rows: 15999
# File: MCD.csv, Rows: 14927
# File: FCIT.L.csv, Rows: 14660
# File: SMT.L.csv, Rows: 14660
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 1
# File: F.csv, Rows: 13463
# File: LLY.csv, Rows: 13463
# File: HAL.csv, Rows: 13463
# File: PCG.csv, Rows: 13463
# File: AXP.csv, Rows: 13463
# File: EMR.csv, Rows: 13463
# File: PFE.csv, Rows: 13463
# File: DE.csv, Rows: 13463
# File: TXN.csv, Rows: 13463
# File: BMY.csv, Rows: 13463
# File: ETN.csv, Rows: 13463
# File: DD.csv, Rows: 13463
# File: ETR.csv, Rows: 13463
# File: WFC.csv, Rows: 13463
# File: PEP.csv, Rows: 13463
# File: WMT.csv, Rows: 13403
# File: WBA.csv, Rows: 13345
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 2
# File: AIG.csv, Rows: 13317
# File: ES.csv, Rows: 13283
# File: CLX.csv, Rows: 13283
# File: CVS.csv, Rows: 13283
# File: VMC.csv, Rows: 13283
# File: BDX.csv, Rows: 13283
# File: EVRG.csv, Rows: 13283
# File: MKC.csv, Rows: 13283
# File: BAC.csv, Rows: 13283
# File: TGT.csv, Rows: 13283
# File: K.csv, Rows: 13283
# File: RVTY.csv, Rows: 13283
# File: CMS.csv, Rows: 13283
# File: BALL.csv, Rows: 13283
# File: TER.csv, Rows: 13283
# File: MMC.csv, Rows: 13283
# File: XEL.csv, Rows: 13283
# File: NEE.csv, Rows: 13283
# File: NI.csv, Rows: 13283
# File: ECL.csv, Rows: 13283
# File: CMI.csv, Rows: 13283
# File: PNW.csv, Rows: 13283
# File: CPB.csv, Rows: 13283
# File: AVY.csv, Rows: 13283
# File: SPGI.csv, Rows: 13283
# File: TXT.csv, Rows: 13283
# File: LNT.csv, Rows: 13283
# File: SNA.csv, Rows: 13283
# File: GWW.csv, Rows: 13283
# File: ITW.csv, Rows: 13269
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 3
# File: CL.csv, Rows: 13234
# File: MDT.csv, Rows: 13234
# File: EXC.csv, Rows: 13234
# File: BK.csv, Rows: 13233
# File: USB.csv, Rows: 13233
# File: FRT.csv, Rows: 13233
# File: EIX.csv, Rows: 13233
# File: PNR.csv, Rows: 13233
# File: WY.csv, Rows: 13233
# File: SYY.csv, Rows: 13230
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 4
# File: PEG.csv, Rows: 11549
# File: UNP.csv, Rows: 11549
# File: LUV.csv, Rows: 11549
# File: BIO.csv, Rows: 11510
# File: TYL.csv, Rows: 11497
# File: CAG.csv, Rows: 11497
# File: HAS.csv, Rows: 11497
# File: RHI.csv, Rows: 11497
# File: MAS.csv, Rows: 11497
# File: TT.csv, Rows: 11497
# File: NUE.csv, Rows: 11497
# File: ABT.csv, Rows: 11497
# File: IPG.csv, Rows: 11497
# File: VTRS.csv, Rows: 11497
# File: J.csv, Rows: 11497
# File: JPM.csv, Rows: 11497
# File: NTRS.csv, Rows: 11497
# File: PCAR.csv, Rows: 11497
# File: WST.csv, Rows: 11497
# File: WEC.csv, Rows: 11497
# File: PH.csv, Rows: 11497
# File: ADM.csv, Rows: 11497
# File: OMC.csv, Rows: 11497
# File: CINF.csv, Rows: 11497
# File: AMD.csv, Rows: 11497
# File: GIS.csv, Rows: 11497
# File: FITB.csv, Rows: 11497
# File: PPL.csv, Rows: 11497
# File: EQT.csv, Rows: 11497
# File: DOV.csv, Rows: 11497
# File: SWK.csv, Rows: 11497
# File: TFX.csv, Rows: 11497
# File: INTC.csv, Rows: 11497
# File: ADI.csv, Rows: 11497
# File: AFL.csv, Rows: 11497
# File: STT.csv, Rows: 11497
# File: PGR.csv, Rows: 11497
# File: CMA.csv, Rows: 11497
# File: SHW.csv, Rows: 11497
# File: UDR.csv, Rows: 11497
# File: D.csv, Rows: 11497
# File: SYK.csv, Rows: 11497
# File: ROL.csv, Rows: 11497
# File: CHD.csv, Rows: 11497
# File: HSY.csv, Rows: 11497
# File: CMCSA.csv, Rows: 11497
# File: HRL.csv, Rows: 11497
# File: LEN.csv, Rows: 11497
# File: TMO.csv, Rows: 11497
# File: TSN.csv, Rows: 11497
# File: AMAT.csv, Rows: 11497
# File: RF.csv, Rows: 11497
# File: LOW.csv, Rows: 11497
# File: HBAN.csv, Rows: 11497
# File: EFX.csv, Rows: 11497
# File: MTB.csv, Rows: 11497
# File: FMC.csv, Rows: 11497
# File: L.csv, Rows: 11497
# File: GPC.csv, Rows: 11497
# File: PHM.csv, Rows: 11497
# File: PPG.csv, Rows: 11497
# File: APD.csv, Rows: 11497
# File: NEM.csv, Rows: 11497
# File: DUK.csv, Rows: 11497
# File: KMB.csv, Rows: 11497
# File: ADP.csv, Rows: 11497
# File: HST.csv, Rows: 11497
# File: NDSN.csv, Rows: 11496
# File: TFC.csv, Rows: 11496
# File: WELL.csv, Rows: 11495
# File: AON.csv, Rows: 11444
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 5
# File: GL.csv, Rows: 11359
# File: OKE.csv, Rows: 11359
# File: KLAC.csv, Rows: 11354
# File: CSX.csv, Rows: 11336
# File: PSA.csv, Rows: 11326
# File: NKE.csv, Rows: 11317
# File: AAPL.csv, Rows: 11309
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 6
# File: UHS.csv, Rows: 11166
# File: HD.csv, Rows: 11114
# File: BAX.csv, Rows: 11089
# File: GLW.csv, Rows: 11044
# File: OXY.csv, Rows: 11044
# File: SO.csv, Rows: 11044
# File: SLB.csv, Rows: 11044
# File: LHX.csv, Rows: 11044
# File: COP.csv, Rows: 11044
# File: HUM.csv, Rows: 11044
# File: NOC.csv, Rows: 11044
# File: ROK.csv, Rows: 11044
# File: WMB.csv, Rows: 11044
# File: VLO.csv, Rows: 11043
# File: CI.csv, Rows: 10982
# File: BBWI.csv, Rows: 10981
# File: NSC.csv, Rows: 10939
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 7
# File: AMGN.csv, Rows: 10674
# File: RJF.csv, Rows: 10664
# File: CAH.csv, Rows: 10641
# File: CTAS.csv, Rows: 10630
# File: PAYX.csv, Rows: 10625
# File: BEN.csv, Rows: 10606
# File: AOS.csv, Rows: 10601
# File: VZ.csv, Rows: 10565
# File: T.csv, Rows: 10565
# File: JBHT.csv, Rows: 10564
# File: ATO.csv, Rows: 10540
# File: LRCX.csv, Rows: 10451
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 8
# File: MU.csv, Rows: 10432
# File: AJG.csv, Rows: 10419
# File: AME.csv, Rows: 10399
# File: SWKS.csv, Rows: 10364
# File: EXPD.csv, Rows: 10351
# Processing cluster 9
# File: BBY.csv, Rows: 10210
# File: DOC.csv, Rows: 10185
# File: ADSK.csv, Rows: 10160
# File: NVR.csv, Rows: 10145
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: DVN.csv, Rows: 10145
# File: ROST.csv, Rows: 10132
# File: JKHY.csv, Rows: 10060
# File: MNST.csv, Rows: 10048
# File: ORCL.csv, Rows: 9984
# File: MSFT.csv, Rows: 9983
# File: TROW.csv, Rows: 9970
# File: COST.csv, Rows: 9902
# File: ADBE.csv, Rows: 9877
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 10
# File: FI.csv, Rows: 9847
# File: BKR.csv, Rows: 9714
# File: CDNS.csv, Rows: 9669
# File: TJX.csv, Rows: 9657
# File: FICO.csv, Rows: 9640
# File: CCL.csv, Rows: 9638
# File: FAST.csv, Rows: 9619
# File: DGE.L.csv, Rows: 9615
# File: SCHW.csv, Rows: 9597
# File: JCI.csv, Rows: 9593
# File: RS1.L.csv, Rows: 9573
# File: ABF.L.csv, Rows: 9573
# File: TSCO.L.csv, Rows: 9573
# File: TW.L.csv, Rows: 9573
# File: RR.L.csv, Rows: 9573
# File: DPLM.L.csv, Rows: 9573
# File: SMIN.L.csv, Rows: 9573
# File: RKT.L.csv, Rows: 9573
# File: AHT.L.csv, Rows: 9573
# File: MKS.L.csv, Rows: 9573
# File: BA.L.csv, Rows: 9573
# File: WTB.L.csv, Rows: 9573
# File: RIO.L.csv, Rows: 9573
# File: BT-A.L.csv, Rows: 9573
# File: ANTO.L.csv, Rows: 9573
# File: PSON.L.csv, Rows: 9573
# File: LAND.L.csv, Rows: 9573
# File: STAN.L.csv, Rows: 9573
# File: KGF.L.csv, Rows: 9573
# File: REL.L.csv, Rows: 9573
# File: LGEN.L.csv, Rows: 9573
# File: BNZL.L.csv, Rows: 9573
# File: IMI.L.csv, Rows: 9573
# File: SDR.L.csv, Rows: 9573
# File: AV.L.csv, Rows: 9573
# File: WEIR.L.csv, Rows: 9573
# File: BARC.L.csv, Rows: 9573
# File: RTO.L.csv, Rows: 9573
# File: HLMA.L.csv, Rows: 9573
# File: ULVR.L.csv, Rows: 9573
# File: SBRY.L.csv, Rows: 9573
# File: GSK.L.csv, Rows: 9573
# File: PRU.L.csv, Rows: 9573
# File: PSN.L.csv, Rows: 9573
# File: BKG.L.csv, Rows: 9573
# File: SPX.L.csv, Rows: 9573
# File: NXT.L.csv, Rows: 9573
# File: SGRO.L.csv, Rows: 9573
# File: NWG.L.csv, Rows: 9573
# File: CRDA.L.csv, Rows: 9572
# File: BP.L.csv, Rows: 9572
# File: SN.L.csv, Rows: 9572
# File: HSBA.L.csv, Rows: 9571
# File: KEY.csv, Rows: 9565
# File: MOS.csv, Rows: 9510
# File: BN.PA.csv, Rows: 9495
# File: VOD.L.csv, Rows: 9491
# File: MGM.csv, Rows: 9443
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 11
# File: TECH.csv, Rows: 9246
# File: SVT.L.csv, Rows: 9197
# File: UU.L.csv, Rows: 9197
# File: SGE.L.csv, Rows: 9195
# File: IEX.csv, Rows: 9168
# File: GEN.csv, Rows: 9153
# File: EA.csv, Rows: 9092
# File: EOG.csv, Rows: 9082
# File: CS.PA.csv, Rows: 9076
# File: PTC.csv, Rows: 9036
# File: STJ.L.csv, Rows: 9011
# File: CTRA.csv, Rows: 8994
# File: CSCO.csv, Rows: 8988
# File: EN.PA.csv, Rows: 8980
# File: HOLX.csv, Rows: 8980
# File: LH.csv, Rows: 8960
# File: TRMB.csv, Rows: 8882
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 12
# File: AZO.csv, Rows: 8706
# File: REGN.csv, Rows: 8706
# File: IDXX.csv, Rows: 8649
# File: AES.csv, Rows: 8646
# File: VRTX.csv, Rows: 8627
# File: TEP.PA.csv, Rows: 8615
# File: ZBRA.csv, Rows: 8611
# File: BIIB.csv, Rows: 8589
# File: ODFL.csv, Rows: 8562
# File: APH.csv, Rows: 8551
# File: KIM.csv, Rows: 8541
# File: QCOM.csv, Rows: 8527
# File: HWDN.L.csv, Rows: 8519
# File: GILD.csv, Rows: 8501
# File: ROP.csv, Rows: 8485
# File: SNPS.csv, Rows: 8477
# File: STZ.csv, Rows: 8463
# File: MHK.csv, Rows: 8452
# File: BSX.csv, Rows: 8419
# File: STE.csv, Rows: 8411
# File: DHI.csv, Rows: 8407
# File: LIN.csv, Rows: 8399
# File: SBUX.csv, Rows: 8392
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 13
# File: BNP.PA.csv, Rows: 8255
# File: MTCH.csv, Rows: 8250
# File: SPY.csv, Rows: 8242
# File: MS.csv, Rows: 8226
# File: INTU.csv, Rows: 8213
# File: MCHP.csv, Rows: 8208
# File: CB.csv, Rows: 8204
# File: ORLY.csv, Rows: 8184
# File: RCL.csv, Rows: 8181
# File: JBL.csv, Rows: 8178
# File: AZN.csv, Rows: 8171
# File: ALL.csv, Rows: 8156
# File: EQR.csv, Rows: 8107
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 14
# File: IT.csv, Rows: 8070
# File: DECK.csv, Rows: 8062
# File: REG.csv, Rows: 8052
# File: INCY.csv, Rows: 8048
# File: EMN.csv, Rows: 8021
# File: SPG.csv, Rows: 8021
# File: III.L.csv, Rows: 7996
# File: MAA.csv, Rows: 7989
# File: TSCO.csv, Rows: 7975
# File: MLM.csv, Rows: 7975
# File: ALB.csv, Rows: 7973
# File: AVB.csv, Rows: 7960
# File: CPRT.csv, Rows: 7956
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 15
# File: WPP.L.csv, Rows: 7816
# File: O.csv, Rows: 7808
# File: SJM.csv, Rows: 7799
# File: MCO.csv, Rows: 7799
# File: MCK.csv, Rows: 7791
# File: PARA.csv, Rows: 7787
# File: COF.csv, Rows: 7787
# Processing cluster 16
# File: COR.csv, Rows: 7692
# File: MDY.csv, Rows: 7671
# File: DRI.csv, Rows: 7668
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: RMD.csv, Rows: 7651
# File: WAB.csv, Rows: 7641
# File: NG.L.csv, Rows: 7632
# File: FCX.csv, Rows: 7626
# File: LLOY.L.csv, Rows: 7619
# File: IVZ.csv, Rows: 7592
# File: ACGL.csv, Rows: 7579
# File: EG.csv, Rows: 7566
# File: POOL.csv, Rows: 7558
# File: DVA.csv, Rows: 7546
# File: HSIC.csv, Rows: 7543
# File: EL.csv, Rows: 7533
# File: WAT.csv, Rows: 7533
# File: NTAP.csv, Rows: 7531
# File: HIG.csv, Rows: 7514
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 17
# File: BMW.DE.csv, Rows: 7421
# File: SIE.DE.csv, Rows: 7421
# File: IMB.L.csv, Rows: 7420
# File: DBK.DE.csv, Rows: 7415
# File: DTE.DE.csv, Rows: 7415
# Processing cluster 18
# File: JD.L.csv, Rows: 7406
# File: CBK.DE.csv, Rows: 7395
# File: ALV.DE.csv, Rows: 7395
# File: BAYN.DE.csv, Rows: 7395
# File: RWE.DE.csv, Rows: 7395
# File: BAS.DE.csv, Rows: 7395
# File: CON.DE.csv, Rows: 7395
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 19
# File: KMX.csv, Rows: 7227
# File: ERF.PA.csv, Rows: 7205
# File: TTWO.csv, Rows: 7179
# File: VTR.csv, Rows: 7165
# File: AMZN.csv, Rows: 7157
# File: ARE.csv, Rows: 7149
# File: RL.csv, Rows: 7138
# File: BXP.csv, Rows: 7134
# Processing cluster 20
# File: YUM.csv, Rows: 7071
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: TSM.csv, Rows: 7055
# File: SAP.DE.csv, Rows: 7052
# File: CHRW.csv, Rows: 7050
# File: FE.csv, Rows: 7033
# File: MTD.csv, Rows: 7029
# File: PLD.csv, Rows: 7024
# File: URI.csv, Rows: 7006
# File: MUV2.DE.csv, Rows: 6998
# File: ADS.DE.csv, Rows: 6998
# File: HEN3.DE.csv, Rows: 6997
# File: AEE.csv, Rows: 6997
# File: MRK.DE.csv, Rows: 6996
# File: DIA.csv, Rows: 6986
# File: BEI.DE.csv, Rows: 6978
# File: QIA.DE.csv, Rows: 6978
# File: VRSN.csv, Rows: 6978
# File: VOW3.DE.csv, Rows: 6978
# File: HEI.DE.csv, Rows: 6975
# File: PWR.csv, Rows: 6969
# File: RHM.DE.csv, Rows: 6968
# File: AMT.csv, Rows: 6959
# File: FLTR.L.csv, Rows: 6945
# File: MAR.csv, Rows: 6943
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 21
# File: FRE.DE.csv, Rows: 6900
# File: AIR.DE.csv, Rows: 6899
# File: MSTR.csv, Rows: 6887
# File: CTSH.csv, Rows: 6881
# File: SRE.csv, Rows: 6875
# File: CSGP.csv, Rows: 6873
# File: RSG.csv, Rows: 6873
# File: INF.L.csv, Rows: 6841
# File: CCI.csv, Rows: 6840
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 22
# File: SRT3.DE.csv, Rows: 6778
# File: XLV.csv, Rows: 6752
# File: XLY.csv, Rows: 6752
# File: XLE.csv, Rows: 6752
# File: XLI.csv, Rows: 6752
# File: XLF.csv, Rows: 6752
# File: XLK.csv, Rows: 6752
# File: NVDA.csv, Rows: 6732
# File: AAL.L.csv, Rows: 6732
# File: UTG.L.csv, Rows: 6726
# File: QQQ.csv, Rows: 6700
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 23
# File: GS.csv, Rows: 6662
# File: FFIV.csv, Rows: 6640
# File: RMS.PA.csv, Rows: 6635
# File: RI.PA.csv, Rows: 6635
# File: SGO.PA.csv, Rows: 6635
# File: SU.PA.csv, Rows: 6635
# File: SAN.PA.csv, Rows: 6635
# File: DG.PA.csv, Rows: 6635
# File: DSY.PA.csv, Rows: 6635
# File: CAP.PA.csv, Rows: 6635
# File: KER.PA.csv, Rows: 6635
# File: RNO.PA.csv, Rows: 6635
# File: GLE.PA.csv, Rows: 6635
# File: MC.PA.csv, Rows: 6635
# File: ENGI.PA.csv, Rows: 6635
# File: ORA.PA.csv, Rows: 6635
# File: EL.PA.csv, Rows: 6635
# File: SAF.PA.csv, Rows: 6635
# File: OR.PA.csv, Rows: 6635
# File: HO.PA.csv, Rows: 6635
# File: TTE.PA.csv, Rows: 6635
# File: AI.PA.csv, Rows: 6635
# File: ML.PA.csv, Rows: 6635
# File: CA.PA.csv, Rows: 6635
# File: SBAC.csv, Rows: 6632
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 24
# File: EOAN.DE.csv, Rows: 6600
# File: ATCO-B.ST.csv, Rows: 6577
# File: CPG.L.csv, Rows: 6571
# File: DCC.L.csv, Rows: 6571
# File: BLK.csv, Rows: 6557
# File: ERIC-B.ST.csv, Rows: 6554
# File: AZN.ST.csv, Rows: 6554
# File: SKA-B.ST.csv, Rows: 6554
# File: ASSA-B.ST.csv, Rows: 6554
# File: SHB-A.ST.csv, Rows: 6554
# File: HEXA-B.ST.csv, Rows: 6554
# File: SWED-A.ST.csv, Rows: 6554
# File: GETI-B.ST.csv, Rows: 6554
# File: ELUX-B.ST.csv, Rows: 6554
# File: NDA-SE.ST.csv, Rows: 6554
# File: SKF-B.ST.csv, Rows: 6554
# File: ALIV-SDB.ST.csv, Rows: 6554
# File: TEL2-B.ST.csv, Rows: 6554
# File: ATCO-A.ST.csv, Rows: 6554
# File: SAND.ST.csv, Rows: 6554
# File: INVE-B.ST.csv, Rows: 6554
# File: VOLV-B.ST.csv, Rows: 6554
# File: HM-B.ST.csv, Rows: 6554
# File: SEB-A.ST.csv, Rows: 6554
# File: SCA-B.ST.csv, Rows: 6554
# File: KINV-B.ST.csv, Rows: 6554
# File: IFX.DE.csv, Rows: 6550
# File: AKAM.csv, Rows: 6537
# File: UPS.csv, Rows: 6529
# File: A.csv, Rows: 6523
# File: TDY.csv, Rows: 6520
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 25
# File: PUB.PA.csv, Rows: 6449
# File: TELIA.ST.csv, Rows: 6438
# File: EW.csv, Rows: 6435
# File: MET.csv, Rows: 6428
# File: ON.csv, Rows: 6410
# File: IWB.csv, Rows: 6397
# File: IYW.csv, Rows: 6397
# File: IVV.csv, Rows: 6397
# File: IVW.csv, Rows: 6392
# File: IVE.csv, Rows: 6392
# File: IJH.csv, Rows: 6392
# File: IJR.csv, Rows: 6392
# File: IWM.csv, Rows: 6392
# File: IWF.csv, Rows: 6392
# File: IWD.csv, Rows: 6392
# File: HNR1.DE.csv, Rows: 6390
# File: SMH.csv, Rows: 6387
# File: ISRG.csv, Rows: 6378
# File: CRL.csv, Rows: 6373
# File: MRVL.csv, Rows: 6368
# File: IUSG.csv, Rows: 6349
# File: ILMN.csv, Rows: 6349
# File: EZJ.L.csv, Rows: 6345
# File: IUSV.csv, Rows: 6344
# File: EQIX.csv, Rows: 6339
# File: DHL.DE.csv, Rows: 6320
# File: DB1.DE.csv, Rows: 6315
# File: SPYG.csv, Rows: 6304
# File: SPYV.csv, Rows: 6304
# File: TPR.csv, Rows: 6300
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 26
# File: GPN.csv, Rows: 6232
# File: ALGN.csv, Rows: 6222
# File: ABB.ST.csv, Rows: 6203
# File: STLAP.PA.csv, Rows: 6200
# File: STMPA.PA.csv, Rows: 6200
# File: AIR.PA.csv, Rows: 6200
# Processing cluster 27
# File: LSEG.L.csv, Rows: 6168
# File: WTW.csv, Rows: 6130
# File: MDLZ.csv, Rows: 6129
# File: VTI.csv, Rows: 6127
# File: ACA.PA.csv, Rows: 6126
# File: AXON.csv, Rows: 6125
# File: FIS.csv, Rows: 6124
# File: ACN.csv, Rows: 6104
# File: ZBH.csv, Rows: 6100
# File: BG.csv, Rows: 6094
# File: IWR.csv, Rows: 6077
# File: EFA.csv, Rows: 6077
# File: PFG.csv, Rows: 6041
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /home/ken/.pyenv/versions/myenv/lib/python3.11/site-packages/pandas/core/internals/blocks.py:395: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# Processing cluster 28
# File: ITRK.L.csv, Rows: 5948
# File: BRBY.L.csv, Rows: 5913
# File: FRAS.L.csv, Rows: 5900
# File: NFLX.csv, Rows: 5895
# File: NDAQ.csv, Rows: 5869
# File: TLT.csv, Rows: 5849
# File: SHY.csv, Rows: 5849
# File: IEF.csv, Rows: 5849
# File: LQD.csv, Rows: 5849
# File: BEZ.L.csv, Rows: 5826
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 29
# File: MRO.L.csv, Rows: 5576
# File: AGG.csv, Rows: 5555
# File: LKQ.csv, Rows: 5550
# File: DVY.csv, Rows: 5526
# File: NRG.csv, Rows: 5510
# File: ITOT.csv, Rows: 5475
# File: VUG.csv, Rows: 5470
# File: VTV.csv, Rows: 5470
# File: VO.csv, Rows: 5470
# File: VHT.csv, Rows: 5470
# File: VGT.csv, Rows: 5470
# File: VV.csv, Rows: 5470
# File: VB.csv, Rows: 5470
# File: VBR.csv, Rows: 5470
# File: AIZ.csv, Rows: 5466
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 30
# File: CBRE.csv, Rows: 5379
# File: CRM.csv, Rows: 5371
# File: DPZ.csv, Rows: 5358
# File: ADM.L.csv, Rows: 5339
# File: EXR.csv, Rows: 5334
# File: GOOGL.csv, Rows: 5331
# File: GOOG.csv, Rows: 5331
# File: VNQ.csv, Rows: 5303
# File: DLR.csv, Rows: 5281
# File: MKTX.csv, Rows: 5276
# File: ENT.L.csv, Rows: 5276
# File: GLD.csv, Rows: 5267
# File: MPWR.csv, Rows: 5266
# File: LVS.csv, Rows: 5249
# File: CE.csv, Rows: 5224
# File: IAU.csv, Rows: 5219
# File: VWO.csv, Rows: 5191
# File: VGK.csv, Rows: 5191
# File: MT.AS.csv, Rows: 5190
# File: MTX.DE.csv, Rows: 5185
# File: ALO.PA.csv, Rows: 5178
# File: DXCM.csv, Rows: 5167
# File: BLDR.csv, Rows: 5115
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 31
# File: WBD.csv, Rows: 5108
# File: EXPE.csv, Rows: 5099
# File: EFV.csv, Rows: 5088
# File: CF.csv, Rows: 5084
# File: AMP.csv, Rows: 5060
# File: AAL.csv, Rows: 5052
# File: HIK.L.csv, Rows: 5051
# File: SDY.csv, Rows: 5017
# File: SPLG.csv, Rows: 5017
# File: ICE.csv, Rows: 5016
# File: LR.PA.csv, Rows: 5001
# File: LYV.csv, Rows: 4992
# File: CMG.csv, Rows: 4969
# File: UAL.csv, Rows: 4962
# File: RMV.L.csv, Rows: 4959
# File: TDG.csv, Rows: 4936
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 32
# File: LDOS.csv, Rows: 4786
# File: VYM.csv, Rows: 4764
# File: FSLR.csv, Rows: 4763
# File: IGSB.csv, Rows: 4728
# File: SHV.csv, Rows: 4728
# File: SKG.L.csv, Rows: 4703
# File: VEU.csv, Rows: 4690
# File: MBB.csv, Rows: 4684
# File: BR.csv, Rows: 4680
# File: SMCI.csv, Rows: 4675
# File: BND.csv, Rows: 4668
# File: BIV.csv, Rows: 4668
# File: BSV.csv, Rows: 4668
# File: TMUS.csv, Rows: 4661
# File: SPDW.csv, Rows: 4656
# File: DAL.csv, Rows: 4651
# File: PODD.csv, Rows: 4643
# File: BIL.csv, Rows: 4633
# File: MNDI.L.csv, Rows: 4631
# File: TEL.csv, Rows: 4622
# File: BX.csv, Rows: 4616
# File: VEA.csv, Rows: 4593
# File: LULU.csv, Rows: 4592
# File: MELI.csv, Rows: 4582
# File: MUB.csv, Rows: 4562
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 33
# File: ULTA.csv, Rows: 4529
# File: MGK.csv, Rows: 4486
# File: PM.csv, Rows: 4432
# File: V.csv, Rows: 4430
# File: ACWI.csv, Rows: 4424
# File: FRES.L.csv, Rows: 4413
# File: AWK.csv, Rows: 4406
# File: KDP.csv, Rows: 4396
# Processing cluster 34
# File: VRSK.csv, Rows: 4038
# File: PHNX.L.csv, Rows: 4026
# File: SCHX.csv, Rows: 4019
# File: SCHF.csv, Rows: 4019
# File: SCHB.csv, Rows: 4019
# File: DG.csv, Rows: 4011
# File: FTNT.csv, Rows: 4008
# File: VCIT.csv, Rows: 4005
# File: VGSH.csv, Rows: 4005
# File: VCSH.csv, Rows: 4005
# File: VGIT.csv, Rows: 4005
# File: SCHG.csv, Rows: 3978
# File: CHTR.csv, Rows: 3977
# File: BNR.DE.csv, Rows: 3960
# File: TQQQ.csv, Rows: 3951
# File: GNRC.csv, Rows: 3951
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# Processing cluster 35
# File: LYB.csv, Rows: 3899
# File: OCDO.L.csv, Rows: 3857
# File: TSLA.csv, Rows: 3856
# File: NXPI.csv, Rows: 3829
# File: VOO.csv, Rows: 3806
# File: GM.csv, Rows: 3756
# File: VXUS.csv, Rows: 3708
# File: KMI.csv, Rows: 3698
# Processing cluster 36
# File: GOVT.csv, Rows: 3438
# File: ENPH.csv, Rows: 3413
# File: PSX.csv, Rows: 3405
# File: AMCR.csv, Rows: 3382
# File: META.csv, Rows: 3379
# File: PANW.csv, Rows: 3336
# Processing cluster 37
# File: FANG.csv, Rows: 3277
# File: WDAY.csv, Rows: 3277
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: IEFA.csv, Rows: 3269
# File: IXUS.csv, Rows: 3269
# File: IEMG.csv, Rows: 3269
# File: ABBV.csv, Rows: 3224
# Processing cluster 38
# File: NCLH.csv, Rows: 3212
# File: CCH.L.csv, Rows: 3158
# File: IQV.csv, Rows: 3136
# File: VNA.DE.csv, Rows: 3122
# File: BNDX.csv, Rows: 3119
# File: NWS.csv, Rows: 3108
# File: NWSA.csv, Rows: 3108
# File: CDW.csv, Rows: 3102
# File: QUAL.csv, Rows: 3088
# Processing cluster 39
# File: WLN.PA.csv, Rows: 2902
# File: PAYC.csv, Rows: 2901
# File: BME.L.csv, Rows: 2874
# File: ANET.csv, Rows: 2865
# File: DGRO.csv, Rows: 2861
# File: IUSB.csv, Rows: 2861
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# File: SYF.csv, Rows: 2827
# File: ZAL.DE.csv, Rows: 2812
# File: CZR.csv, Rows: 2791
# File: CFG.csv, Rows: 2789
# File: KEYS.csv, Rows: 2771
# File: QRVO.csv, Rows: 2720
# Processing cluster 40
# File: ETSY.csv, Rows: 2649
# File: SHOP.csv, Rows: 2625
# File: PYPL.csv, Rows: 2594
# File: KHC.csv, Rows: 2594
# File: 1COV.DE.csv, Rows: 2558
# File: VTEB.csv, Rows: 2558
# File: SINCH.ST.csv, Rows: 2528
# Processing cluster 41
# File: FTV.csv, Rows: 2342
# File: TTD.csv, Rows: 2287
# File: CTEC.L.csv, Rows: 2272
# File: HWM.csv, Rows: 2258
# File: LW.csv, Rows: 2251
# File: COWZ.csv, Rows: 2222
# File: INVH.csv, Rows: 2196
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:16: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10246/2627308016.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df_vol.fillna(method='bfill', inplace=True)
